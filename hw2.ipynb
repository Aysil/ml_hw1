# %%
import pickle
import pandas as pd
import random
import numpy as np

# %%
with open('players.pkl', 'rb') as f:
    players = pickle.load(f)
with open('results.pkl', 'rb') as f:
    results = pickle.load(f)
with open('tournaments.pkl', 'rb') as f:
    tournaments = pickle.load(f)

# %%
keys = list(players.keys())
players[keys[0]]
# Out:
# {'id': 1, 'name': 'Алексей', 'patronymic': None, 'surname': 'Абабилов'}

# %%
keys = list(results.keys())
results[keys[2000]]
# Out:
# [{'team': {'id': 3586,
#    'name': 'Noname',
#    'town': {'id': 63, 'name': 'Волгоград'}},
#   'mask': '111111000101110111010111111110100010',
#   'current': {'name': 'Noname', 'town': {'id': 63, 'name': 'Волгоград'}},
#   'questionsTotal': 24,
#   'synchRequest': None,
#   'position': 1,
#   'controversials': [],
#   'flags': [],
#   'teamMembers': [{'flag': 'Б',
#     'usedRating': 4200,
#     'rating': 4208,
#     'player': {'id': 41255,
#      'name': 'Александр',
#      'patronymic': 'Сергеевич',
#      'surname': 'Акулиничев'}},
#    {'flag': 'Б',
#     'usedRating': 3484,
#     'rating': 4185,
#     'player': {'id': 3276,
#      'name': 'Александр',
#      'patronymic': 'Сергеевич',
#      'surname': 'Беседин'}},
#    {'flag': 'К',
#     'usedRating': 2763,
#     'rating': 4153,
#     'player': {'id': 42091,
#      'name': 'Юрий',
#      'patronymic': 'Александрович',
#      'surname': 'Воропаев'}},
#    {'flag': 'Б',
#     'usedRating': 2066,
#     'rating': 4133,
#     'player': {'id': 29731,
#      'name': 'Константин',
#      'patronymic': 'Александрович',
#      'surname': 'Смолий'}},
#    {'flag': 'Б',
#     'usedRating': 1178,
#     'rating': 3535,
#     'player': {'id': 72211,
#      'name': 'Мария',
#      'patronymic': 'Владимировна',
#      'surname': 'Подрядчикова'}},
#    {'flag': 'Б',
#     'usedRating': 546,
#     'rating': 3275,
#     'player': {'id': 19905,
#      'name': 'Антон',
#      'patronymic': 'Юрьевич',
#      'surname': 'Минкин'}}]},
#  {'team': {'id': 2065,
#    'name': 'Сирин',
#    'town': {'id': 63, 'name': 'Волгоград'}},
#   'mask': '011010001010111101011011110100010111',
#   'current': {'name': 'Сирин', 'town': {'id': 63, 'name': 'Волгоград'}},
#   'questionsTotal': 21,
#   'synchRequest': None,
#   'position': 2,
#   'controversials': [],
#   'flags': [],
#   'teamMembers': [{'flag': 'К',
#     'usedRating': 3775,
#     'rating': 3779,
#     'player': {'id': 20701,
#      'name': 'Роман',
#      'patronymic': 'Владимирович',
#      'surname': 'Мерзляков'}},
#    {'flag': 'Б',
#     'usedRating': 3093,
#     'rating': 3717,
#     'player': {'id': 56614,
#      'name': 'Денис',
#      'patronymic': 'Валерьевич',
#      'surname': 'Леонтьев'}},
#    {'flag': 'Б',
#     'usedRating': 2205,
#     'rating': 3313,
#     'player': {'id': 17566,
#      'name': 'Михаил',
#      'patronymic': 'Петрович',
#      'surname': 'Кухтик'}},
#    {'flag': 'Б',
#     'usedRating': 1642,
#     'rating': 3284,
#     'player': {'id': 34213,
#      'name': 'Екатерина',
#      'patronymic': 'Алексеевна',
#      'surname': 'Хрипунова'}},
#    {'flag': None,
#     'usedRating': 816,
#     'rating': 2450,
#     'player': {'id': 37788,
#      'name': 'Алексей',
#      'patronymic': 'Владимирович',
#      'surname': 'Соколов'}},
#    {'flag': None,
#     'usedRating': 392,
#     'rating': 2354,
#     'player': {'id': 680,
#      'name': 'Алексей',
#      'patronymic': 'Юрьевич',
#      'surname': 'Александров'}}]},
#  {'team': {'id': 40456,
#    'name': 'Volgograd United',
#    'town': {'id': 63, 'name': 'Волгоград'}},
#   'mask': '110110000010000101010011111100010101',
#   'current': {'name': 'Volgograd United',
#    'town': {'id': 63, 'name': 'Волгоград'}},
#   'questionsTotal': 17,
#   'synchRequest': None,
#   'position': 3,
#   'controversials': [],
#   'flags': [],
#   'teamMembers': [{'flag': 'Б',
#     'usedRating': 1504,
#     'rating': 1505,
#     'player': {'id': 54458,
#      'name': 'Артём',
#      'patronymic': 'Владимирович',
#      'surname': 'Солодков'}},
#    {'flag': 'Б',
#     'usedRating': 1214,
#     'rating': 1458,
#     'player': {'id': 59684,
#      'name': 'Маргарита',
#      'patronymic': 'Владимировна',
#      'surname': 'Солодкова'}},
#    {'flag': 'Б',
#     'usedRating': 948,
#     'rating': 1423,
#     'player': {'id': 68491,
#      'name': 'Дмитрий',
#      'patronymic': 'Андреевич',
#      'surname': 'Еркин'}},
#    {'flag': 'Б',
#     'usedRating': 711,
#     'rating': 1421,
#     'player': {'id': 61384,
#      'name': 'Дмитрий',
#      'patronymic': 'Владимирович',
#      'surname': 'Костенюк'}},
#    {'flag': 'Б',
#     'usedRating': 423,
#     'rating': 1268,
#     'player': {'id': 54023,
#      'name': 'Екатерина',
#      'patronymic': 'Юрьевна',
#      'surname': 'Иващенко'}},
#    {'flag': 'Б',
#     'usedRating': 211,
#     'rating': 1268,
#     'player': {'id': 69706,
#      'name': 'Елена',
#      'patronymic': 'Александровна',
#      'surname': 'Ермакова'}}]},
#  {'team': {'id': 37490,
#    'name': 'Хладна Звезда',
#    'town': {'id': 63, 'name': 'Волгоград'}},
#   'mask': '000110001110001000011000011100010001',
#   'current': {'name': 'Хладна Звезда',
#    'town': {'id': 63, 'name': 'Волгоград'}},
#   'questionsTotal': 13,
#   'synchRequest': None,
#   'position': 4,
#   'controversials': [],
#   'flags': [],
#   'teamMembers': [{'flag': 'Б',
#     'usedRating': 1869,
#     'rating': 1869,
#     'player': {'id': 24507,
#      'name': 'Евгений',
#      'patronymic': 'Викторович',
#      'surname': 'Перехожев'}},
#    {'flag': 'Б',
#     'usedRating': 1226,
#     'rating': 1471,
#     'player': {'id': 6977,
#      'name': 'Андрей',
#      'patronymic': 'Юрьевич',
#      'surname': 'Гетманенко'}},
#    {'flag': None,
#     'usedRating': 734,
#     'rating': 1104,
#     'player': {'id': 41293,
#      'name': 'Роман',
#      'patronymic': 'Сергеевич',
#      'surname': 'Кобышев'}},
#    {'flag': 'Б',
#     'usedRating': 463,
#     'rating': 925,
#     'player': {'id': 65906,
#      'name': 'Таисия',
#      'patronymic': 'Александровна',
#      'surname': 'Кудинова'}}]},
#  {'team': {'id': 37737,
#    'name': 'Не исключено',
#    'town': {'id': 63, 'name': 'Волгоград'}},
#   'mask': '011000000100000100001011110000010001',
#   'current': {'name': 'Не исключено', 'town': {'id': 63, 'name': 'Волгоград'}},
#   'questionsTotal': 11,
#   'synchRequest': None,
#   'position': 5,
#   'controversials': [],
#   'flags': [],
#   'teamMembers': [{'flag': 'Б',
#     'usedRating': 1133,
#     'rating': 1132,
#     'player': {'id': 54454,
#      'name': 'Павел',
#      'patronymic': 'Сергеевич',
#      'surname': 'Андреев'}},
#    {'flag': 'Б',
#     'usedRating': 830,
#     'rating': 994,
#     'player': {'id': 26653,
#      'name': 'Антон',
#      'patronymic': 'Юрьевич',
#      'surname': 'Рассказов'}},
#    {'flag': 'Б',
#     'usedRating': 628,
#     'rating': 939,
#     'player': {'id': 57145,
#      'name': 'Павел',
#      'patronymic': 'Александрович',
#      'surname': 'Донцов'}},
#    {'flag': 'Б',
#     'usedRating': 448,
#     'rating': 892,
#     'player': {'id': 59467,
#      'name': 'Андрей',
#      'patronymic': 'Алексеевич',
#      'surname': 'Суходолов'}},
#    {'flag': 'К',
#     'usedRating': 257,
#     'rating': 768,
#     'player': {'id': 54455,
#      'name': 'Антон',
#      'patronymic': 'Николаевич',
#      'surname': 'Бондаренко'}},
#    {'flag': 'Б',
#     'usedRating': 118,
#     'rating': 702,
#     'player': {'id': 71740,
#      'name': 'Алёна',
#      'patronymic': 'Игоревна',
#      'surname': 'Онищенко'}}]},
#  {'team': {'id': 27390,
#    'name': 'Приход',
#    'town': {'id': 63, 'name': 'Волгоград'}},
#   'mask': '001010000000001000000000101110000001',
#   'current': {'name': 'Приход', 'town': {'id': 63, 'name': 'Волгоград'}},
#   'questionsTotal': 8,
#   'synchRequest': None,
#   'position': 6,
#   'controversials': [],
#   'flags': [],
#   'teamMembers': [{'flag': 'Л',
#     'usedRating': 1420,
#     'rating': 1424,
#     'player': {'id': 16740,
#      'name': 'Александр',
#      'patronymic': 'Валерьевич',
#      'surname': 'Кубатиев'}},
#    {'flag': 'Б',
#     'usedRating': 808,
#     'rating': 966,
#     'player': {'id': 41763,
#      'name': 'Павел',
#      'patronymic': 'Александрович',
#      'surname': 'Бакулин'}},
#    {'flag': 'Л',
#     'usedRating': 211,
#     'rating': 315,
#     'player': {'id': 56612,
#      'name': 'Сергей',
#      'patronymic': 'Сергеевич',
#      'surname': 'Демидок'}},
#    {'flag': 'Б',
#     'usedRating': 31,
#     'rating': 62,
#     'player': {'id': 41760,
#      'name': 'Сергей',
#      'patronymic': 'Викторович',
#      'surname': 'Несвит'}}]},
#  {'team': {'id': 37767,
#    'name': 'Скажи миру Ы',
#    'town': {'id': 63, 'name': 'Волгоград'}},
#   'mask': '100010000000000000001010100100000001',
#   'current': {'name': 'Скажи миру Ы', 'town': {'id': 63, 'name': 'Волгоград'}},
#   'questionsTotal': 7,
#   'synchRequest': None,
#   'position': 7,
#   'controversials': [],
#   'flags': [],
#   'teamMembers': [{'flag': 'Б',
#     'usedRating': 543,
#     'rating': 545,
#     'player': {'id': 79239,
#      'name': 'Алеся',
#      'patronymic': 'Дмитриевна',
#      'surname': 'Пономарёва'}},
#    {'flag': 'Б',
#     'usedRating': 420,
#     'rating': 506,
#     'player': {'id': 54611,
#      'name': 'Анатолий',
#      'patronymic': 'Александрович',
#      'surname': 'Мухин'}},
#    {'flag': 'Б',
#     'usedRating': 315,
#     'rating': 473,
#     'player': {'id': 57138,
#      'name': 'Диана',
#      'patronymic': 'Дмитриевна',
#      'surname': 'Тчанникова'}},
#    {'flag': 'Л',
#     'usedRating': 94,
#     'rating': 188,
#     'player': {'id': 59682,
#      'name': 'Кирилл',
#      'patronymic': 'Павлович',
#      'surname': 'Бойков'}},
#    {'flag': 'Б',
#     'usedRating': 62,
#     'rating': 189,
#     'player': {'id': 66811,
#      'name': 'Виктор',
#      'patronymic': 'Олегович',
#      'surname': 'Лиханов'}},
#    {'flag': 'Б',
#     'usedRating': 28,
#     'rating': 169,
#     'player': {'id': 54610,
#      'name': 'Максим',
#      'patronymic': 'Петрович',
#      'surname': 'Мещеряков'}}]},
#  {'team': {'id': 45306,
#    'name': 'Клевер',
#    'town': {'id': 63, 'name': 'Волгоград'}},
#   'mask': '000010000000001000000000000000010001',
#   'current': {'name': 'Клевер', 'town': {'id': 63, 'name': 'Волгоград'}},
#   'questionsTotal': 4,
#   'synchRequest': None,
#   'position': 8,
#   'controversials': [],
#   'flags': [],
#   'teamMembers': [{'flag': 'Б',
#     'usedRating': 343,
#     'rating': 344,
#     'player': {'id': 88601,
#      'name': 'Савелий',
#      'patronymic': 'Владимирович',
#      'surname': 'Лименя'}},
#    {'flag': 'Б',
#     'usedRating': 138,
#     'rating': 166,
#     'player': {'id': 90316,
#      'name': 'Максим',
#      'patronymic': 'Романович',
#      'surname': 'Маслов'}},
#    {'flag': 'Б',
#     'usedRating': 45,
#     'rating': 69,
#     'player': {'id': 91059,
#      'name': 'Ольга',
#      'patronymic': 'Владимировна',
#      'surname': 'Ананьина'}}]}]

# %%
keys = list(tournaments.keys())
tournaments[keys[2]]
# Out:
# {'id': 3,
#  'name': 'Турнир в Ижевске',
#  'dateStart': '2003-11-22T00:00:00+03:00',
#  'dateEnd': '2003-11-24T00:00:00+03:00',
#  'type': {'id': 2, 'name': 'Обычный'},
#  'season': '/seasons/2',
#  'orgcommittee': [],
#  'synchData': None,
#  'questionQty': None}

# %% [markdown]
# ### Подготовка данных
# Разбиваем на train и test, в train берем 2019 год, в test - 2020. Выкидываем из рассмотрения данные, где нет поля mask или где оно заполнено некорректно, например в рамках одного турнира для разных команд значение в поле mask имеет разную длину.

# %%
train = {}
train_players = {}
test = {}
test_players = {}
for tournament_id in tournaments.keys():
    tournament_data = tournaments[tournament_id]
    year = tournament_data['dateStart'][:4]
    if year not in ['2019', '2020']:
        continue
    filtered_results = []
    skip_tournament = False
    mask_len = None
    for team_data in results[tournament_id]:
        if 'mask' not in team_data:
            continue
        if team_data['mask'] is None:
            continue
        if mask_len is None:
            mask_len = len(team_data['mask'])
        if sum([e not in ['0','1'] for e in team_data['mask']]) > 0:
            skip_tournament = True
            break
        if mask_len != len(team_data['mask']):
            skip_tournament = True
            break
        if len(team_data['teamMembers']) == 0:
            continue
        filtered_results.append(team_data)
    if skip_tournament:
        continue
    if year == '2019':
        for team_data in filtered_results:
            ids = [e['player']['id'] for e in team_data['teamMembers']]
            for id in ids:
                if id in train_players:
                    train_players[id]['games'] += 1
                else:
                    train_players[id] = {'games': 1}
        train[tournament_id] = filtered_results
    if year == '2020':
        test[tournament_id] = filtered_results
        for team_data in filtered_results:
            ids = [e['player']['id'] for e in team_data['teamMembers']]
            for id in ids:
                if id in test_players:
                    test_players[id]['games'] += 1
                else:
                    test_players[id] = {'games': 1}

# %% [markdown]
# Отбираем игроков, которые сыграли в более, чем 10 играх, для таких игроков на основе имеющихся данных можно более достоверно предсказывать рейтинг

# %%
train_players_ids = [e for e in train_players if train_players[e]['games'] > 10]
len(train_players_ids)
# Out:
# 8013

# %%
train_players_ids_set = set(train_players_ids)
filtered_train = {}
for tournament_id in train:
    teams = train[tournament_id]
    filtered_teams = []
    for team_data in teams:
        ids = [e['player']['id'] for e in team_data['teamMembers']]
        curr_players = list(set(ids) & train_players_ids_set)
        if len(curr_players) == 0:
            continue
        filtered_teams.append({'mask': team_data['mask'], 'ids': curr_players})
    filtered_train[tournament_id] = filtered_teams

# %%
df_players = pd.DataFrame(players).transpose()
df_players
# Out:
#             id       name  patronymic    surname
# 1            1    Алексей        None   Абабилов
# 10          10      Игорь                 Абалов
# 11          11    Наталья     Юрьевна  Абалымова
# 12          12      Артур  Евгеньевич    Абальян
# 13          13       Эрик  Евгеньевич    Абальян
# ...        ...        ...         ...        ...
# 224700  224700      Артём  Евгеньевич      Садов
# 224701  224701     Даниил    Олегович   Трефилов
# 224702  224702   Владимир  Араратович   Басенцян
# 224703  224703     Руслан   Ринатович   Дауранов
# 224704  224704  Александр  Викторович    Гапонов
#
# [204063 rows x 4 columns]

# %%
res = {e: {'id': e, 'name': players[e]['name'], 'patronymic': players[e]['patronymic'], 'surname': players[e]['surname'], 'questions': 0, 'right_answers': 0} for e in train_players_ids}
for tournament_id in train:
    teams = train[tournament_id]
    for team in teams:
        right_answers = team['mask'].count('1')
        questions = len(team['mask'])
        for member in team['teamMembers']:
            id = member['player']['id']
            res[id]['questions'] += questions
            res[id]['right_answers'] += right_answers
res
# Out:
# {131077: {'id': 131077,
#   'name': 'Паруйр',
#   'patronymic': 'Паруйрович',
#   'surname': 'Аланакян',
#   'questions': 1537,
#   'right_answers': 783},
#  131080: {'id': 131080,
#   'name': 'Иван',
#   'patronymic': 'Владимирович',
#   'surname': 'Мешков',
#   'questions': 598,
#   'right_answers': 214},
#  131082: {'id': 131082,
#   'name': 'Валерия',
#   'patronymic': 'Андреевна',
#   'surname': 'Кан',
#   'questions': 4788,
#   'right_answers': 2690},
#  131083: {'id': 131083,
#   'name': 'Валерий',
#   'patronymic': 'Рафаилович',
#   'surname': 'Аввакумов',
#   'questions': 1445,
#   'right_answers': 839},
#  15: {'id': 15,
#   'name': 'Олег',
#   'patronymic': 'Игоревич',
#   'surname': 'Абарников',
#   'questions': 562,
#   'right_answers': 202},
#  16: {'id': 16,
#   'name': 'Азер',
#   'patronymic': 'Абасали оглы',
#   'surname': 'Абасалиев',
#   'questions': 234,
#   'right_answers': 129},
#  23: {'id': 23,
#   'name': 'Андрей',
#   'patronymic': 'Николаевич',
#   'surname': 'Абащенко',
#   'questions': 36,
#   'right_answers': 18},
#  131098: {'id': 131098,
#   'name': 'Екатерина',
#   'patronymic': 'Анатольевна',
#   'surname': 'Дьяк',
#   'questions': 732,
#   'right_answers': 227},
#  131099: {'id': 131099,
#   'name': 'Илья',
#   'patronymic': 'Сергеевич',
#   'surname': 'Метревели',
#   'questions': 72,
#   'right_answers': 22},
#  31: {'id': 31,
#   'name': 'Ситара',
#   'patronymic': 'Фахраддин гызы',
#   'surname': 'Абасова',
#   'questions': 1050,
#   'right_answers': 464},
#  131106: {'id': 131106,
#   'name': 'Екатерина',
#   'patronymic': 'Романовна',
#   'surname': 'Бурякова',
#   'questions': 72,
#   'right_answers': 32},
#  35: {'id': 35,
#   'name': 'Нарек',
#   'patronymic': 'Гагикович',
#   'surname': 'Абгарян',
#   'questions': 927,
#   'right_answers': 480},
#  131108: {'id': 131108,
#   'name': 'Сергей',
#   'patronymic': 'Иванович',
#   'surname': 'Бородько',
#   'questions': 522,
#   'right_answers': 259},
#  38: {'id': 38,
#   'name': 'Эдуард',
#   'patronymic': '',
#   'surname': 'Абдеев',
#   'questions': 597,
#   'right_answers': 121},
#  131111: {'id': 131111,
#   'name': 'Елена',
#   'patronymic': 'Александровна',
#   'surname': 'Журавлёва',
#   'questions': 558,
#   'right_answers': 279},
#  131112: {'id': 131112,
#   'name': 'Николай',
#   'patronymic': 'Александрович',
#   'surname': 'Аникин',
#   'questions': 216,
#   'right_answers': 83},
#  131117: {'id': 131117,
#   'name': 'Владимир',
#   'patronymic': 'Владимирович',
#   'surname': 'Привалов',
#   'questions': 45,
#   'right_answers': 15},
#  47: {'id': 47,
#   'name': 'Алёна',
#   'patronymic': 'Маратовна',
#   'surname': 'Абдрахманова',
#   'questions': 543,
#   'right_answers': 284},
#  131120: {'id': 131120,
#   'name': 'Филипп',
#   'patronymic': '',
#   'surname': 'Устинов',
#   'questions': 1920,
#   'right_answers': 817},
#  208423: {'id': 208423,
#   'name': 'Алексей',
#   'patronymic': 'Викторович',
#   'surname': 'Маслов',
#   'questions': 72,
#   'right_answers': 2},
#  208424: {'id': 208424,
#   'name': 'Анастасия',
#   'patronymic': 'Сергеевна',
#   'surname': 'Федосеева',
#   'questions': 72,
#   'right_answers': 2},
#  59: {'id': 59,
#   'name': 'Руфат',
#   'patronymic': 'Чингиз оглы',
#   'surname': 'Абдулла',
#   'questions': 516,
#   'right_answers': 197},
#  131135: {'id': 131135,
#   'name': 'Музаффар',
#   'patronymic': 'Алишер угли',
#   'surname': 'Ахмедов',
#   'questions': 1179,
#   'right_answers': 484},
#  208425: {'id': 208425,
#   'name': 'Анастасия',
#   'patronymic': 'Владимировна',
#   'surname': 'Юсупова',
#   'questions': 72,
#   'right_answers': 2},
#  65: {'id': 65,
#   'name': 'Орхан',
#   'patronymic': 'Юсиф оглы',
#   'surname': 'Абдуллаев',
#   'questions': 288,
#   'right_answers': 96},
#  131139: {'id': 131139,
#   'name': 'Антон',
#   'patronymic': 'Анатольевич',
#   'surname': 'Гордиюк',
#   'questions': 48,
#   'right_answers': 15},
#  131140: {'id': 131140,
#   'name': 'Михаил',
#   'patronymic': 'Александрович',
#   'surname': 'Хурсан',
#   'questions': 291,
#   'right_answers': 120},
#  131146: {'id': 131146,
#   'name': 'Михаил',
#   'patronymic': 'Андреевич',
#   'surname': 'Анохин',
#   'questions': 597,
#   'right_answers': 121},
#  131147: {'id': 131147,
#   'name': 'Елизавета',
#   'patronymic': 'Дмитриевна',
#   'surname': 'Ноздреватых',
#   'questions': 3131,
#   'right_answers': 1241},
#  79: {'id': 79,
#   'name': 'Саидкамол',
#   'patronymic': 'Саидахатович',
#   'surname': 'Абдуразаков',
#   'questions': 1500,
#   'right_answers': 636},
#  80: {'id': 80,
#   'name': 'Виктор',
#   'patronymic': 'Александрович',
#   'surname': 'Абдураманов',
#   'questions': 892,
#   'right_answers': 490},
#  82: {'id': 82,
#   'name': 'Владимир',
#   'patronymic': 'Юрьевич',
#   'surname': 'Абдурахманов',
#   'questions': 1782,
#   'right_answers': 714},
#  131154: {'id': 131154,
#   'name': 'Михаил',
#   'patronymic': 'Сергеевич',
#   'surname': 'Калинин',
#   'questions': 108,
#   'right_answers': 63},
#  131157: {'id': 131157,
#   'name': 'Илья',
#   'patronymic': 'Геннадьевич',
#   'surname': 'Мирин',
#   'questions': 45,
#   'right_answers': 24},
#  131159: {'id': 131159,
#   'name': 'Юрий',
#   'patronymic': 'Владимирович',
#   'surname': 'Гордиенко',
#   'questions': 1813,
#   'right_answers': 927},
#  98: {'id': 98,
#   'name': 'Тимур',
#   'patronymic': 'Асанович',
#   'surname': 'Аблаев',
#   'questions': 117,
#   'right_answers': 39},
#  131176: {'id': 131176,
#   'name': 'Антон',
#   'patronymic': 'Сергеевич',
#   'surname': 'Дюба',
#   'questions': 6802,
#   'right_answers': 3145},
#  131177: {'id': 131177,
#   'name': 'Ольга',
#   'patronymic': 'Сергеевна',
#   'surname': 'Дюба',
#   'questions': 108,
#   'right_answers': 38},
#  131179: {'id': 131179,
#   'name': 'Фируз',
#   'patronymic': 'Искандарович',
#   'surname': 'Бакоев',
#   'questions': 2793,
#   'right_answers': 966},
#  131180: {'id': 131180,
#   'name': 'Дарья',
#   'patronymic': 'Ивановна',
#   'surname': 'Никитченко',
#   'questions': 72,
#   'right_answers': 30},
#  112: {'id': 112,
#   'name': 'Жанна',
#   'patronymic': 'Сергеевна',
#   'surname': 'Аболмазова',
#   'questions': 156,
#   'right_answers': 36},
#  113: {'id': 113,
#   'name': 'Дмитрий',
#   'patronymic': 'Юрьевич',
#   'surname': 'Аболонко',
#   'questions': 228,
#   'right_answers': 87},
#  117: {'id': 117,
#   'name': 'Марина',
#   'patronymic': 'Германовна',
#   'surname': 'Аботурова',
#   'questions': 2424,
#   'right_answers': 1368},
#  131190: {'id': 131190,
#   'name': 'Мария',
#   'patronymic': 'Алексеевна',
#   'surname': 'Фомченко',
#   'questions': 40,
#   'right_answers': 9},
#  119: {'id': 119,
#   'name': 'Ани',
#   'patronymic': 'Седраковна',
#   'surname': 'Абраамян',
#   'questions': 619,
#   'right_answers': 292},
#  133: {'id': 133,
#   'name': 'Андрей',
#   'patronymic': 'Леонидович',
#   'surname': 'Абрамов',
#   'questions': 1009,
#   'right_answers': 581},
#  136: {'id': 136,
#   'name': 'Георгий',
#   'patronymic': '',
#   'surname': 'Абрамов',
#   'questions': 360,
#   'right_answers': 136},
#  144: {'id': 144,
#   'name': 'Сергей',
#   'patronymic': 'Леонидович',
#   'surname': 'Абрамов',
#   'questions': 1281,
#   'right_answers': 768},
#  131221: {'id': 131221,
#   'name': 'Илья',
#   'patronymic': 'Ильшатович',
#   'surname': 'Гарфутдинов',
#   'questions': 36,
#   'right_answers': 16},
#  131222: {'id': 131222,
#   'name': 'Константин',
#   'patronymic': 'Николаевич',
#   'surname': 'Иванов',
#   'questions': 228,
#   'right_answers': 129},
#  150: {'id': 150,
#   'name': 'Алёна',
#   'patronymic': 'Анатольевна',
#   'surname': 'Вельможко',
#   'questions': 372,
#   'right_answers': 238},
#  131223: {'id': 131223,
#   'name': 'Карина',
#   'patronymic': 'Аскаровна',
#   'surname': 'Абдрахимова',
#   'questions': 111,
#   'right_answers': 55},
#  153: {'id': 153,
#   'name': 'Екатерина',
#   'patronymic': 'Владимировна',
#   'surname': 'Абрамова',
#   'questions': 258,
#   'right_answers': 112},
#  208443: {'id': 208443,
#   'name': 'Дмитрий',
#   'patronymic': 'Ефимович',
#   'surname': 'Абрамов',
#   'questions': 72,
#   'right_answers': 0},
#  131224: {'id': 131224,
#   'name': 'Юлия',
#   'patronymic': 'Дмитриевна',
#   'surname': 'Костельная',
#   'questions': 72,
#   'right_answers': 28},
#  131229: {'id': 131229,
#   'name': 'Елена',
#   'patronymic': 'Владимировна',
#   'surname': 'Левчук',
#   'questions': 72,
#   'right_answers': 25},
#  131230: {'id': 131230,
#   'name': 'Даниил',
#   'patronymic': 'Анатольевич',
#   'surname': 'Роговский',
#   'questions': 72,
#   'right_answers': 25},
#  131231: {'id': 131231,
#   'name': 'Рамис',
#   'patronymic': 'Ришатович',
#   'surname': 'Шакиров',
#   'questions': 72,
#   'right_answers': 14},
#  160: {'id': 160,
#   'name': 'Наталия',
#   'patronymic': 'Александровна',
#   'surname': 'Абрамова',
#   'questions': 39,
#   'right_answers': 19},
#  157: {'id': 157,
#   'name': 'Ксения',
#   'patronymic': 'Игоревна',
#   'surname': 'Абрамова',
#   'questions': 36,
#   'right_answers': 21},
#  131235: {'id': 131235,
#   'name': 'Игорь',
#   'patronymic': 'Сергеевич',
#   'surname': 'Горшенин',
#   'questions': 72,
#   'right_answers': 14},
#  131240: {'id': 131240,
#   'name': 'Никита',
#   'patronymic': 'Юрьевич',
#   'surname': 'Акимов',
#   'questions': 72,
#   'right_answers': 18},
#  176: {'id': 176,
#   'name': 'Сергей',
#   'patronymic': 'Лазаревич',
#   'surname': 'Абрамян',
#   'questions': 2303,
#   'right_answers': 1470},
#  178: {'id': 178,
#   'name': 'Вадим',
#   'patronymic': 'Вадимович',
#   'surname': 'Абрашин',
#   'questions': 1563,
#   'right_answers': 685},
#  182: {'id': 182,
#   'name': 'Алексей',
#   'patronymic': 'Михайлович',
#   'surname': 'Абросимов',
#   'questions': 1695,
#   'right_answers': 809},
#  131263: {'id': 131263,
#   'name': 'Константин',
#   'patronymic': '',
#   'surname': 'Штейнке',
#   'questions': 36,
#   'right_answers': 18},
#  131267: {'id': 131267,
#   'name': 'Давид',
#   'patronymic': 'Викторович',
#   'surname': 'Тавасиев',
#   'questions': 3216,
#   'right_answers': 1365},
#  196: {'id': 196,
#   'name': 'Адиль',
#   'patronymic': 'Фикрет оглы',
#   'surname': 'Абушев',
#   'questions': 204,
#   'right_answers': 81},
#  131270: {'id': 131270,
#   'name': 'Ольга',
#   'patronymic': 'Владимировна',
#   'surname': 'Кореновская',
#   'questions': 108,
#   'right_answers': 40},
#  131271: {'id': 131271,
#   'name': 'Ярослава',
#   'patronymic': 'Антоновна',
#   'surname': 'Стрельцова',
#   'questions': 180,
#   'right_answers': 66},
#  131277: {'id': 131277,
#   'name': 'Анастасия',
#   'patronymic': '',
#   'surname': 'Харук',
#   'questions': 36,
#   'right_answers': 13},
#  131282: {'id': 131282,
#   'name': 'Владимир',
#   'patronymic': '',
#   'surname': 'Рущак',
#   'questions': 697,
#   'right_answers': 271},
#  131283: {'id': 131283,
#   'name': 'Анатолий',
#   'patronymic': 'Анатольевич',
#   'surname': 'Усенко',
#   'questions': 72,
#   'right_answers': 48},
#  131285: {'id': 131285,
#   'name': 'Виктория',
#   'patronymic': '',
#   'surname': 'Гусенюк',
#   'questions': 36,
#   'right_answers': 12},
#  131290: {'id': 131290,
#   'name': 'Лилия',
#   'patronymic': 'Загитовна',
#   'surname': 'Гайнуллина',
#   'questions': 1731,
#   'right_answers': 811},
#  131291: {'id': 131291,
#   'name': 'Константин',
#   'patronymic': 'Владимирович',
#   'surname': 'Гражданов',
#   'questions': 828,
#   'right_answers': 404},
#  131292: {'id': 131292,
#   'name': 'Александра',
#   'patronymic': 'Владимировна',
#   'surname': 'Брянцева',
#   'questions': 36,
#   'right_answers': 28},
#  223: {'id': 223,
#   'name': 'Илья',
#   'patronymic': 'Леонидович',
#   'surname': 'Аввакумов',
#   'questions': 136,
#   'right_answers': 85},
#  131301: {'id': 131301,
#   'name': 'Александра',
#   'patronymic': 'Николаевна',
#   'surname': 'Гонина',
#   'questions': 75,
#   'right_answers': 20},
#  230: {'id': 230,
#   'name': 'Михаил',
#   'patronymic': 'Александрович',
#   'surname': 'Авдеев',
#   'questions': 732,
#   'right_answers': 448},
#  131303: {'id': 131303,
#   'name': 'Андрей',
#   'patronymic': 'Алексеевич',
#   'surname': 'Сергеюк',
#   'questions': 513,
#   'right_answers': 193},
#  232: {'id': 232,
#   'name': 'Сергей',
#   'patronymic': 'Петрович',
#   'surname': 'Авдеев',
#   'questions': 1676,
#   'right_answers': 653},
#  233: {'id': 233,
#   'name': 'Анжелика',
#   'patronymic': 'Сергеевна',
#   'surname': 'Авдеева',
#   'questions': 724,
#   'right_answers': 208},
#  236: {'id': 236,
#   'name': 'Дмитрий',
#   'patronymic': 'Владимирович',
#   'surname': 'Авдеенко',
#   'questions': 81,
#   'right_answers': 53},
#  131313: {'id': 131313,
#   'name': 'Екатерина',
#   'patronymic': 'Александровна',
#   'surname': 'Конькова',
#   'questions': 210,
#   'right_answers': 93},
#  131315: {'id': 131315,
#   'name': 'Валерий',
#   'patronymic': 'Грантович',
#   'surname': 'Месропян',
#   'questions': 2170,
#   'right_answers': 902},
#  131320: {'id': 131320,
#   'name': 'Мария',
#   'patronymic': 'Сергеевна',
#   'surname': 'Дуброва',
#   'questions': 1428,
#   'right_answers': 626},
#  131322: {'id': 131322,
#   'name': 'Дарья',
#   'patronymic': 'Сергеевна',
#   'surname': 'Кузенкова',
#   'questions': 48,
#   'right_answers': 9},
#  131333: {'id': 131333,
#   'name': 'Наталия',
#   'patronymic': 'Андреевна',
#   'surname': 'Сафонова',
#   'questions': 545,
#   'right_answers': 354},
#  261: {'id': 261,
#   'name': 'Евгений',
#   'patronymic': 'Сергеевич',
#   'surname': 'Аверкин',
#   'questions': 72,
#   'right_answers': 34},
#  263: {'id': 263,
#   'name': 'Анна',
#   'patronymic': 'Олеговна',
#   'surname': 'Аверкина',
#   'questions': 84,
#   'right_answers': 31},
#  208466: {'id': 208466,
#   'name': 'Софья',
#   'patronymic': 'Андреевна',
#   'surname': 'Шиш',
#   'questions': 72,
#   'right_answers': 6},
#  131347: {'id': 131347,
#   'name': 'Павел',
#   'patronymic': 'Алексеевич',
#   'surname': 'Цветков',
#   'questions': 180,
#   'right_answers': 114},
#  278: {'id': 278,
#   'name': 'Араик',
#   'patronymic': 'Самвелович',
#   'surname': 'Аветисян',
#   'questions': 1423,
#   'right_answers': 808},
#  131353: {'id': 131353,
#   'name': 'Татьяна',
#   'patronymic': 'Михайловна',
#   'surname': 'Клочихина',
#   'questions': 216,
#   'right_answers': 64},
#  286: {'id': 286,
#   'name': 'Карен',
#   'patronymic': '',
#   'surname': 'Аветисян',
#   'questions': 60,
#   'right_answers': 17},
#  131373: {'id': 131373,
#   'name': 'Ирина',
#   'patronymic': 'Сергеевна',
#   'surname': 'Корчагина',
#   'questions': 36,
#   'right_answers': 19},
#  131377: {'id': 131377,
#   'name': 'Дарья',
#   'patronymic': 'Сергеевна',
#   'surname': 'Кузнецова',
#   'questions': 2485,
#   'right_answers': 1388},
#  131384: {'id': 131384,
#   'name': 'Альберт',
#   'patronymic': 'Арамович',
#   'surname': 'Мелкумян',
#   'questions': 60,
#   'right_answers': 7},
#  131387: {'id': 131387,
#   'name': 'Виталий',
#   'patronymic': 'Александрович',
#   'surname': 'Королёв',
#   'questions': 633,
#   'right_answers': 252},
#  315: {'id': 315,
#   'name': 'Александр',
#   'patronymic': 'Николаевич',
#   'surname': 'Автух',
#   'questions': 366,
#   'right_answers': 274},
#  131389: {'id': 131389,
#   'name': 'Юлия',
#   'patronymic': 'Витальевна',
#   'surname': 'Самусева',
#   'questions': 36,
#   'right_answers': 13},
#  131394: {'id': 131394,
#   'name': 'Ирина',
#   'patronymic': 'Юрьевна',
#   'surname': 'Флотская',
#   'questions': 350,
#   'right_answers': 173},
#  323: {'id': 323,
#   'name': 'Заур',
#   'patronymic': 'Фуад оглы',
#   'surname': 'Агаев',
#   'questions': 4099,
#   'right_answers': 2298},
#  322: {'id': 322,
#   'name': 'Джабраил',
#   'patronymic': '',
#   'surname': 'Агаев',
#   'questions': 72,
#   'right_answers': 31},
#  328: {'id': 328,
#   'name': 'Алия',
#   'patronymic': 'Ибрагимовна',
#   'surname': 'Агаева',
#   'questions': 2339,
#   'right_answers': 1209},
#  330: {'id': 330,
#   'name': 'Марина',
#   'patronymic': 'Сахибовна',
#   'surname': 'Бойко',
#   'questions': 151,
#   'right_answers': 60},
#  131406: {'id': 131406,
#   'name': 'Павел',
#   'patronymic': 'Петрович',
#   'surname': 'Тимофеев',
#   'questions': 606,
#   'right_answers': 171},
#  131410: {'id': 131410,
#   'name': 'Константин',
#   'patronymic': 'Сергеевич',
#   'surname': 'Лащухин',
#   'questions': 699,
#   'right_answers': 225},
#  131415: {'id': 131415,
#   'name': 'Михаил',
#   'patronymic': 'Юрьевич',
#   'surname': 'Вицен',
#   'questions': 220,
#   'right_answers': 80},
#  131416: {'id': 131416,
#   'name': 'Татьяна',
#   'patronymic': 'Аркадьевна',
#   'surname': 'Миронова',
#   'questions': 114,
#   'right_answers': 65},
#  131417: {'id': 131417,
#   'name': 'Сергей',
#   'patronymic': 'Александрович',
#   'surname': 'Миронов',
#   'questions': 114,
#   'right_answers': 65},
#  131418: {'id': 131418,
#   'name': 'Анна',
#   'patronymic': 'Романовна',
#   'surname': 'Зац',
#   'questions': 150,
#   'right_answers': 90},
#  131419: {'id': 131419,
#   'name': 'Павел',
#   'patronymic': 'Анатольевич',
#   'surname': 'Рапопорт',
#   'questions': 294,
#   'right_answers': 175},
#  131420: {'id': 131420,
#   'name': 'Максим',
#   'patronymic': 'Анатольевич',
#   'surname': 'Рапопорт',
#   'questions': 114,
#   'right_answers': 65},
#  345: {'id': 345,
#   'name': 'Глеб',
#   'patronymic': 'Александрович',
#   'surname': 'Агапов',
#   'questions': 441,
#   'right_answers': 242},
#  131422: {'id': 131422,
#   'name': 'Игорь',
#   'patronymic': 'Борисович',
#   'surname': 'Глик',
#   'questions': 252,
#   'right_answers': 157},
#  131423: {'id': 131423,
#   'name': 'Илья',
#   'patronymic': '',
#   'surname': 'Хинский',
#   'questions': 108,
#   'right_answers': 66},
#  131426: {'id': 131426,
#   'name': 'Михаил',
#   'patronymic': '',
#   'surname': 'Каган',
#   'questions': 216,
#   'right_answers': 139},
#  354: {'id': 354,
#   'name': 'Алексей',
#   'patronymic': 'Сергеевич',
#   'surname': 'Агарков',
#   'questions': 153,
#   'right_answers': 44},
#  131443: {'id': 131443,
#   'name': 'Александр',
#   'patronymic': 'Ефимович',
#   'surname': 'Миньковский',
#   'questions': 36,
#   'right_answers': 18},
#  131445: {'id': 131445,
#   'name': 'Тимур',
#   'patronymic': '',
#   'surname': 'Кожахметов',
#   'questions': 504,
#   'right_answers': 233},
#  131446: {'id': 131446,
#   'name': 'Нурсултан',
#   'patronymic': 'Абатович',
#   'surname': 'Журманбетов',
#   'questions': 144,
#   'right_answers': 23},
#  376: {'id': 376,
#   'name': 'Ольга',
#   'patronymic': 'Назаровна',
#   'surname': 'Агаханова',
#   'questions': 1407,
#   'right_answers': 739},
#  377: {'id': 377,
#   'name': 'Сауле',
#   'patronymic': 'Ануаровна',
#   'surname': 'Агдаулетова',
#   'questions': 41,
#   'right_answers': 9},
#  379: {'id': 379,
#   'name': 'Андрей',
#   'patronymic': 'Петрович',
#   'surname': 'Агеев',
#   'questions': 1095,
#   'right_answers': 536},
#  131451: {'id': 131451,
#   'name': 'Нариман',
#   'patronymic': '',
#   'surname': 'Кудусов',
#   'questions': 363,
#   'right_answers': 81},
#  131453: {'id': 131453,
#   'name': 'Ольга',
#   'patronymic': 'Ивановна',
#   'surname': 'Егорчева',
#   'questions': 2288,
#   'right_answers': 985},
#  131454: {'id': 131454,
#   'name': 'Евгений',
#   'patronymic': 'Владимирович',
#   'surname': 'Мачихин',
#   'questions': 4658,
#   'right_answers': 2037},
#  385: {'id': 385,
#   'name': 'Эдуард',
#   'patronymic': 'Игоревич',
#   'surname': 'Агеев',
#   'questions': 185,
#   'right_answers': 86},
#  397: {'id': 397,
#   'name': 'Николай',
#   'patronymic': 'Важаевич',
#   'surname': 'Агладзе',
#   'questions': 628,
#   'right_answers': 305},
#  398: {'id': 398,
#   'name': 'Ильдар',
#   'patronymic': 'Равилевич',
#   'surname': 'Аглиуллин',
#   'questions': 2768,
#   'right_answers': 1456},
#  409: {'id': 409,
#   'name': 'Алла',
#   'patronymic': 'Арменовна',
#   'surname': 'Агулян',
#   'questions': 615,
#   'right_answers': 311},
#  131486: {'id': 131486,
#   'name': 'Дарья',
#   'patronymic': 'Сергеевна',
#   'surname': 'Пилипюк',
#   'questions': 36,
#   'right_answers': 14},
#  415: {'id': 415,
#   'name': 'Дмитрий',
#   'patronymic': 'Алексеевич',
#   'surname': 'Адаменко',
#   'questions': 237,
#   'right_answers': 119},
#  131488: {'id': 131488,
#   'name': 'Александр',
#   'patronymic': 'Михайлович',
#   'surname': 'Тяжлов',
#   'questions': 1834,
#   'right_answers': 561},
#  418: {'id': 418,
#   'name': 'Алексей',
#   'patronymic': 'Юрьевич',
#   'surname': 'Адамов',
#   'questions': 75,
#   'right_answers': 22},
#  419: {'id': 419,
#   'name': 'Илья',
#   'patronymic': 'Николаевич',
#   'surname': 'Адамов',
#   'questions': 1143,
#   'right_answers': 712},
#  437: {'id': 437,
#   'name': 'Маргарита',
#   'patronymic': 'Ринатовна',
#   'surname': 'Адигамова',
#   'questions': 36,
#   'right_answers': 9},
#  441: {'id': 441,
#   'name': 'Эльдар',
#   'patronymic': 'Махмуд оглы',
#   'surname': 'Адильзаде',
#   'questions': 36,
#   'right_answers': 25},
#  445: {'id': 445,
#   'name': 'Арсен',
#   'patronymic': 'Араратович',
#   'surname': 'Адонц',
#   'questions': 135,
#   'right_answers': 61},
#  447: {'id': 447,
#   'name': 'Александр',
#   'patronymic': 'Сергеевич',
#   'surname': 'Андреянычев',
#   'questions': 255,
#   'right_answers': 137},
#  450: {'id': 450,
#   'name': 'Линара',
#   'patronymic': 'Ремзиевна',
#   'surname': 'Адылова',
#   'questions': 72,
#   'right_answers': 10},
#  453: {'id': 453,
#   'name': 'Нилуфар',
#   'patronymic': 'Абдуллаевна',
#   'surname': 'Азамова',
#   'questions': 1232,
#   'right_answers': 481},
#  457: {'id': 457,
#   'name': 'Александр',
#   'patronymic': 'Николаевич',
#   'surname': 'Азарко',
#   'questions': 2061,
#   'right_answers': 1151},
#  474: {'id': 474,
#   'name': 'Карим',
#   'patronymic': 'Рашитович',
#   'surname': 'Азизов',
#   'questions': 2082,
#   'right_answers': 934},
#  475: {'id': 475,
#   'name': 'Джамиля',
#   'patronymic': 'Намик кызы',
#   'surname': 'Азизова',
#   'questions': 1978,
#   'right_answers': 932},
#  208507: {'id': 208507,
#   'name': 'Данила',
#   'patronymic': 'Игоревич',
#   'surname': 'Буркасов',
#   'questions': 216,
#   'right_answers': 11},
#  486: {'id': 486,
#   'name': 'Яна',
#   'patronymic': 'Исаевна',
#   'surname': 'Азриэль',
#   'questions': 1139,
#   'right_answers': 534},
#  487: {'id': 487,
#   'name': 'Игорь',
#   'patronymic': 'Меерович',
#   'surname': 'Аипкин',
#   'questions': 3306,
#   'right_answers': 1913},
#  131558: {'id': 131558,
#   'name': 'Надежда',
#   'patronymic': 'Юрьевна',
#   'surname': 'Кувшинова',
#   'questions': 36,
#   'right_answers': 11},
#  489: {'id': 489,
#   'name': 'Александр',
#   'patronymic': 'Андреевич',
#   'surname': 'Аистов',
#   'questions': 2979,
#   'right_answers': 1681},
#  131562: {'id': 131562,
#   'name': 'Вадим',
#   'patronymic': 'Юрьевич',
#   'surname': 'Стоянов',
#   'questions': 804,
#   'right_answers': 456},
#  131563: {'id': 131563,
#   'name': 'Никита',
#   'patronymic': 'Иванович',
#   'surname': 'Пометов',
#   'questions': 804,
#   'right_answers': 447},
#  131564: {'id': 131564,
#   'name': 'Александра',
#   'patronymic': 'Игоревна',
#   'surname': 'Музыченко',
#   'questions': 372,
#   'right_answers': 192},
#  131565: {'id': 131565,
#   'name': 'Ксения',
#   'patronymic': 'Сергеевна',
#   'surname': 'Харина',
#   'questions': 612,
#   'right_answers': 361},
#  490: {'id': 490,
#   'name': 'Ксения',
#   'patronymic': 'Петровна',
#   'surname': 'Аитова',
#   'questions': 605,
#   'right_answers': 386},
#  131573: {'id': 131573,
#   'name': 'Руслан',
#   'patronymic': 'Якупович',
#   'surname': 'Султыгов',
#   'questions': 108,
#   'right_answers': 26},
#  503: {'id': 503,
#   'name': 'Даниил',
#   'patronymic': 'Олегович',
#   'surname': 'Айзенштейн',
#   'questions': 981,
#   'right_answers': 468},
#  505: {'id': 505,
#   'name': 'Иделия',
#   'patronymic': 'Мукадясовна',
#   'surname': 'Айзятулова',
#   'questions': 2225,
#   'right_answers': 1468},
#  509: {'id': 509,
#   'name': 'Армен',
#   'patronymic': 'Самвелович',
#   'surname': 'Айрапетян',
#   'questions': 471,
#   'right_answers': 137},
#  131587: {'id': 131587,
#   'name': 'Кирилл',
#   'patronymic': 'Владимирович',
#   'surname': 'Ворошилов',
#   'questions': 192,
#   'right_answers': 62},
#  131589: {'id': 131589,
#   'name': 'Павел',
#   'patronymic': '',
#   'surname': 'Тусь',
#   'questions': 144,
#   'right_answers': 81},
#  131590: {'id': 131590,
#   'name': 'Татьяна',
#   'patronymic': '',
#   'surname': 'Бабинец',
#   'questions': 108,
#   'right_answers': 73},
#  131592: {'id': 131592,
#   'name': 'Артём',
#   'patronymic': 'Игоревич',
#   'surname': 'Ерохин',
#   'questions': 759,
#   'right_answers': 389},
#  131594: {'id': 131594,
#   'name': 'Игорь',
#   'patronymic': 'Владимирович',
#   'surname': 'Данилов',
#   'questions': 36,
#   'right_answers': 27},
#  531: {'id': 531,
#   'name': 'Асиф',
#   'patronymic': '',
#   'surname': 'Акберов',
#   'questions': 396,
#   'right_answers': 176},
#  131606: {'id': 131606,
#   'name': 'Полина',
#   'patronymic': 'Викторовна',
#   'surname': 'Ступачук',
#   'questions': 309,
#   'right_answers': 125},
#  535: {'id': 535,
#   'name': 'Алексей',
#   'patronymic': 'Александрович',
#   'surname': 'Акименко',
#   'questions': 729,
#   'right_answers': 418},
#  537: {'id': 537,
#   'name': 'Никита',
#   'patronymic': 'Викторович',
#   'surname': 'Акименко',
#   'questions': 1564,
#   'right_answers': 612},
#  131610: {'id': 131610,
#   'name': 'Мария',
#   'patronymic': 'Сергеевна',
#   'surname': 'Кутасина',
#   'questions': 84,
#   'right_answers': 20},
#  131629: {'id': 131629,
#   'name': 'Ольга',
#   'patronymic': 'Владимировна',
#   'surname': 'Регушевская',
#   'questions': 2805,
#   'right_answers': 1252},
#  131631: {'id': 131631,
#   'name': 'Ольга',
#   'patronymic': 'Борисовна',
#   'surname': 'Беликова',
#   'questions': 1656,
#   'right_answers': 560},
#  131642: {'id': 131642,
#   'name': 'Никита',
#   'patronymic': 'Валерьевич',
#   'surname': 'Гогу',
#   'questions': 324,
#   'right_answers': 112},
#  571: {'id': 571,
#   'name': 'Александр',
#   'patronymic': '',
#   'surname': 'Акопян',
#   'questions': 502,
#   'right_answers': 167},
#  131646: {'id': 131646,
#   'name': 'Гегам',
#   'patronymic': 'Арамаисович',
#   'surname': 'Арутюнян',
#   'questions': 2350,
#   'right_answers': 963},
#  131647: {'id': 131647,
#   'name': 'Елена',
#   'patronymic': 'Сергеевна',
#   'surname': 'Парьева',
#   'questions': 846,
#   'right_answers': 279},
#  576: {'id': 576,
#   'name': 'Грайр',
#   'patronymic': 'Геворгович',
#   'surname': 'Акопян',
#   'questions': 96,
#   'right_answers': 50},
#  131654: {'id': 131654,
#   'name': 'Евгений',
#   'patronymic': 'Михайлович',
#   'surname': 'Фролов',
#   'questions': 36,
#   'right_answers': 4},
#  131655: {'id': 131655,
#   'name': 'Руслан',
#   'patronymic': 'Михайлович',
#   'surname': 'Чалов',
#   'questions': 36,
#   'right_answers': 4},
#  131657: {'id': 131657,
#   'name': 'Дарья',
#   'patronymic': 'Владимировна',
#   'surname': 'Дубова',
#   'questions': 144,
#   'right_answers': 53},
#  131659: {'id': 131659,
#   'name': 'Адиля',
#   'patronymic': 'Тамерлановна',
#   'surname': 'Фаттахова',
#   'questions': 336,
#   'right_answers': 214},
#  591: {'id': 591,
#   'name': 'Мария',
#   'patronymic': '',
#   'surname': 'Аксарина',
#   'questions': 468,
#   'right_answers': 185},
#  599: {'id': 599,
#   'name': 'Андрей',
#   'patronymic': 'Сергеевич',
#   'surname': 'Аксёнов',
#   'questions': 576,
#   'right_answers': 181},
#  602: {'id': 602,
#   'name': 'Игорь',
#   'patronymic': 'Игоревич',
#   'surname': 'Аксёнов',
#   'questions': 548,
#   'right_answers': 206},
#  131674: {'id': 131674,
#   'name': 'Виктория',
#   'patronymic': 'Дмитриевна',
#   'surname': 'Кучерявенко',
#   'questions': 189,
#   'right_answers': 62},
#  131676: {'id': 131676,
#   'name': 'Николай',
#   'patronymic': 'Романович',
#   'surname': 'Амосов',
#   'questions': 225,
#   'right_answers': 69},
#  616: {'id': 616,
#   'name': 'Юлия',
#   'patronymic': 'Феликсовна',
#   'surname': 'Аксенцева',
#   'questions': 36,
#   'right_answers': 22},
#  619: {'id': 619,
#   'name': 'Максим',
#   'patronymic': 'Александрович',
#   'surname': 'Аксюто',
#   'questions': 183,
#   'right_answers': 62},
#  623: {'id': 623,
#   'name': 'Михаил',
#   'patronymic': 'Петрович',
#   'surname': 'Акулич',
#   'questions': 399,
#   'right_answers': 167},
#  131699: {'id': 131699,
#   'name': 'Юрий',
#   'patronymic': '',
#   'surname': 'Боровских',
#   'questions': 813,
#   'right_answers': 270},
#  631: {'id': 631,
#   'name': 'Михаил',
#   'patronymic': 'Ильич',
#   'surname': 'Акушский',
#   'questions': 1553,
#   'right_answers': 771},
#  639: {'id': 639,
#   'name': 'Арутюн',
#   'patronymic': 'Рудикович',
#   'surname': 'Алавердян',
#   'questions': 151,
#   'right_answers': 85},
#  641: {'id': 641,
#   'name': 'Сергей',
#   'patronymic': 'Давидович',
#   'surname': 'Алавердян',
#   'questions': 597,
#   'right_answers': 364},
#  131713: {'id': 131713,
#   'name': 'Елизавета',
#   'patronymic': 'Дмитриевна',
#   'surname': 'Чернова',
#   'questions': 252,
#   'right_answers': 81},
#  643: {'id': 643,
#   'name': 'Артём',
#   'patronymic': 'Анатольевич',
#   'surname': 'Аладин',
#   'questions': 90,
#   'right_answers': 52},
#  644: {'id': 644,
#   'name': 'Данила',
#   'patronymic': 'Юрьевич',
#   'surname': 'Аладин',
#   'questions': 1287,
#   'right_answers': 755},
#  131717: {'id': 131717,
#   'name': 'Александр',
#   'patronymic': 'Сергеевич',
#   'surname': 'Бабаев',
#   'questions': 428,
#   'right_answers': 211},
#  131719: {'id': 131719,
#   'name': 'Денис',
#   'patronymic': 'Андреевич',
#   'surname': 'Фролов',
#   'questions': 519,
#   'right_answers': 197},
#  131720: {'id': 131720,
#   'name': 'Варвара',
#   'patronymic': '',
#   'surname': 'Ульянёнок',
#   'questions': 36,
#   'right_answers': 20},
#  131723: {'id': 131723,
#   'name': 'Олег',
#   'patronymic': 'Вячеславович',
#   'surname': 'Сергеев',
#   'questions': 1774,
#   'right_answers': 952},
#  131727: {'id': 131727,
#   'name': 'Сергей',
#   'patronymic': 'Николаевич',
#   'surname': 'Чавчавадзе',
#   'questions': 5675,
#   'right_answers': 2184},
#  656: {'id': 656,
#   'name': 'Андрей',
#   'patronymic': 'Борисович',
#   'surname': 'Алакозов',
#   'questions': 138,
#   'right_answers': 83},
#  658: {'id': 658,
#   'name': 'Нора',
#   'patronymic': 'Амиковна',
#   'surname': 'Аланакян',
#   'questions': 1191,
#   'right_answers': 705},
#  660: {'id': 660,
#   'name': 'Борис',
#   'patronymic': '',
#   'surname': 'Алапин',
#   'questions': 288,
#   'right_answers': 148},
#  662: {'id': 662,
#   'name': 'Алексей',
#   'patronymic': 'Сергеевич',
#   'surname': 'Алас',
#   'questions': 480,
#   'right_answers': 210},
#  131738: {'id': 131738,
#   'name': 'Михаил',
#   'patronymic': 'Сергеевич',
#   'surname': 'Калмыков',
#   'questions': 267,
#   'right_answers': 125},
#  131739: {'id': 131739,
#   'name': 'Александр',
#   'patronymic': 'Александрович',
#   'surname': 'Шамрай',
#   'questions': 36,
#   'right_answers': 14},
#  668: {'id': 668,
#   'name': 'Татьяна',
#   'patronymic': 'Леонидовна',
#   'surname': 'Алдошина',
#   'questions': 137,
#   'right_answers': 39},
#  670: {'id': 670,
#   'name': 'Наталья',
#   'patronymic': 'Николаевна',
#   'surname': 'Валевская',
#   'questions': 393,
#   'right_answers': 156},
#  680: {'id': 680,
#   'name': 'Алексей',
#   'patronymic': 'Юрьевич',
#   'surname': 'Александров',
#   'questions': 108,
#   'right_answers': 57},
#  131753: {'id': 131753,
#   'name': 'Николай',
#   'patronymic': 'Александрович',
#   'surname': 'Некрасов',
#   'questions': 4282,
#   'right_answers': 1763},
#  131752: {'id': 131752,
#   'name': 'Али',
#   'patronymic': 'Бурханович',
#   'surname': 'Берберов',
#   'questions': 447,
#   'right_answers': 203},
#  683: {'id': 683,
#   'name': 'Антон',
#   'patronymic': 'Вячеславович',
#   'surname': 'Александров',
#   'questions': 1970,
#   'right_answers': 1093},
#  131756: {'id': 131756,
#   'name': 'Екатерина',
#   'patronymic': 'Олеговна',
#   'surname': 'Бревнова',
#   'questions': 36,
#   'right_answers': 6},
#  131759: {'id': 131759,
#   'name': 'Бексултан',
#   'patronymic': 'Мирхатович',
#   'surname': 'Балтабаев',
#   'questions': 1869,
#   'right_answers': 718},
#  131762: {'id': 131762,
#   'name': 'Фаррух',
#   'patronymic': 'Фарходович',
#   'surname': 'Муратов',
#   'questions': 219,
#   'right_answers': 53},
#  691: {'id': 691,
#   'name': 'Дмитрий',
#   'patronymic': 'Сергеевич',
#   'surname': 'Александров',
#   'questions': 432,
#   'right_answers': 155},
#  696: {'id': 696,
#   'name': 'Максим',
#   'patronymic': 'Сергеевич',
#   'surname': 'Александров',
#   'questions': 708,
#   'right_answers': 411},
#  699: {'id': 699,
#   'name': 'Пётр',
#   'patronymic': 'Владимирович',
#   'surname': 'Александров',
#   'questions': 467,
#   'right_answers': 105},
#  707: {'id': 707,
#   'name': 'Елена',
#   'patronymic': 'Андреевна',
#   'surname': 'Александрова',
#   'questions': 48,
#   'right_answers': 27},
#  712: {'id': 712,
#   'name': 'Светлана',
#   'patronymic': 'Львовна',
#   'surname': 'Александрова',
#   'questions': 150,
#   'right_answers': 57},
#  131786: {'id': 131786,
#   'name': 'Георгий',
#   'patronymic': 'Валентинович',
#   'surname': 'Шванов',
#   'questions': 1578,
#   'right_answers': 633},
#  716: {'id': 716,
#   'name': 'Юлия',
#   'patronymic': 'Анатольевна',
#   'surname': 'Александрова',
#   'questions': 318,
#   'right_answers': 65},
#  131790: {'id': 131790,
#   'name': 'Максим',
#   'patronymic': 'Алексеевич',
#   'surname': 'Данилов',
#   'questions': 468,
#   'right_answers': 213},
#  131794: {'id': 131794,
#   'name': 'Александра',
#   'patronymic': 'Андреевна',
#   'surname': 'Бойкова',
#   'questions': 396,
#   'right_answers': 136},
#  726: {'id': 726,
#   'name': 'Алексей',
#   'patronymic': 'Николаевич',
#   'surname': 'Алексапольский',
#   'questions': 228,
#   'right_answers': 83},
#  730: {'id': 730,
#   'name': 'Мария',
#   'patronymic': 'Игоревна',
#   'surname': 'Алексашина',
#   'questions': 90,
#   'right_answers': 25},
#  731: {'id': 731,
#   'name': 'Александр',
#   'patronymic': 'Николаевич',
#   'surname': 'Алексеев',
#   'questions': 630,
#   'right_answers': 215},
#  131807: {'id': 131807,
#   'name': 'Лариса',
#   'patronymic': 'Сергеевна',
#   'surname': 'Бокова',
#   'questions': 36,
#   'right_answers': 12},
#  131810: {'id': 131810,
#   'name': 'Алексей',
#   'patronymic': 'Михайлович',
#   'surname': 'Мякишев',
#   'questions': 387,
#   'right_answers': 192},
#  131811: {'id': 131811,
#   'name': 'Константин',
#   'patronymic': 'Валерьевич',
#   'surname': 'Воинов',
#   'questions': 90,
#   'right_answers': 21},
#  740: {'id': 740,
#   'name': 'Борислав',
#   'patronymic': 'Борисович',
#   'surname': 'Алексеев',
#   'questions': 36,
#   'right_answers': 15},
#  747: {'id': 747,
#   'name': 'Владислав',
#   'patronymic': 'Владимирович',
#   'surname': 'Алексеев',
#   'questions': 1032,
#   'right_answers': 684},
#  131823: {'id': 131823,
#   'name': 'Анна',
#   'patronymic': 'Владимировна',
#   'surname': 'Коршункова',
#   'questions': 1500,
#   'right_answers': 695},
#  131827: {'id': 131827,
#   'name': 'Алексей',
#   'patronymic': 'Олегович',
#   'surname': 'Осинцев',
#   'questions': 621,
#   'right_answers': 211},
#  757: {'id': 757,
#   'name': 'Иван',
#   'patronymic': 'Сергеевич',
#   'surname': 'Алексеев',
#   'questions': 72,
#   'right_answers': 34},
#  131833: {'id': 131833,
#   'name': 'Анна',
#   'patronymic': 'Александровна',
#   'surname': 'Горбунова',
#   'questions': 76,
#   'right_answers': 25},
#  131838: {'id': 131838,
#   'name': 'Денис',
#   'patronymic': 'Васильевич',
#   'surname': 'Кузнецов',
#   'questions': 669,
#   'right_answers': 355},
#  772: {'id': 772,
#   'name': 'Станислав',
#   'patronymic': '',
#   'surname': 'Алексеев',
#   'questions': 324,
#   'right_answers': 169},
#  777: {'id': 777,
#   'name': 'Анастасия',
#   'patronymic': 'Геннадиевна',
#   'surname': 'Алексеева',
#   'questions': 144,
#   'right_answers': 32},
#  131850: {'id': 131850,
#   'name': 'Алексей',
#   'patronymic': 'Анатольевич',
#   'surname': 'Солдатенков',
#   'questions': 90,
#   'right_answers': 58},
#  131852: {'id': 131852,
#   'name': 'Александра',
#   'patronymic': 'Николаевна',
#   'surname': 'Акиншина',
#   'questions': 162,
#   'right_answers': 57},
#  781: {'id': 781,
#   'name': 'Екатерина',
#   'patronymic': 'Виталиевна',
#   'surname': 'Гордиенко',
#   'questions': 232,
#   'right_answers': 112},
#  131857: {'id': 131857,
#   'name': 'Юлия',
#   'patronymic': 'Маратовна',
#   'surname': 'Нигматянова',
#   'questions': 117,
#   'right_answers': 46},
#  131859: {'id': 131859,
#   'name': 'Елизавета',
#   'patronymic': 'Игоревна',
#   'surname': 'Борисова',
#   'questions': 45,
#   'right_answers': 17},
#  789: {'id': 789,
#   'name': 'Татьяна',
#   'patronymic': 'Сергеевна',
#   'surname': 'Алексеева',
#   'questions': 108,
#   'right_answers': 33},
#  131864: {'id': 131864,
#   'name': 'Давид',
#   'patronymic': 'Андреевич',
#   'surname': 'Арутюнов',
#   'questions': 45,
#   'right_answers': 17},
#  131866: {'id': 131866,
#   'name': 'Вероника',
#   'patronymic': 'Сергеевна',
#   'surname': 'Гаврилова',
#   'questions': 738,
#   'right_answers': 335},
#  131867: {'id': 131867,
#   'name': 'Владимир',
#   'patronymic': 'Александрович',
#   'surname': 'Лазуткин',
#   'questions': 45,
#   'right_answers': 17},
#  131869: {'id': 131869,
#   'name': 'Светлана',
#   'patronymic': 'Викторовна',
#   'surname': 'Сурикова',
#   'questions': 966,
#   'right_answers': 495},
#  798: {'id': 798,
#   'name': 'Елена',
#   'patronymic': 'Александровна',
#   'surname': 'Петренко',
#   'questions': 372,
#   'right_answers': 184},
#  797: {'id': 797,
#   'name': 'Екатерина',
#   'patronymic': 'Вячеславовна',
#   'surname': 'Алексеенко',
#   'questions': 36,
#   'right_answers': 20},
#  803: {'id': 803,
#   'name': 'Сергей',
#   'patronymic': 'Николаевич',
#   'surname': 'Алексеенко',
#   'questions': 504,
#   'right_answers': 308},
#  131876: {'id': 131876,
#   'name': 'Владислав',
#   'patronymic': 'Романович',
#   'surname': 'Печников',
#   'questions': 72,
#   'right_answers': 30},
#  131878: {'id': 131878,
#   'name': 'Полина',
#   'patronymic': 'Михайловна',
#   'surname': 'Сироткина',
#   'questions': 36,
#   'right_answers': 18},
#  131879: {'id': 131879,
#   'name': 'Кристина',
#   'patronymic': 'Владимировна',
#   'surname': 'Брачук',
#   'questions': 36,
#   'right_answers': 12},
#  808: {'id': 808,
#   'name': 'Илья',
#   'patronymic': 'Феликсович',
#   'surname': 'Алескер',
#   'questions': 216,
#   'right_answers': 134},
#  131881: {'id': 131881,
#   'name': 'Анастасия',
#   'patronymic': 'Андреевна',
#   'surname': 'Лобкова',
#   'questions': 180,
#   'right_answers': 99},
#  811: {'id': 811,
#   'name': 'Денис',
#   'patronymic': 'Викторович',
#   'surname': 'Аленин',
#   'questions': 312,
#   'right_answers': 167},
#  131886: {'id': 131886,
#   'name': 'Арсений',
#   'patronymic': 'Владимирович',
#   'surname': 'Григорьев',
#   'questions': 201,
#   'right_answers': 101},
#  131887: {'id': 131887,
#   'name': 'Дмитрий',
#   'patronymic': 'Алексеевич',
#   'surname': 'Лебедев',
#   'questions': 45,
#   'right_answers': 17},
#  131890: {'id': 131890,
#   'name': 'Рита',
#   'patronymic': 'Сергеевна',
#   'surname': 'Чемисова',
#   'questions': 36,
#   'right_answers': 19},
#  822: {'id': 822,
#   'name': 'Дмитрий',
#   'patronymic': 'Владимирович',
#   'surname': 'Алёхин',
#   'questions': 561,
#   'right_answers': 298},
#  824: {'id': 824,
#   'name': 'Елена',
#   'patronymic': 'Анатольевна',
#   'surname': 'Алёхина',
#   'questions': 144,
#   'right_answers': 48},
#  131899: {'id': 131899,
#   'name': 'Юлия',
#   'patronymic': '',
#   'surname': 'Бычкова',
#   'questions': 90,
#   'right_answers': 56},
#  131904: {'id': 131904,
#   'name': 'Екатерина',
#   'patronymic': 'Юрьевна',
#   'surname': 'Черкашина',
#   'questions': 473,
#   'right_answers': 321},
#  131905: {'id': 131905,
#   'name': 'Юлия',
#   'patronymic': 'Александровна',
#   'surname': 'Субботина',
#   'questions': 365,
#   'right_answers': 240},
#  131908: {'id': 131908,
#   'name': 'Иван',
#   'patronymic': 'Сергеевич',
#   'surname': 'Киселёв',
#   'questions': 8809,
#   'right_answers': 5167},
#  131909: {'id': 131909,
#   'name': 'Андрей',
#   'patronymic': 'Юрьевич',
#   'surname': 'Андрюшин',
#   'questions': 6626,
#   'right_answers': 3865},
#  131910: {'id': 131910,
#   'name': 'Вячеслав',
#   'patronymic': 'Александрович',
#   'surname': 'Потякин',
#   'questions': 6604,
#   'right_answers': 3853},
#  131911: {'id': 131911,
#   'name': 'Алина',
#   'patronymic': 'Александровна',
#   'surname': 'Ягодова',
#   'questions': 6889,
#   'right_answers': 4073},
#  840: {'id': 840,
#   'name': 'Александр',
#   'patronymic': 'Тофигович',
#   'surname': 'Алиев',
#   'questions': 624,
#   'right_answers': 389},
#  837: {'id': 837,
#   'name': 'Илькин',
#   'patronymic': '',
#   'surname': 'Алибейли',
#   'questions': 345,
#   'right_answers': 78},
#  131914: {'id': 131914,
#   'name': 'Анжела',
#   'patronymic': 'Максимовна',
#   'surname': 'Гельберг',
#   'questions': 81,
#   'right_answers': 40},
#  849: {'id': 849,
#   'name': 'Рашад',
#   'patronymic': 'Джалал оглы',
#   'surname': 'Алиев',
#   'questions': 2681,
#   'right_answers': 1292},
#  131922: {'id': 131922,
#   'name': 'Дмитрий',
#   'patronymic': 'Александрович',
#   'surname': 'Васильев',
#   'questions': 1037,
#   'right_answers': 564},
#  851: {'id': 851,
#   'name': 'Роман',
#   'patronymic': 'Абрамович',
#   'surname': 'Алиев',
#   'questions': 447,
#   'right_answers': 101},
#  131925: {'id': 131925,
#   'name': 'Яна',
#   'patronymic': 'Олеговна',
#   'surname': 'Гробова',
#   'questions': 1414,
#   'right_answers': 528},
#  853: {'id': 853,
#   'name': 'Рухид',
#   'patronymic': 'Ахмед оглы',
#   'surname': 'Алиев',
#   'questions': 582,
#   'right_answers': 251},
#  856: {'id': 856,
#   'name': 'Теймур',
#   'patronymic': 'Эдуардович',
#   'surname': 'Алиев',
#   'questions': 618,
#   'right_answers': 333},
#  860: {'id': 860,
#   'name': 'Эмин',
#   'patronymic': 'Фархад оглы',
#   'surname': 'Алиев',
#   'questions': 1092,
#   'right_answers': 553},
#  131932: {'id': 131932,
#   'name': 'Дмитрий',
#   'patronymic': 'Евгеньевич',
#   'surname': 'Шеповалов',
#   'questions': 648,
#   'right_answers': 329},
#  131934: {'id': 131934,
#   'name': 'Мери',
#   'patronymic': 'Грачевна',
#   'surname': 'Арутюнян',
#   'questions': 2350,
#   'right_answers': 959},
#  131933: {'id': 131933,
#   'name': 'Анастасия',
#   'patronymic': 'Владимировна',
#   'surname': 'Трофимова',
#   'questions': 648,
#   'right_answers': 329},
#  131936: {'id': 131936,
#   'name': 'Владилена',
#   'patronymic': 'Павловна',
#   'surname': 'Коробова',
#   'questions': 36,
#   'right_answers': 25},
#  868: {'id': 868,
#   'name': 'Ульвия',
#   'patronymic': 'Эльдар гызы',
#   'surname': 'Алиева',
#   'questions': 450,
#   'right_answers': 147},
#  869: {'id': 869,
#   'name': 'Элина',
#   'patronymic': '',
#   'surname': 'Алиева',
#   'questions': 36,
#   'right_answers': 10},
#  131945: {'id': 131945,
#   'name': 'Владимир',
#   'patronymic': 'Романович',
#   'surname': 'Широкий',
#   'questions': 36,
#   'right_answers': 13},
#  881: {'id': 881,
#   'name': 'Денис',
#   'patronymic': 'Владимирович',
#   'surname': 'Алимов',
#   'questions': 147,
#   'right_answers': 50},
#  208588: {'id': 208588,
#   'name': 'Денис',
#   'patronymic': 'Павлович',
#   'surname': 'Фёдоров',
#   'questions': 288,
#   'right_answers': 29},
#  885: {'id': 885,
#   'name': 'Станислав',
#   'patronymic': 'Анатольевич',
#   'surname': 'Алимпов',
#   'questions': 1771,
#   'right_answers': 1063},
#  887: {'id': 887,
#   'name': 'Дмитрий',
#   'patronymic': '',
#   'surname': 'Алипченков',
#   'questions': 108,
#   'right_answers': 38},
#  208589: {'id': 208589,
#   'name': 'Юлия',
#   'patronymic': 'Андреевна',
#   'surname': 'Гончарук',
#   'questions': 216,
#   'right_answers': 21},
#  131961: {'id': 131961,
#   'name': 'Ирина',
#   'patronymic': 'Андреевна',
#   'surname': 'Леонтьева',
#   'questions': 1533,
#   'right_answers': 460},
#  208590: {'id': 208590,
#   'name': 'Виктория',
#   'patronymic': 'Юрьевна',
#   'surname': 'Зинченко',
#   'questions': 216,
#   'right_answers': 21},
#  902: {'id': 902,
#   'name': 'Руслан',
#   'patronymic': 'Растямович',
#   'surname': 'Аловердиев',
#   'questions': 849,
#   'right_answers': 494},
#  904: {'id': 904,
#   'name': 'Максим',
#   'patronymic': 'Альбертович',
#   'surname': 'Алонцев',
#   'questions': 3099,
#   'right_answers': 1861},
#  131979: {'id': 131979,
#   'name': 'Руслан',
#   'patronymic': 'Георгиевич',
#   'surname': 'Бимбасов',
#   'questions': 126,
#   'right_answers': 38},
#  131980: {'id': 131980,
#   'name': 'Светлана',
#   'patronymic': 'Львовна',
#   'surname': 'Сундуева',
#   'questions': 2631,
#   'right_answers': 1122},
#  907: {'id': 907,
#   'name': 'Дмитрий',
#   'patronymic': '',
#   'surname': 'Алсаев',
#   'questions': 216,
#   'right_answers': 102},
#  131982: {'id': 131982,
#   'name': 'Яна',
#   'patronymic': '',
#   'surname': 'Пугач',
#   'questions': 153,
#   'right_answers': 76},
#  131991: {'id': 131991,
#   'name': 'Евгений',
#   'patronymic': '',
#   'surname': 'Медяник',
#   'questions': 36,
#   'right_answers': 8},
#  131995: {'id': 131995,
#   'name': 'Дмитрий',
#   'patronymic': 'Николаевич',
#   'surname': 'Антипов',
#   'questions': 852,
#   'right_answers': 521},
#  208596: {'id': 208596,
#   'name': 'Александр',
#   'patronymic': 'Павлович',
#   'surname': 'Шириков',
#   'questions': 252,
#   'right_answers': 55},
#  929: {'id': 929,
#   'name': 'Евгения',
#   'patronymic': 'Андреевна',
#   'surname': 'Чериканова',
#   'questions': 123,
#   'right_answers': 30},
#  932: {'id': 932,
#   'name': 'Григорий',
#   'patronymic': 'Эдуардович',
#   'surname': 'Алхазов',
#   'questions': 1220,
#   'right_answers': 710},
#  132006: {'id': 132006,
#   'name': 'Айвар',
#   'patronymic': 'Римович',
#   'surname': 'Салимов',
#   'questions': 144,
#   'right_answers': 73},
#  935: {'id': 935,
#   'name': 'Ольга',
#   'patronymic': 'Фёдоровна',
#   'surname': 'Алыпова',
#   'questions': 36,
#   'right_answers': 8},
#  132013: {'id': 132013,
#   'name': 'Юрий',
#   'patronymic': 'Иванович',
#   'surname': 'Ломшин',
#   'questions': 72,
#   'right_answers': 14},
#  950: {'id': 950,
#   'name': 'Александр',
#   'patronymic': 'Михайлович',
#   'surname': 'Альтшулер',
#   'questions': 4991,
#   'right_answers': 2822},
#  132023: {'id': 132023,
#   'name': 'Елена',
#   'patronymic': 'Владимировна',
#   'surname': 'Полонская',
#   'questions': 72,
#   'right_answers': 54},
#  958: {'id': 958,
#   'name': 'Анастасия',
#   'patronymic': 'Александровна',
#   'surname': 'Амалина',
#   'questions': 108,
#   'right_answers': 69},
#  208603: {'id': 208603,
#   'name': 'Илья',
#   'patronymic': 'Алексеевич',
#   'surname': 'Брюзгин',
#   'questions': 288,
#   'right_answers': 28},
#  960: {'id': 960,
#   'name': 'Адиль',
#   'patronymic': 'Каиртаевич',
#   'surname': 'Амангельдинов',
#   'questions': 36,
#   'right_answers': 10},
#  132033: {'id': 132033,
#   'name': 'Юлия',
#   'patronymic': 'Юрьевна',
#   'surname': 'Зарецкая',
#   'questions': 156,
#   'right_answers': 80},
#  132034: {'id': 132034,
#   'name': 'Михаил',
#   'patronymic': 'Александрович',
#   'surname': 'Лебедев',
#   'questions': 192,
#   'right_answers': 92},
#  132035: {'id': 132035,
#   'name': 'Олег',
#   'patronymic': 'Леонидович',
#   'surname': 'Богачук',
#   'questions': 192,
#   'right_answers': 92},
#  132036: {'id': 132036,
#   'name': 'Инна',
#   'patronymic': 'Геннадьевна',
#   'surname': 'Калустова',
#   'questions': 252,
#   'right_answers': 105},
#  132037: {'id': 132037,
#   'name': 'Гай',
#   'patronymic': 'Борисович',
#   'surname': 'Калустов',
#   'questions': 252,
#   'right_answers': 93},
#  132040: {'id': 132040,
#   'name': 'Дарья',
#   'patronymic': 'Дмитриевна',
#   'surname': 'Смирнова',
#   'questions': 192,
#   'right_answers': 79},
#  132043: {'id': 132043,
#   'name': 'Анастасия',
#   'patronymic': 'Игоревна',
#   'surname': 'Цыганко',
#   'questions': 36,
#   'right_answers': 16},
#  132044: {'id': 132044,
#   'name': 'Пётр',
#   'patronymic': 'Николаевич',
#   'surname': 'Гришин',
#   'questions': 84,
#   'right_answers': 35},
#  132049: {'id': 132049,
#   'name': 'Валерия',
#   'patronymic': '',
#   'surname': 'Рахматова',
#   'questions': 36,
#   'right_answers': 23},
#  992: {'id': 992,
#   'name': 'Наиля',
#   'patronymic': 'Эльхан гызы',
#   'surname': 'Амирбекова',
#   'questions': 60,
#   'right_answers': 12},
#  1000: {'id': 1000,
#   'name': 'Анна',
#   'patronymic': 'Владимировна',
#   'surname': 'Виниченко',
#   'questions': 556,
#   'right_answers': 327},
#  1001: {'id': 1001,
#   'name': 'Сергей',
#   'patronymic': '',
#   'surname': 'Амлинский',
#   'questions': 1516,
#   'right_answers': 974},
#  132078: {'id': 132078,
#   'name': 'Юлия',
#   'patronymic': 'Валерьевна',
#   'surname': 'Морозова',
#   'questions': 180,
#   'right_answers': 53},
#  1007: {'id': 1007,
#   'name': 'Людмила',
#   'patronymic': 'Львовна',
#   'surname': 'Амстиславская',
#   'questions': 324,
#   'right_answers': 151},
#  132079: {'id': 132079,
#   'name': 'Глеб',
#   'patronymic': 'Олегович',
#   'surname': 'Самбуров',
#   'questions': 72,
#   'right_answers': 12},
#  1019: {'id': 1019,
#   'name': 'Екатерина',
#   'patronymic': 'Сергеевна',
#   'surname': 'Ананьева',
#   'questions': 450,
#   'right_answers': 131},
#  132093: {'id': 132093,
#   'name': 'Марина',
#   'patronymic': 'Анатольевна',
#   'surname': 'Лада',
#   'questions': 40,
#   'right_answers': 23},
#  1022: {'id': 1022,
#   'name': 'Григорий',
#   'patronymic': 'Евгеньевич',
#   'surname': 'Ананьин',
#   'questions': 1614,
#   'right_answers': 830},
#  132095: {'id': 132095,
#   'name': 'Куралбек',
#   'patronymic': 'Саинович',
#   'surname': 'Кармысов',
#   'questions': 1035,
#   'right_answers': 294},
#  1029: {'id': 1029,
#   'name': 'Анатолий',
#   'patronymic': 'Вацлавович',
#   'surname': 'Анацкий',
#   'questions': 36,
#   'right_answers': 14},
#  132101: {'id': 132101,
#   'name': 'Инна',
#   'patronymic': '',
#   'surname': 'Резник',
#   'questions': 72,
#   'right_answers': 49},
#  132105: {'id': 132105,
#   'name': 'Юлия',
#   'patronymic': 'Александровна',
#   'surname': 'Кирпичёва',
#   'questions': 36,
#   'right_answers': 12},
#  1033: {'id': 1033,
#   'name': 'Елена',
#   'patronymic': 'Александровна',
#   'surname': 'Ковалёва',
#   'questions': 2799,
#   'right_answers': 1409},
#  132107: {'id': 132107,
#   'name': 'Илья',
#   'patronymic': 'Александрович',
#   'surname': 'Порошин',
#   'questions': 255,
#   'right_answers': 34},
#  208618: {'id': 208618,
#   'name': 'Софья',
#   'patronymic': 'Александровна',
#   'surname': 'Пивоварова',
#   'questions': 324,
#   'right_answers': 30},
#  132111: {'id': 132111,
#   'name': 'Арман',
#   'patronymic': 'Давидович',
#   'surname': 'Тадевосян',
#   'questions': 84,
#   'right_answers': 22},
#  208619: {'id': 208619,
#   'name': 'Мария',
#   'patronymic': 'Владиславовна',
#   'surname': 'Югай',
#   'questions': 288,
#   'right_answers': 30},
#  1042: {'id': 1042,
#   'name': 'Геннадий',
#   'patronymic': 'Михайлович',
#   'surname': 'Андрачник',
#   'questions': 537,
#   'right_answers': 238},
#  1043: {'id': 1043,
#   'name': 'Алексей',
# ...
#   'name': 'Александр',
#   'patronymic': 'Андреевич',
#   'surname': 'Чубукин',
#   'questions': 1581,
#   'right_answers': 522},
#  133679: {'id': 133679,
#   'name': 'Дарья',
#   'patronymic': 'Андреевна',
#   'surname': 'Толочкина',
#   'questions': 276,
#   'right_answers': 93},
#  2612: {'id': 2612,
#   'name': 'Елена',
#   'patronymic': 'Сергеевна',
#   'surname': 'Басканова',
#   'questions': 48,
#   'right_answers': 19},
#  133684: {'id': 133684,
#   'name': 'Ксения',
#   'patronymic': 'Сергеевна',
#   'surname': 'Ёлчева',
#   'questions': 84,
#   'right_answers': 49},
#  133693: {'id': 133693,
#   'name': 'Артём',
#   'patronymic': 'Игоревич',
#   'surname': 'Бушинский',
#   'questions': 90,
#   'right_answers': 23},
#  133694: {'id': 133694,
#   'name': 'Алексей',
#   'patronymic': 'Алексеевич',
#   'surname': 'Бирюлин',
#   'questions': 90,
#   'right_answers': 23},
#  2623: {'id': 2623,
#   'name': 'Ильдар',
#   'patronymic': 'Фаритович',
#   'surname': 'Басыров',
#   'questions': 333,
#   'right_answers': 123},
#  133696: {'id': 133696,
#   'name': 'Василий',
#   'patronymic': 'Геннадьевич',
#   'surname': 'Кочетков',
#   'questions': 90,
#   'right_answers': 23},
#  133697: {'id': 133697,
#   'name': 'Андрей',
#   'patronymic': 'Юрьевич',
#   'surname': 'Лапонов',
#   'questions': 90,
#   'right_answers': 23},
#  208934: {'id': 208934,
#   'name': 'Илья',
#   'patronymic': 'Дмитриевич',
#   'surname': 'Малеваный',
#   'questions': 36,
#   'right_answers': 13},
#  2628: {'id': 2628,
#   'name': 'Кирилл',
#   'patronymic': 'Геннадьевич',
#   'surname': 'Батайкин',
#   'questions': 183,
#   'right_answers': 39},
#  208937: {'id': 208937,
#   'name': 'Олег',
#   'patronymic': 'Мухтарович',
#   'surname': 'Сархатов',
#   'questions': 72,
#   'right_answers': 8},
#  2642: {'id': 2642,
#   'name': 'Руслан',
#   'patronymic': 'Юсупович',
#   'surname': 'Батдалов',
#   'questions': 1745,
#   'right_answers': 904},
#  2643: {'id': 2643,
#   'name': 'Эльвира',
#   'patronymic': 'Юсуповна',
#   'surname': 'Батдалова',
#   'questions': 1410,
#   'right_answers': 670},
#  208938: {'id': 208938,
#   'name': 'Виктория',
#   'patronymic': 'Алексеевна',
#   'surname': 'Павленко',
#   'questions': 72,
#   'right_answers': 8},
#  133720: {'id': 133720,
#   'name': 'Антон',
#   'patronymic': 'Викторович',
#   'surname': 'Кузнецов',
#   'questions': 36,
#   'right_answers': 26},
#  133724: {'id': 133724,
#   'name': 'Владимир',
#   'patronymic': 'Александрович',
#   'surname': 'Семешов',
#   'questions': 837,
#   'right_answers': 425},
#  133725: {'id': 133725,
#   'name': 'Алексей',
#   'patronymic': 'Викторович',
#   'surname': 'Войтович',
#   'questions': 909,
#   'right_answers': 459},
#  133727: {'id': 133727,
#   'name': 'Станислав',
#   'patronymic': 'Александрович',
#   'surname': 'Невежин',
#   'questions': 510,
#   'right_answers': 256},
#  2659: {'id': 2659,
#   'name': 'Екатерина',
#   'patronymic': 'Александровна',
#   'surname': 'Крюкова',
#   'questions': 1289,
#   'right_answers': 620},
#  133739: {'id': 133739,
#   'name': 'Наталья',
#   'patronymic': 'Юрьевна',
#   'surname': 'Спешилова',
#   'questions': 372,
#   'right_answers': 151},
#  2668: {'id': 2668,
#   'name': 'Людмила',
#   'patronymic': 'Николаевна',
#   'surname': 'Батуева',
#   'questions': 5005,
#   'right_answers': 2348},
#  133745: {'id': 133745,
#   'name': 'Виктор',
#   'patronymic': 'Викторович',
#   'surname': 'Брикс',
#   'questions': 603,
#   'right_answers': 274},
#  2673: {'id': 2673,
#   'name': 'Хаким',
#   'patronymic': 'Шухратович',
#   'surname': 'Батыралиев',
#   'questions': 384,
#   'right_answers': 280},
#  133747: {'id': 133747,
#   'name': 'Павел',
#   'patronymic': 'Хассенович',
#   'surname': 'Абди',
#   'questions': 801,
#   'right_answers': 401},
#  133748: {'id': 133748,
#   'name': 'Татьяна',
#   'patronymic': 'Эдуардовна',
#   'surname': 'Гапеева',
#   'questions': 72,
#   'right_answers': 14},
#  2678: {'id': 2678,
#   'name': 'Алексей',
#   'patronymic': 'Николаевич',
#   'surname': 'Батьков',
#   'questions': 1965,
#   'right_answers': 1046},
#  133757: {'id': 133757,
#   'name': 'Екатерина',
#   'patronymic': 'Александровна',
#   'surname': 'Попова',
#   'questions': 1110,
#   'right_answers': 582},
#  133758: {'id': 133758,
#   'name': 'Александр',
#   'patronymic': 'Валентинович',
#   'surname': 'Меньшиков',
#   'questions': 1218,
#   'right_answers': 572},
#  133765: {'id': 133765,
#   'name': 'Валерий',
#   'patronymic': 'Евгеньевич',
#   'surname': 'Камаев',
#   'questions': 1793,
#   'right_answers': 822},
#  2694: {'id': 2694,
#   'name': 'Игорь',
#   'patronymic': 'Олегович',
#   'surname': 'Бахарев',
#   'questions': 357,
#   'right_answers': 179},
#  2695: {'id': 2695,
#   'name': 'Илья',
#   'patronymic': '',
#   'surname': 'Бахарев',
#   'questions': 75,
#   'right_answers': 22},
#  2697: {'id': 2697,
#   'name': 'Сергей',
#   'patronymic': 'Владимирович',
#   'surname': 'Бахарев',
#   'questions': 924,
#   'right_answers': 152},
#  2698: {'id': 2698,
#   'name': 'Анна',
#   'patronymic': 'Игоревна',
#   'surname': 'Бахарева',
#   'questions': 1880,
#   'right_answers': 1126},
#  2705: {'id': 2705,
#   'name': 'Владимир',
#   'patronymic': 'Павлович',
#   'surname': 'Бахмутов',
#   'questions': 1023,
#   'right_answers': 592},
#  2706: {'id': 2706,
#   'name': 'Иван',
#   'patronymic': 'Павлович',
#   'surname': 'Бахмутов',
#   'questions': 1131,
#   'right_answers': 658},
#  2712: {'id': 2712,
#   'name': 'Давид',
#   'patronymic': '',
#   'surname': 'Бахтадзе',
#   'questions': 72,
#   'right_answers': 39},
#  2717: {'id': 2717,
#   'name': 'Алексей',
#   'patronymic': '',
#   'surname': 'Бахтин',
#   'questions': 108,
#   'right_answers': 45},
#  2719: {'id': 2719,
#   'name': 'Семён',
#   'patronymic': 'Михайлович',
#   'surname': 'Бахтин',
#   'questions': 228,
#   'right_answers': 51},
#  2727: {'id': 2727,
#   'name': 'Давид',
#   'patronymic': '',
#   'surname': 'Бацикадзе',
#   'questions': 72,
#   'right_answers': 29},
#  2735: {'id': 2735,
#   'name': 'Александр',
#   'patronymic': 'Анатольевич',
#   'surname': 'Бачук',
#   'questions': 72,
#   'right_answers': 54},
#  133811: {'id': 133811,
#   'name': 'Матиар',
#   'patronymic': 'Мизанурович',
#   'surname': 'Рахман Хашими',
#   'questions': 1434,
#   'right_answers': 627},
#  133813: {'id': 133813,
#   'name': 'Иван',
#   'patronymic': 'Ильич',
#   'surname': 'Куимов',
#   'questions': 36,
#   'right_answers': 20},
#  2742: {'id': 2742,
#   'name': 'Диана',
#   'patronymic': 'Фанисовна',
#   'surname': 'Хасанова',
#   'questions': 1374,
#   'right_answers': 710},
#  2744: {'id': 2744,
#   'name': 'Александра',
#   'patronymic': 'Сергеевна',
#   'surname': 'Башина',
#   'questions': 336,
#   'right_answers': 124},
#  133822: {'id': 133822,
#   'name': 'Валерий',
#   'patronymic': 'Григорьевич',
#   'surname': 'Слюсаренко',
#   'questions': 798,
#   'right_answers': 374},
#  133823: {'id': 133823,
#   'name': 'Дарья',
#   'patronymic': 'Александровна',
#   'surname': 'Иващенко',
#   'questions': 72,
#   'right_answers': 34},
#  133830: {'id': 133830,
#   'name': 'Артём',
#   'patronymic': 'Вячеславович',
#   'surname': 'Моськин',
#   'questions': 528,
#   'right_answers': 220},
#  2758: {'id': 2758,
#   'name': 'Сергей',
#   'patronymic': 'Иосифович',
#   'surname': 'Башлыкевич',
#   'questions': 1125,
#   'right_answers': 741},
#  2763: {'id': 2763,
#   'name': 'Дмитрий',
#   'patronymic': 'Николаевич',
#   'surname': 'Башук',
#   'questions': 1951,
#   'right_answers': 902},
#  2766: {'id': 2766,
#   'name': 'Ирина',
#   'patronymic': 'Ивановна',
#   'surname': 'Баяндина',
#   'questions': 414,
#   'right_answers': 155},
#  133839: {'id': 133839,
#   'name': 'Игорь',
#   'patronymic': 'Владимирович',
#   'surname': 'Тодоров',
#   'questions': 2858,
#   'right_answers': 1572},
#  133841: {'id': 133841,
#   'name': 'Анна',
#   'patronymic': 'Николаевна',
#   'surname': 'Гловацкая',
#   'questions': 1518,
#   'right_answers': 815},
#  133842: {'id': 133842,
#   'name': 'Ольга',
#   'patronymic': 'Николаевна',
#   'surname': 'Гловацкая',
#   'questions': 2785,
#   'right_answers': 1369},
#  213725: {'id': 213725,
#   'name': 'Игнат',
#   'patronymic': 'Романович',
#   'surname': 'Гребенев',
#   'questions': 36,
#   'right_answers': 2},
#  2785: {'id': 2785,
#   'name': 'Виталий',
#   'patronymic': 'Евгеньевич',
#   'surname': 'Бедарев',
#   'questions': 60,
#   'right_answers': 25},
#  133858: {'id': 133858,
#   'name': 'Иван',
#   'patronymic': 'Георгиевич',
#   'surname': 'Мордвинцев',
#   'questions': 300,
#   'right_answers': 89},
#  133861: {'id': 133861,
#   'name': 'Екатерина',
#   'patronymic': 'Дмитриевна',
#   'surname': 'Сколотнева',
#   'questions': 1752,
#   'right_answers': 922},
#  2791: {'id': 2791,
#   'name': 'Сулхан',
#   'patronymic': '',
#   'surname': 'Бежанидзе',
#   'questions': 228,
#   'right_answers': 36},
#  133864: {'id': 133864,
#   'name': 'Анна',
#   'patronymic': '',
#   'surname': 'Щеглова',
#   'questions': 132,
#   'right_answers': 38},
#  2796: {'id': 2796,
#   'name': 'Александр',
#   'patronymic': 'Дмитриевич',
#   'surname': 'Безбородкин',
#   'questions': 633,
#   'right_answers': 276},
#  2797: {'id': 2797,
#   'name': 'Андрей',
#   'patronymic': 'Александрович',
#   'surname': 'Безбородов',
#   'questions': 551,
#   'right_answers': 351},
#  133876: {'id': 133876,
#   'name': 'Вячеслав',
#   'patronymic': 'Александрович',
#   'surname': 'Горбунов',
#   'questions': 72,
#   'right_answers': 24},
#  133883: {'id': 133883,
#   'name': 'Николай',
#   'patronymic': 'Владимирович',
#   'surname': 'Исаев',
#   'questions': 3709,
#   'right_answers': 1915},
#  133885: {'id': 133885,
#   'name': 'Дмитрий',
#   'patronymic': 'Андреевич',
#   'surname': 'Чугунов',
#   'questions': 36,
#   'right_answers': 17},
#  133888: {'id': 133888,
#   'name': 'Лилия',
#   'patronymic': 'Иосифовна',
#   'surname': 'Шайнберг',
#   'questions': 117,
#   'right_answers': 38},
#  133893: {'id': 133893,
#   'name': 'Мария',
#   'patronymic': 'Алексеевна',
#   'surname': 'Магдиева',
#   'questions': 1173,
#   'right_answers': 536},
#  133894: {'id': 133894,
#   'name': 'Фёдор',
#   'patronymic': 'Сергеевич',
#   'surname': 'Лукин',
#   'questions': 156,
#   'right_answers': 41},
#  2828: {'id': 2828,
#   'name': 'Александр',
#   'patronymic': 'Анатольевич',
#   'surname': 'Безруков',
#   'questions': 228,
#   'right_answers': 153},
#  2829: {'id': 2829,
#   'name': 'Алексей',
#   'patronymic': 'Андреевич',
#   'surname': 'Безруков',
#   'questions': 36,
#   'right_answers': 11},
#  133902: {'id': 133902,
#   'name': 'Дмитрий',
#   'patronymic': 'Юрьевич',
#   'surname': 'Ходырев',
#   'questions': 893,
#   'right_answers': 472},
#  2838: {'id': 2838,
#   'name': 'Дмитрий',
#   'patronymic': 'Алексеевич',
#   'surname': 'Безрученко',
#   'questions': 60,
#   'right_answers': 19},
#  133910: {'id': 133910,
#   'name': 'Владислав',
#   'patronymic': 'Русланович',
#   'surname': 'Петрушкевич',
#   'questions': 72,
#   'right_answers': 37},
#  133916: {'id': 133916,
#   'name': 'Алексей',
#   'patronymic': '',
#   'surname': 'Квасневский',
#   'questions': 36,
#   'right_answers': 14},
#  133917: {'id': 133917,
#   'name': 'Николай',
#   'patronymic': 'Михайлович',
#   'surname': 'Руденко',
#   'questions': 2709,
#   'right_answers': 1284},
#  2851: {'id': 2851,
#   'name': 'Мария',
#   'patronymic': 'Алексеевна',
#   'surname': 'Безчастная',
#   'questions': 1540,
#   'right_answers': 789},
#  2857: {'id': 2857,
#   'name': 'Юлия',
#   'patronymic': 'Феликсовна',
#   'surname': 'Бейнер',
#   'questions': 2896,
#   'right_answers': 1744},
#  2859: {'id': 2859,
#   'name': 'Виталий',
#   'patronymic': '',
#   'surname': 'Бекасов',
#   'questions': 72,
#   'right_answers': 25},
#  2860: {'id': 2860,
#   'name': 'Вера',
#   'patronymic': 'Владимировна',
#   'surname': 'Бекелева',
#   'questions': 161,
#   'right_answers': 73},
#  2861: {'id': 2861,
#   'name': 'Алексей',
#   'patronymic': 'Алексеевич',
#   'surname': 'Бекетов',
#   'questions': 84,
#   'right_answers': 10},
#  133933: {'id': 133933,
#   'name': 'Александра',
#   'patronymic': '',
#   'surname': 'Кочубей',
#   'questions': 531,
#   'right_answers': 364},
#  133936: {'id': 133936,
#   'name': 'Антон',
#   'patronymic': '',
#   'surname': 'Измайлов',
#   'questions': 36,
#   'right_answers': 19},
#  208982: {'id': 208982,
#   'name': 'Анна',
#   'patronymic': 'Альбертовна',
#   'surname': 'Конашкова',
#   'questions': 72,
#   'right_answers': 14},
#  133940: {'id': 133940,
#   'name': 'Дмитрий',
#   'patronymic': '',
#   'surname': 'Соловей',
#   'questions': 45,
#   'right_answers': 10},
#  2870: {'id': 2870,
#   'name': 'Яков',
#   'patronymic': 'Моисеевич',
#   'surname': 'Беккерман',
#   'questions': 729,
#   'right_answers': 312},
#  208983: {'id': 208983,
#   'name': 'Всеволод',
#   'patronymic': 'Романович',
#   'surname': 'Курбатов',
#   'questions': 72,
#   'right_answers': 14},
#  2872: {'id': 2872,
#   'name': 'Катерина',
#   'patronymic': 'Алексеевна',
#   'surname': 'Беклемышева',
#   'questions': 390,
#   'right_answers': 207},
#  2874: {'id': 2874,
#   'name': 'Гияз',
#   'patronymic': 'Эдуардович',
#   'surname': 'Бекмухамедов',
#   'questions': 432,
#   'right_answers': 199},
#  133946: {'id': 133946,
#   'name': 'Татьяна',
#   'patronymic': 'Владимировна',
#   'surname': 'Бойко',
#   'questions': 588,
#   'right_answers': 194},
#  208984: {'id': 208984,
#   'name': 'Алиса',
#   'patronymic': 'Максимовна',
#   'surname': 'Низовцева',
#   'questions': 72,
#   'right_answers': 14},
#  133949: {'id': 133949,
#   'name': 'Ирина',
#   'patronymic': 'Валерьевна',
#   'surname': 'Ровникова',
#   'questions': 36,
#   'right_answers': 22},
#  208985: {'id': 208985,
#   'name': 'Григорий',
#   'patronymic': 'Максимович',
#   'surname': 'Петров',
#   'questions': 72,
#   'right_answers': 14},
#  2885: {'id': 2885,
#   'name': 'Бауржан',
#   'patronymic': 'Нуржанович',
#   'surname': 'Бектемиров',
#   'questions': 1363,
#   'right_answers': 789},
#  2888: {'id': 2888,
#   'name': 'Айдар',
#   'patronymic': 'Маратович',
#   'surname': 'Бекчинтаев',
#   'questions': 549,
#   'right_answers': 308},
#  2890: {'id': 2890,
#   'name': 'Ольга',
#   'patronymic': '',
#   'surname': 'Бекчурина',
#   'questions': 249,
#   'right_answers': 124},
#  2891: {'id': 2891,
#   'name': 'Александр',
#   'patronymic': 'Сергеевич',
#   'surname': 'Бекшаев',
#   'questions': 2714,
#   'right_answers': 1605},
#  133965: {'id': 133965,
#   'name': 'Виктор',
#   'patronymic': 'Александрович',
#   'surname': 'Заец',
#   'questions': 304,
#   'right_answers': 119},
#  133967: {'id': 133967,
#   'name': 'Василий',
#   'patronymic': '',
#   'surname': 'Савицкий',
#   'questions': 36,
#   'right_answers': 18},
#  2898: {'id': 2898,
#   'name': 'Мария',
#   'patronymic': 'Борисовна',
#   'surname': 'Беланкова',
#   'questions': 1344,
#   'right_answers': 591},
#  133972: {'id': 133972,
#   'name': 'Георгий',
#   'patronymic': 'Сергеевич',
#   'surname': 'Останевич',
#   'questions': 612,
#   'right_answers': 301},
#  2902: {'id': 2902,
#   'name': 'Инесса',
#   'patronymic': 'Евгеньевна',
#   'surname': 'Кузнецова',
#   'questions': 1486,
#   'right_answers': 673},
#  2904: {'id': 2904,
#   'name': 'Илья',
#   'patronymic': 'Николаевич',
#   'surname': 'Белевич',
#   'questions': 561,
#   'right_answers': 251},
#  208990: {'id': 208990,
#   'name': 'Олеся',
#   'patronymic': '',
#   'surname': 'Лукарецкая',
#   'questions': 252,
#   'right_answers': 61},
#  2906: {'id': 2906,
#   'name': 'Илья',
#   'patronymic': 'Николаевич',
#   'surname': 'Белейчев',
#   'questions': 432,
#   'right_answers': 230},
#  2907: {'id': 2907,
#   'name': 'Алексей',
#   'patronymic': 'Анатольевич',
#   'surname': 'Беленихин',
#   'questions': 72,
#   'right_answers': 18},
#  2910: {'id': 2910,
#   'name': 'Екатерина',
#   'patronymic': 'Ильинична',
#   'surname': 'Беленко',
#   'questions': 2366,
#   'right_answers': 1490},
#  133982: {'id': 133982,
#   'name': 'Георгий',
#   'patronymic': 'Юрьевич',
#   'surname': 'Калашнов',
#   'questions': 180,
#   'right_answers': 74},
#  133984: {'id': 133984,
#   'name': 'Глеб',
#   'patronymic': 'Николаевич',
#   'surname': 'Путалов',
#   'questions': 504,
#   'right_answers': 200},
#  133985: {'id': 133985,
#   'name': 'Мария',
#   'patronymic': 'Николаевна',
#   'surname': 'Томарёва',
#   'questions': 282,
#   'right_answers': 101},
#  2914: {'id': 2914,
#   'name': 'Леонид',
#   'patronymic': 'Борисович',
#   'surname': 'Беленький',
#   'questions': 1041,
#   'right_answers': 594},
#  133983: {'id': 133983,
#   'name': 'Ирина',
#   'patronymic': 'Николаевна',
#   'surname': 'Филиппова',
#   'questions': 36,
#   'right_answers': 21},
#  208991: {'id': 208991,
#   'name': 'Иван',
#   'patronymic': '',
#   'surname': 'Дроздов',
#   'questions': 252,
#   'right_answers': 61},
#  2917: {'id': 2917,
#   'name': 'Дмитрий',
#   'patronymic': 'Анатольевич',
#   'surname': 'Белицкий',
#   'questions': 789,
#   'right_answers': 308},
#  2920: {'id': 2920,
#   'name': 'Олег',
#   'patronymic': '',
#   'surname': 'Белецкий',
#   'questions': 324,
#   'right_answers': 171},
#  ...}

# %%
df_players_train = pd.DataFrame(res).transpose()
df_players_train
# Out:
#             id      name     patronymic    surname questions right_answers
# 131077  131077    Паруйр     Паруйрович   Аланакян      1537           783
# 131080  131080      Иван   Владимирович     Мешков       598           214
# 131082  131082   Валерия      Андреевна        Кан      4788          2690
# 131083  131083   Валерий     Рафаилович  Аввакумов      1445           839
# 15          15      Олег       Игоревич  Абарников       562           202
# ...        ...       ...            ...        ...       ...           ...
# 208409  208409   Дмитрий  Александрович     Ашуров       288            63
# 131055  131055    Полина       Игоревна   Трощенко        90            11
# 208410  208410     Артём     Дмитриевич  Ворошилов       288            63
# 131061  131061  Владимир     Михайлович    Воронов       561           209
# 131068  131068      Илья      Сергеевич   Кижватов        42            18
#
# [59101 rows x 6 columns]

# %%
def compare_masks(mask1, mask2):
    first_better = 0
    equals = 0
    count = min(len(mask1), len(mask2))
    for i in range(count):
        first_better += mask1[i] > mask2[i]
        equals += mask1[i] == mask2[i]
    return (count, first_better, equals)

# %% [markdown]
# Введем $\gamma_k$ - рейтинги игроков, такие что:
# p(i>j) = $\frac{\gamma_i}{\gamma_i + \theta\gamma_j}$ - вероятность того, что i-ый игрок ответит правильно, а j-ый нет, тогда p(i=j) = 1 - $\frac{\gamma_i}{\gamma_i + \theta\gamma_j} - \frac{\gamma_j}{\gamma_j + \theta\gamma_i}$ - вероятность, что либо оба ответят правильно, либо оба ответят неправильно

# %%
res = {}
for tournament_id in filtered_train:
    teams = filtered_train[tournament_id]
    n_teams = len(teams)
    for idx1 in range(n_teams):
        for idx2 in range(idx1 + 1, n_teams):
            questions, first_better, equals = compare_masks(teams[idx1]['mask'], teams[idx2]['mask'])
            for id1 in teams[idx1]['ids']:
                for id2 in teams[idx2]['ids']:
                    key1 = (id1, id2)
                    key2 = (id2, id1)
                    if key1 in res:
                        res[key1]['count'] += questions
                        res[key1]['i>j'] += first_better
                        res[key1]['i=j'] += equals
                    elif key2 in res:
                        res[key2]['count'] += questions
                        res[key2]['i>j'] += questions - first_better - equals
                        res[key2]['i=j'] += equals
                    else:
                        res[key1] = {'id1': id1, 'id2': id2, 'count': questions, 'i>j': first_better, 'i=j': equals}

res
# Out:
# {(15456, 40840): {'id1': 15456,
#   'id2': 40840,
#   'count': 390,
#   'i>j': 103,
#   'i=j': 262},
#  (15456, 16206): {'id1': 15456,
#   'id2': 16206,
#   'count': 246,
#   'i>j': 65,
#   'i=j': 166},
#  (15456, 1584): {'id1': 15456,
#   'id2': 1584,
#   'count': 327,
#   'i>j': 75,
#   'i=j': 229},
#  (15456, 1585): {'id1': 15456,
#   'id2': 1585,
#   'count': 387,
#   'i>j': 50,
#   'i=j': 277},
#  (15456, 10998): {'id1': 15456,
#   'id2': 10998,
#   'count': 318,
#   'i>j': 77,
#   'i=j': 221},
#  (6212, 40840): {'id1': 6212,
#   'id2': 40840,
#   'count': 687,
#   'i>j': 181,
#   'i=j': 456},
#  (6212, 16206): {'id1': 6212,
#   'id2': 16206,
#   'count': 430,
#   'i>j': 110,
#   'i=j': 286},
#  (6212, 1584): {'id1': 6212,
#   'id2': 1584,
#   'count': 471,
#   'i>j': 124,
#   'i=j': 314},
#  (6212, 1585): {'id1': 6212, 'id2': 1585, 'count': 635, 'i>j': 84, 'i=j': 465},
#  (6212, 10998): {'id1': 6212,
#   'id2': 10998,
#   'count': 543,
#   'i>j': 143,
#   'i=j': 361},
#  (26089, 40840): {'id1': 26089,
#   'id2': 40840,
#   'count': 184,
#   'i>j': 35,
#   'i=j': 135},
#  (26089, 16206): {'id1': 26089,
#   'id2': 16206,
#   'count': 76,
#   'i>j': 11,
#   'i=j': 59},
#  (26089, 1584): {'id1': 26089,
#   'id2': 1584,
#   'count': 112,
#   'i>j': 22,
#   'i=j': 81},
#  (26089, 1585): {'id1': 26089,
#   'id2': 1585,
#   'count': 126,
#   'i>j': 17,
#   'i=j': 92},
#  (26089, 10998): {'id1': 26089,
#   'id2': 10998,
#   'count': 148,
#   'i>j': 29,
#   'i=j': 108},
#  (22799, 40840): {'id1': 22799,
#   'id2': 40840,
#   'count': 507,
#   'i>j': 137,
#   'i=j': 338},
#  (22799, 16206): {'id1': 22799,
#   'id2': 16206,
#   'count': 322,
#   'i>j': 79,
#   'i=j': 220},
#  (22799, 1584): {'id1': 22799,
#   'id2': 1584,
#   'count': 399,
#   'i>j': 105,
#   'i=j': 268},
#  (22799, 1585): {'id1': 22799,
#   'id2': 1585,
#   'count': 341,
#   'i>j': 53,
#   'i=j': 243},
#  (22799, 10998): {'id1': 22799,
#   'id2': 10998,
#   'count': 435,
#   'i>j': 112,
#   'i=j': 295},
#  (18036, 40840): {'id1': 18036,
#   'id2': 40840,
#   'count': 246,
#   'i>j': 65,
#   'i=j': 162},
#  (18036, 16206): {'id1': 18036,
#   'id2': 16206,
#   'count': 174,
#   'i>j': 48,
#   'i=j': 113},
#  (18036, 1584): {'id1': 18036,
#   'id2': 1584,
#   'count': 210,
#   'i>j': 59,
#   'i=j': 135},
#  (18036, 1585): {'id1': 18036,
#   'id2': 1585,
#   'count': 264,
#   'i>j': 43,
#   'i=j': 186},
#  (18036, 10998): {'id1': 18036,
#   'id2': 10998,
#   'count': 210,
#   'i>j': 59,
#   'i=j': 135},
#  (18332, 40840): {'id1': 18332,
#   'id2': 40840,
#   'count': 762,
#   'i>j': 197,
#   'i=j': 505},
#  (18332, 16206): {'id1': 18332,
#   'id2': 16206,
#   'count': 469,
#   'i>j': 118,
#   'i=j': 312},
#  (18332, 1584): {'id1': 18332,
#   'id2': 1584,
#   'count': 399,
#   'i>j': 107,
#   'i=j': 265},
#  (18332, 1585): {'id1': 18332,
#   'id2': 1585,
#   'count': 449,
#   'i>j': 71,
#   'i=j': 317},
#  (18332, 10998): {'id1': 18332,
#   'id2': 10998,
#   'count': 582,
#   'i>j': 151,
#   'i=j': 387},
#  (15456, 31332): {'id1': 15456,
#   'id2': 31332,
#   'count': 108,
#   'i>j': 20,
#   'i=j': 77},
#  (15456, 21060): {'id1': 15456,
#   'id2': 21060,
#   'count': 156,
#   'i>j': 34,
#   'i=j': 111},
#  (15456, 35850): {'id1': 15456,
#   'id2': 35850,
#   'count': 156,
#   'i>j': 34,
#   'i=j': 111},
#  (15456, 10187): {'id1': 15456,
#   'id2': 10187,
#   'count': 72,
#   'i>j': 21,
#   'i=j': 46},
#  (15456, 18168): {'id1': 15456,
#   'id2': 18168,
#   'count': 156,
#   'i>j': 34,
#   'i=j': 111},
#  (15456, 23513): {'id1': 15456,
#   'id2': 23513,
#   'count': 228,
#   'i>j': 57,
#   'i=j': 159},
#  (6212, 31332): {'id1': 6212,
#   'id2': 31332,
#   'count': 180,
#   'i>j': 41,
#   'i=j': 123},
#  (6212, 21060): {'id1': 6212,
#   'id2': 21060,
#   'count': 305,
#   'i>j': 73,
#   'i=j': 213},
#  (6212, 35850): {'id1': 6212,
#   'id2': 35850,
#   'count': 305,
#   'i>j': 73,
#   'i=j': 213},
#  (6212, 10187): {'id1': 6212,
#   'id2': 10187,
#   'count': 144,
#   'i>j': 38,
#   'i=j': 98},
#  (6212, 18168): {'id1': 6212,
#   'id2': 18168,
#   'count': 305,
#   'i>j': 73,
#   'i=j': 213},
#  (6212, 23513): {'id1': 6212,
#   'id2': 23513,
#   'count': 518,
#   'i>j': 130,
#   'i=j': 349},
#  (26089, 31332): {'id1': 26089,
#   'id2': 31332,
#   'count': 72,
#   'i>j': 14,
#   'i=j': 51},
#  (26089, 21060): {'id1': 26089,
#   'id2': 21060,
#   'count': 108,
#   'i>j': 21,
#   'i=j': 79},
#  (26089, 35850): {'id1': 26089,
#   'id2': 35850,
#   'count': 108,
#   'i>j': 21,
#   'i=j': 79},
#  (26089, 10187): {'id1': 26089,
#   'id2': 10187,
#   'count': 72,
#   'i>j': 14,
#   'i=j': 53},
#  (26089, 18168): {'id1': 26089,
#   'id2': 18168,
#   'count': 108,
#   'i>j': 21,
#   'i=j': 79},
#  (26089, 23513): {'id1': 26089,
#   'id2': 23513,
#   'count': 108,
#   'i>j': 21,
#   'i=j': 79},
#  (22799, 31332): {'id1': 22799,
#   'id2': 31332,
#   'count': 144,
#   'i>j': 30,
#   'i=j': 101},
#  (22799, 21060): {'id1': 22799,
#   'id2': 21060,
#   'count': 269,
#   'i>j': 62,
#   'i=j': 191},
#  (22799, 35850): {'id1': 22799,
#   'id2': 35850,
#   'count': 269,
#   'i>j': 62,
#   'i=j': 191},
#  (22799, 10187): {'id1': 22799,
#   'id2': 10187,
#   'count': 144,
#   'i>j': 35,
#   'i=j': 100},
#  (22799, 18168): {'id1': 22799,
#   'id2': 18168,
#   'count': 269,
#   'i>j': 62,
#   'i=j': 191},
#  (22799, 23513): {'id1': 22799,
#   'id2': 23513,
#   'count': 341,
#   'i>j': 85,
#   'i=j': 239},
#  (18036, 31332): {'id1': 18036,
#   'id2': 31332,
#   'count': 108,
#   'i>j': 20,
#   'i=j': 77},
#  (18036, 21060): {'id1': 18036,
#   'id2': 21060,
#   'count': 192,
#   'i>j': 41,
#   'i=j': 139},
#  (18036, 35850): {'id1': 18036,
#   'id2': 35850,
#   'count': 192,
#   'i>j': 41,
#   'i=j': 139},
#  (18036, 10187): {'id1': 18036,
#   'id2': 10187,
#   'count': 72,
#   'i>j': 14,
#   'i=j': 53},
#  (18036, 18168): {'id1': 18036,
#   'id2': 18168,
#   'count': 192,
#   'i>j': 41,
#   'i=j': 139},
#  (18036, 23513): {'id1': 18036,
#   'id2': 23513,
#   'count': 192,
#   'i>j': 41,
#   'i=j': 139},
#  (18332, 31332): {'id1': 18332,
#   'id2': 31332,
#   'count': 216,
#   'i>j': 50,
#   'i=j': 151},
#  (18332, 21060): {'id1': 18332,
#   'id2': 21060,
#   'count': 341,
#   'i>j': 82,
#   'i=j': 241},
#  (18332, 35850): {'id1': 18332,
#   'id2': 35850,
#   'count': 341,
#   'i>j': 82,
#   'i=j': 241},
#  (18332, 10187): {'id1': 18332,
#   'id2': 10187,
#   'count': 216,
#   'i>j': 57,
#   'i=j': 149},
#  (18332, 18168): {'id1': 18332,
#   'id2': 18168,
#   'count': 341,
#   'i>j': 82,
#   'i=j': 241},
#  (18332, 23513): {'id1': 18332,
#   'id2': 23513,
#   'count': 449,
#   'i>j': 113,
#   'i=j': 313},
#  (15456, 36742): {'id1': 15456,
#   'id2': 36742,
#   'count': 120,
#   'i>j': 31,
#   'i=j': 72},
#  (15456, 28939): {'id1': 15456,
#   'id2': 28939,
#   'count': 36,
#   'i>j': 7,
#   'i=j': 25},
#  (15456, 27375): {'id1': 15456,
#   'id2': 27375,
#   'count': 180,
#   'i>j': 48,
#   'i=j': 116},
#  (15456, 54289): {'id1': 15456,
#   'id2': 54289,
#   'count': 228,
#   'i>j': 66,
#   'i=j': 136},
#  (15456, 15381): {'id1': 15456,
#   'id2': 15381,
#   'count': 180,
#   'i>j': 48,
#   'i=j': 116},
#  (6212, 36742): {'id1': 6212,
#   'id2': 36742,
#   'count': 228,
#   'i>j': 71,
#   'i=j': 137},
#  (6212, 28939): {'id1': 6212, 'id2': 28939, 'count': 72, 'i>j': 18, 'i=j': 47},
#  (6212, 27375): {'id1': 6212,
#   'id2': 27375,
#   'count': 360,
#   'i>j': 106,
#   'i=j': 229},
#  (6212, 54289): {'id1': 6212,
#   'id2': 54289,
#   'count': 300,
#   'i>j': 98,
#   'i=j': 180},
#  (6212, 15381): {'id1': 6212,
#   'id2': 15381,
#   'count': 396,
#   'i>j': 115,
#   'i=j': 250},
#  (26089, 36742): {'id1': 26089,
#   'id2': 36742,
#   'count': 36,
#   'i>j': 7,
#   'i=j': 25},
#  (26089, 28939): {'id1': 26089,
#   'id2': 28939,
#   'count': 36,
#   'i>j': 7,
#   'i=j': 25},
#  (26089, 27375): {'id1': 26089,
#   'id2': 27375,
#   'count': 72,
#   'i>j': 23,
#   'i=j': 40},
#  (26089, 54289): {'id1': 26089,
#   'id2': 54289,
#   'count': 36,
#   'i>j': 7,
#   'i=j': 25},
#  (26089, 15381): {'id1': 26089,
#   'id2': 15381,
#   'count': 72,
#   'i>j': 23,
#   'i=j': 40},
#  (22799, 36742): {'id1': 22799,
#   'id2': 36742,
#   'count': 180,
#   'i>j': 49,
#   'i=j': 113},
#  (22799, 28939): {'id1': 22799,
#   'id2': 28939,
#   'count': 36,
#   'i>j': 7,
#   'i=j': 25},
#  (22799, 27375): {'id1': 22799,
#   'id2': 27375,
#   'count': 144,
#   'i>j': 46,
#   'i=j': 88},
#  (22799, 54289): {'id1': 22799,
#   'id2': 54289,
#   'count': 252,
#   'i>j': 73,
#   'i=j': 158},
#  (22799, 15381): {'id1': 22799,
#   'id2': 15381,
#   'count': 144,
#   'i>j': 46,
#   'i=j': 88},
#  (18036, 36742): {'id1': 18036,
#   'id2': 36742,
#   'count': 180,
#   'i>j': 49,
#   'i=j': 113},
#  (18036, 28939): {'id1': 18036,
#   'id2': 28939,
#   'count': 72,
#   'i>j': 17,
#   'i=j': 48},
#  (18036, 27375): {'id1': 18036,
#   'id2': 27375,
#   'count': 72,
#   'i>j': 14,
#   'i=j': 54},
#  (18036, 54289): {'id1': 18036,
#   'id2': 54289,
#   'count': 252,
#   'i>j': 74,
#   'i=j': 157},
#  (18036, 15381): {'id1': 18036,
#   'id2': 15381,
#   'count': 72,
#   'i>j': 14,
#   'i=j': 54},
#  (18332, 36742): {'id1': 18332,
#   'id2': 36742,
#   'count': 288,
#   'i>j': 90,
#   'i=j': 169},
#  (18332, 28939): {'id1': 18332,
#   'id2': 28939,
#   'count': 108,
#   'i>j': 25,
#   'i=j': 74},
#  (18332, 27375): {'id1': 18332,
#   'id2': 27375,
#   'count': 288,
#   'i>j': 94,
#   'i=j': 166},
#  (18332, 54289): {'id1': 18332,
#   'id2': 54289,
#   'count': 396,
#   'i>j': 122,
#   'i=j': 240},
#  (18332, 15381): {'id1': 18332,
#   'id2': 15381,
#   'count': 288,
#   'i>j': 94,
#   'i=j': 166},
#  (15456, 69476): {'id1': 15456,
#   'id2': 69476,
#   'count': 216,
#   'i>j': 43,
#   'i=j': 144},
#  (15456, 30597): {'id1': 15456,
#   'id2': 30597,
#   'count': 348,
#   'i>j': 82,
#   'i=j': 233},
#  (15456, 26988): {'id1': 15456,
#   'id2': 26988,
#   'count': 336,
#   'i>j': 81,
#   'i=j': 220},
#  (15456, 28689): {'id1': 15456,
#   'id2': 28689,
#   'count': 471,
#   'i>j': 70,
#   'i=j': 327},
#  (15456, 17720): {'id1': 15456,
#   'id2': 17720,
#   'count': 366,
#   'i>j': 112,
#   'i=j': 219},
#  (6212, 69476): {'id1': 6212,
#   'id2': 69476,
#   'count': 396,
#   'i>j': 80,
#   'i=j': 268},
#  (6212, 30597): {'id1': 6212,
#   'id2': 30597,
#   'count': 528,
#   'i>j': 124,
#   'i=j': 353},
#  (6212, 26988): {'id1': 6212,
#   'id2': 26988,
#   'count': 552,
#   'i>j': 122,
#   'i=j': 372},
#  (6212, 28689): {'id1': 6212,
#   'id2': 28689,
#   'count': 857,
#   'i>j': 135,
#   'i=j': 620},
#  (6212, 17720): {'id1': 6212,
#   'id2': 17720,
#   'count': 546,
#   'i>j': 153,
#   'i=j': 342},
#  (26089, 69476): {'id1': 26089,
#   'id2': 69476,
#   'count': 144,
#   'i>j': 34,
#   'i=j': 97},
#  (26089, 30597): {'id1': 26089,
#   'id2': 30597,
#   'count': 144,
#   'i>j': 29,
#   'i=j': 104},
#  (26089, 26988): {'id1': 26089,
#   'id2': 26988,
#   'count': 180,
#   'i>j': 38,
#   'i=j': 126},
#  (26089, 28689): {'id1': 26089,
#   'id2': 28689,
#   'count': 228,
#   'i>j': 42,
#   'i=j': 160},
#  (26089, 17720): {'id1': 26089,
#   'id2': 17720,
#   'count': 36,
#   'i>j': 8,
#   'i=j': 23},
#  (22799, 69476): {'id1': 22799,
#   'id2': 69476,
#   'count': 216,
#   'i>j': 48,
#   'i=j': 146},
#  (22799, 30597): {'id1': 22799,
#   'id2': 30597,
#   'count': 312,
#   'i>j': 75,
#   'i=j': 214},
#  (22799, 26988): {'id1': 22799,
#   'id2': 26988,
#   'count': 336,
#   'i>j': 78,
#   'i=j': 227},
#  (22799, 28689): {'id1': 22799,
#   'id2': 28689,
#   'count': 563,
#   'i>j': 92,
#   'i=j': 400},
#  (22799, 17720): {'id1': 22799,
#   'id2': 17720,
#   'count': 366,
#   'i>j': 111,
#   'i=j': 221},
#  (18036, 69476): {'id1': 18036,
#   'id2': 69476,
#   'count': 108,
#   'i>j': 25,
#   'i=j': 75},
#  (18036, 30597): {'id1': 18036,
#   'id2': 30597,
#   'count': 240,
#   'i>j': 70,
#   'i=j': 158},
#  (18036, 26988): {'id1': 18036,
#   'id2': 26988,
#   'count': 228,
#   'i>j': 64,
#   'i=j': 149},
#  (18036, 28689): {'id1': 18036,
#   'id2': 28689,
#   'count': 414,
#   'i>j': 76,
#   'i=j': 285},
#  (18036, 17720): {'id1': 18036,
#   'id2': 17720,
#   'count': 330,
#   'i>j': 97,
#   'i=j': 199},
#  (18332, 69476): {'id1': 18332,
#   'id2': 69476,
#   'count': 396,
#   'i>j': 91,
#   'i=j': 259},
#  (18332, 30597): {'id1': 18332,
#   'id2': 30597,
#   'count': 696,
#   'i>j': 157,
#   'i=j': 475},
#  (18332, 26988): {'id1': 18332,
#   'id2': 26988,
#   'count': 516,
#   'i>j': 127,
#   'i=j': 337},
#  (18332, 28689): {'id1': 18332,
#   'id2': 28689,
#   'count': 806,
#   'i>j': 127,
#   'i=j': 578},
#  (18332, 17720): {'id1': 18332,
#   'id2': 17720,
#   'count': 438,
#   'i>j': 132,
#   'i=j': 268},
#  (15456, 56000): {'id1': 15456,
#   'id2': 56000,
#   'count': 720,
#   'i>j': 105,
#   'i=j': 515},
#  (15456, 97091): {'id1': 15456,
#   'id2': 97091,
#   'count': 603,
#   'i>j': 140,
#   'i=j': 407},
#  (15456, 5990): {'id1': 15456,
#   'id2': 5990,
#   'count': 723,
#   'i>j': 111,
#   'i=j': 540},
#  (15456, 86833): {'id1': 15456,
#   'id2': 86833,
#   'count': 165,
#   'i>j': 43,
#   'i=j': 111},
#  (15456, 38458): {'id1': 15456,
#   'id2': 38458,
#   'count': 831,
#   'i>j': 141,
#   'i=j': 604},
#  (6212, 56000): {'id1': 6212,
#   'id2': 56000,
#   'count': 809,
#   'i>j': 154,
#   'i=j': 578},
#  (6212, 97091): {'id1': 6212,
#   'id2': 97091,
#   'count': 1053,
#   'i>j': 262,
#   'i=j': 697},
#  (6212, 5990): {'id1': 6212,
#   'id2': 5990,
#   'count': 1032,
#   'i>j': 172,
#   'i=j': 763},
#  (6212, 86833): {'id1': 6212,
#   'id2': 86833,
#   'count': 201,
#   'i>j': 52,
#   'i=j': 135},
#  (6212, 38458): {'id1': 6212,
#   'id2': 38458,
#   'count': 1212,
#   'i>j': 208,
#   'i=j': 875},
#  (26089, 56000): {'id1': 26089,
#   'id2': 56000,
#   'count': 189,
#   'i>j': 31,
#   'i=j': 144},
#  (26089, 97091): {'id1': 26089,
#   'id2': 97091,
#   'count': 193,
#   'i>j': 38,
#   'i=j': 142},
#  (26089, 5990): {'id1': 26089,
#   'id2': 5990,
#   'count': 304,
#   'i>j': 56,
#   'i=j': 225},
#  (26089, 86833): {'id1': 26089,
#   'id2': 86833,
#   'count': 81,
#   'i>j': 11,
#   'i=j': 64},
#  (26089, 38458): {'id1': 26089,
#   'id2': 38458,
#   'count': 304,
#   'i>j': 56,
#   'i=j': 225},
#  (22799, 56000): {'id1': 22799,
#   'id2': 56000,
#   'count': 512,
#   'i>j': 107,
#   'i=j': 357},
#  (22799, 97091): {'id1': 22799,
#   'id2': 97091,
#   'count': 660,
#   'i>j': 162,
#   'i=j': 438},
#  (22799, 5990): {'id1': 22799,
#   'id2': 5990,
#   'count': 771,
#   'i>j': 133,
#   'i=j': 565},
#  (22799, 86833): {'id1': 22799,
#   'id2': 86833,
#   'count': 165,
#   'i>j': 43,
#   'i=j': 111},
#  (22799, 38458): {'id1': 22799,
#   'id2': 38458,
#   'count': 879,
#   'i>j': 161,
#   'i=j': 629},
#  (18036, 56000): {'id1': 18036,
#   'id2': 56000,
#   'count': 363,
#   'i>j': 69,
#   'i=j': 261},
#  (18036, 97091): {'id1': 18036,
#   'id2': 97091,
#   'count': 327,
#   'i>j': 86,
#   'i=j': 214},
#  (18036, 5990): {'id1': 18036,
#   'id2': 5990,
#   'count': 546,
#   'i>j': 101,
#   'i=j': 398},
#  (18036, 86833): {'id1': 18036,
#   'id2': 86833,
#   'count': 129,
#   'i>j': 26,
#   'i=j': 93},
#  (18036, 38458): {'id1': 18036,
#   'id2': 38458,
#   'count': 582,
#   'i>j': 114,
#   'i=j': 415},
#  (18332, 56000): {'id1': 18332,
#   'id2': 56000,
#   'count': 728,
#   'i>j': 139,
#   'i=j': 516},
#  (18332, 97091): {'id1': 18332,
#   'id2': 97091,
#   'count': 948,
#   'i>j': 237,
#   'i=j': 642},
#  (18332, 5990): {'id1': 18332,
#   'id2': 5990,
#   'count': 1095,
#   'i>j': 181,
#   'i=j': 827},
#  (18332, 86833): {'id1': 18332,
#   'id2': 86833,
#   'count': 237,
#   'i>j': 64,
#   'i=j': 159},
#  (18332, 38458): {'id1': 18332,
#   'id2': 38458,
#   'count': 1203,
#   'i>j': 210,
#   'i=j': 890},
#  (15456, 116327): {'id1': 15456,
#   'id2': 116327,
#   'count': 261,
#   'i>j': 57,
#   'i=j': 175},
#  (15456, 489): {'id1': 15456,
#   'id2': 489,
#   'count': 453,
#   'i>j': 104,
#   'i=j': 310},
#  (15456, 116331): {'id1': 15456,
#   'id2': 116331,
#   'count': 706,
#   'i>j': 189,
#   'i=j': 455},
#  (15456, 1370): {'id1': 15456,
#   'id2': 1370,
#   'count': 714,
#   'i>j': 167,
#   'i=j': 475},
#  (15456, 62299): {'id1': 15456,
#   'id2': 62299,
#   'count': 306,
#   'i>j': 55,
#   'i=j': 214},
#  (15456, 129182): {'id1': 15456,
#   'id2': 129182,
#   'count': 420,
#   'i>j': 114,
#   'i=j': 285},
#  (6212, 116327): {'id1': 6212,
#   'id2': 116327,
#   'count': 237,
#   'i>j': 57,
#   'i=j': 162},
#  (6212, 489): {'id1': 6212, 'id2': 489, 'count': 762, 'i>j': 190, 'i=j': 508},
#  (6212, 116331): {'id1': 6212,
#   'id2': 116331,
#   'count': 826,
#   'i>j': 241,
#   'i=j': 534},
#  (6212, 1370): {'id1': 6212,
#   'id2': 1370,
#   'count': 1014,
#   'i>j': 263,
#   'i=j': 671},
#  (6212, 62299): {'id1': 6212,
#   'id2': 62299,
#   'count': 486,
#   'i>j': 105,
#   'i=j': 330},
#  (6212, 129182): {'id1': 6212,
#   'id2': 129182,
#   'count': 681,
#   'i>j': 193,
#   'i=j': 443},
#  (26089, 116327): {'id1': 26089,
#   'id2': 116327,
#   'count': 72,
#   'i>j': 18,
#   'i=j': 47},
#  (26089, 489): {'id1': 26089, 'id2': 489, 'count': 229, 'i>j': 44, 'i=j': 162},
#  (26089, 116331): {'id1': 26089,
#   'id2': 116331,
#   'count': 189,
#   'i>j': 49,
#   'i=j': 129},
#  (26089, 1370): {'id1': 26089,
#   'id2': 1370,
#   'count': 301,
#   'i>j': 60,
#   'i=j': 214},
#  (26089, 62299): {'id1': 26089,
#   'id2': 62299,
#   'count': 193,
#   'i>j': 32,
#   'i=j': 139},
#  (26089, 129182): {'id1': 26089,
#   'id2': 129182,
#   'count': 148,
#   'i>j': 37,
#   'i=j': 96},
#  (22799, 116327): {'id1': 22799,
#   'id2': 116327,
#   'count': 156,
#   'i>j': 42,
#   'i=j': 103},
#  (22799, 489): {'id1': 22799,
#   'id2': 489,
#   'count': 546,
#   'i>j': 135,
#   'i=j': 368},
#  (22799, 116331): {'id1': 22799,
#   'id2': 116331,
#   'count': 561,
#   'i>j': 162,
#   'i=j': 366},
#  (22799, 1370): {'id1': 22799,
#   'id2': 1370,
#   'count': 726,
#   'i>j': 179,
#   'i=j': 488},
#  (22799, 62299): {'id1': 22799,
#   'id2': 62299,
#   'count': 342,
#   'i>j': 72,
#   'i=j': 241},
#  (22799, 129182): {'id1': 22799,
#   'id2': 129182,
#   'count': 537,
#   'i>j': 150,
#   'i=j': 352},
#  (18036, 116327): {'id1': 18036,
#   'id2': 116327,
#   'count': 120,
#   'i>j': 29,
#   'i=j': 83},
#  (18036, 489): {'id1': 18036, 'id2': 489, 'count': 321, 'i>j': 83, 'i=j': 213},
#  (18036, 116331): {'id1': 18036,
#   'id2': 116331,
#   'count': 417,
#   'i>j': 116,
#   'i=j': 271},
#  (18036, 1370): {'id1': 18036,
#   'id2': 1370,
#   'count': 465,
#   'i>j': 122,
#   'i=j': 312},
#  (18036, 62299): {'id1': 18036,
#   'id2': 62299,
#   'count': 117,
#   'i>j': 21,
#   'i=j': 83},
#  (18036, 129182): {'id1': 18036,
#   'id2': 129182,
#   'count': 240,
#   'i>j': 69,
#   'i=j': 155},
#  (18332, 116327): {'id1': 18332,
#   'id2': 116327,
#   'count': 231,
#   'i>j': 64,
#   'i=j': 148},
#  (18332, 489): {'id1': 18332,
#   'id2': 489,
#   'count': 873,
#   'i>j': 213,
#   'i=j': 594},
#  (18332, 116331): {'id1': 18332,
#   'id2': 116331,
#   'count': 888,
#   'i>j': 273,
#   'i=j': 568},
#  (18332, 1370): {'id1': 18332,
#   'id2': 1370,
#   'count': 1158,
#   'i>j': 310,
#   'i=j': 768},
#  (18332, 62299): {'id1': 18332,
#   'id2': 62299,
#   'count': 522,
#   'i>j': 120,
#   'i=j': 363},
#  (18332, 129182): {'id1': 18332,
#   'id2': 129182,
#   'count': 864,
#   'i>j': 240,
#   'i=j': 563},
#  (15456, 72160): {'id1': 15456,
#   'id2': 72160,
#   'count': 786,
#   'i>j': 158,
#   'i=j': 514},
#  (15456, 113703): {'id1': 15456,
#   'id2': 113703,
#   'count': 757,
#   'i>j': 155,
#   'i=j': 516},
#  (15456, 128239): {'id1': 15456,
#   'id2': 128239,
#   'count': 498,
#   'i>j': 114,
#   'i=j': 326},
#  (15456, 72501): {'id1': 15456,
#   'id2': 72501,
#   'count': 117,
#   'i>j': 25,
#   'i=j': 80},
#  (15456, 505): {'id1': 15456,
#   'id2': 505,
#   'count': 618,
#   'i>j': 117,
#   'i=j': 409},
#  (15456, 70750): {'id1': 15456,
#   'id2': 70750,
#   'count': 426,
#   'i>j': 88,
#   'i=j': 296},
#  (6212, 72160): {'id1': 6212,
#   'id2': 72160,
#   'count': 1166,
#   'i>j': 233,
#   'i=j': 806},
#  (6212, 113703): {'id1': 6212,
#   'id2': 113703,
#   'count': 865,
#   'i>j': 182,
#   'i=j': 607},
#  (6212, 128239): {'id1': 6212,
#   'id2': 128239,
#   'count': 926,
#   'i>j': 201,
#   'i=j': 643},
#  (6212, 72501): {'id1': 6212,
#   'id2': 72501,
#   'count': 153,
#   'i>j': 36,
#   'i=j': 105},
#  (6212, 505): {'id1': 6212, 'id2': 505, 'count': 695, 'i>j': 142, 'i=j': 474},
#  (6212, 70750): {'id1': 6212,
#   'id2': 70750,
#   'count': 669,
#   'i>j': 122,
#   'i=j': 474},
#  (26089, 72160): {'id1': 26089,
#   'id2': 72160,
#   'count': 255,
#   'i>j': 66,
#   'i=j': 166},
#  (26089, 113703): {'id1': 26089,
#   'id2': 113703,
#   'count': 193,
#   'i>j': 29,
#   'i=j': 146},
#  (26089, 128239): {'id1': 26089,
#   'id2': 128239,
#   'count': 183,
#   'i>j': 37,
#   'i=j': 130},
#  (26089, 72501): {'id1': 26089,
#   'id2': 72501,
#   'count': 72,
#   'i>j': 17,
#   'i=j': 50},
#  (26089, 505): {'id1': 26089, 'id2': 505, 'count': 171, 'i>j': 38, 'i=j': 117},
#  (26089, 70750): {'id1': 26089,
#   'id2': 70750,
#   'count': 138,
#   'i>j': 22,
#   'i=j': 99},
#  (22799, 72160): {'id1': 22799,
#   'id2': 72160,
#   'count': 794,
#   'i>j': 176,
#   'i=j': 529},
#  (22799, 113703): {'id1': 22799,
#   'id2': 113703,
#   'count': 636,
#   'i>j': 138,
#   'i=j': 439},
#  (22799, 128239): {'id1': 22799,
#   'id2': 128239,
#   'count': 566,
#   'i>j': 135,
#   'i=j': 371},
#  (22799, 72501): {'id1': 22799,
#   'id2': 72501,
#   'count': 72,
#   'i>j': 17,
#   'i=j': 50},
#  (22799, 505): {'id1': 22799,
#   'id2': 505,
#   'count': 638,
#   'i>j': 122,
#   'i=j': 441},
#  (22799, 70750): {'id1': 22799,
#   'id2': 70750,
#   'count': 384,
#   'i>j': 78,
#   'i=j': 258},
#  (18036, 72160): {'id1': 18036,
#   'id2': 72160,
#   'count': 501,
#   'i>j': 104,
#   'i=j': 331},
#  (18036, 113703): {'id1': 18036,
#   'id2': 113703,
#   'count': 339,
#   'i>j': 72,
#   'i=j': 236},
#  (18036, 128239): {'id1': 18036,
#   'id2': 128239,
#   'count': 345,
#   'i>j': 89,
#   'i=j': 216},
#  (18036, 72501): {'id1': 18036,
#   'id2': 72501,
#   'count': 36,
#   'i>j': 6,
#   'i=j': 27},
#  (18036, 505): {'id1': 18036,
#   'id2': 505,
#   'count': 525,
#   'i>j': 106,
#   'i=j': 357},
#  (18036, 70750): {'id1': 18036,
#   'id2': 70750,
#   'count': 276,
#   'i>j': 67,
#   'i=j': 182},
#  (18332, 72160): {'id1': 18332,
#   'id2': 72160,
#   'count': 866,
#   'i>j': 192,
#   'i=j': 578},
#  (18332, 113703): {'id1': 18332,
#   'id2': 113703,
#   'count': 888,
#   'i>j': 207,
#   'i=j': 590},
#  (18332, 128239): {'id1': 18332,
#   'id2': 128239,
#   'count': 710,
#   'i>j': 181,
#   'i=j': 461},
#  (18332, 72501): {'id1': 18332,
#   'id2': 72501,
#   'count': 72,
#   'i>j': 17,
#   'i=j': 50},
#  (18332, 505): {'id1': 18332,
#   'id2': 505,
#   'count': 713,
#   'i>j': 153,
#   'i=j': 484},
#  (18332, 70750): {'id1': 18332,
#   'id2': 70750,
#   'count': 603,
#   'i>j': 119,
#   'i=j': 419},
#  (15456, 129953): {'id1': 15456,
#   'id2': 129953,
#   'count': 144,
#   'i>j': 38,
#   'i=j': 99},
#  (15456, 129955): {'id1': 15456,
#   'id2': 129955,
#   'count': 337,
#   'i>j': 77,
#   'i=j': 229},
#  (15456, 8550): {'id1': 15456,
#   'id2': 8550,
#   'count': 526,
#   'i>j': 118,
#   'i=j': 351},
#  (15456, 159247): {'id1': 15456,
#   'id2': 159247,
#   'count': 448,
#   'i>j': 161,
#   'i=j': 254},
#  (15456, 18938): {'id1': 15456,
#   'id2': 18938,
#   'count': 414,
#   'i>j': 113,
#   'i=j': 262},
#  (15456, 6523): {'id1': 15456,
#   'id2': 6523,
#   'count': 390,
#   'i>j': 135,
#   'i=j': 228},
#  (6212, 129953): {'id1': 6212,
#   'id2': 129953,
#   'count': 216,
#   'i>j': 60,
#   'i=j': 141},
#  (6212, 129955): {'id1': 6212,
#   'id2': 129955,
#   'count': 445,
#   'i>j': 115,
#   'i=j': 297},
#  (6212, 8550): {'id1': 6212,
#   'id2': 8550,
#   'count': 866,
#   'i>j': 236,
#   'i=j': 562},
#  (6212, 159247): {'id1': 6212,
#   'id2': 159247,
#   'count': 597,
#   'i>j': 233,
#   'i=j': 331},
#  (6212, 18938): {'id1': 6212,
#   'id2': 18938,
#   'count': 695,
#   'i>j': 207,
#   'i=j': 439},
#  (6212, 6523): {'id1': 6212,
#   'id2': 6523,
#   'count': 647,
#   'i>j': 248,
#   'i=j': 369},
#  (26089, 129953): {'id1': 26089,
#   'id2': 129953,
#   'count': 72,
#   'i>j': 15,
#   'i=j': 53},
#  (26089, 129955): {'id1': 26089,
#   'id2': 129955,
#   'count': 108,
#   'i>j': 25,
#   'i=j': 77},
#  (26089, 8550): {'id1': 26089,
#   'id2': 8550,
#   'count': 280,
#   'i>j': 78,
#   'i=j': 183},
#  (26089, 159247): {'id1': 26089,
#   'id2': 159247,
#   'count': 108,
#   'i>j': 31,
#   'i=j': 73},
#  (26089, 18938): {'id1': 26089,
#   'id2': 18938,
#   'count': 108,
#   'i>j': 32,
#   'i=j': 67},
#  (26089, 6523): {'id1': 26089,
#   'id2': 6523,
#   'count': 153,
#   'i>j': 47,
#   'i=j': 100},
#  (22799, 129953): {'id1': 22799,
#   'id2': 129953,
#   'count': 180,
#   'i>j': 50,
#   'i=j': 121},
#  (22799, 129955): {'id1': 22799,
#   'id2': 129955,
#   'count': 324,
#   'i>j': 81,
#   'i=j': 220},
#  (22799, 8550): {'id1': 22799,
#   'id2': 8550,
#   'count': 532,
#   'i>j': 139,
#   'i=j': 350},
#  (22799, 159247): {'id1': 22799,
#   'id2': 159247,
#   'count': 449,
#   'i>j': 165,
#   'i=j': 256},
#  (22799, 18938): {'id1': 22799,
#   'id2': 18938,
#   'count': 437,
#   'i>j': 128,
#   'i=j': 276},
#  (22799, 6523): {'id1': 22799,
#   'id2': 6523,
#   'count': 422,
#   'i>j': 146,
#   'i=j': 248},
#  (18036, 129953): {'id1': 18036,
#   'id2': 129953,
#   'count': 108,
#   'i>j': 30,
#   'i=j': 71},
#  (18036, 129955): {'id1': 18036,
#   'id2': 129955,
#   'count': 108,
#   'i>j': 29,
#   'i=j': 71},
#  (18036, 8550): {'id1': 18036,
#   'id2': 8550,
#   'count': 240,
#   'i>j': 75,
#   'i=j': 149},
#  (18036, 159247): {'id1': 18036,
#   'id2': 159247,
#   'count': 192,
#   'i>j': 74,
#   'i=j': 109},
#  (18036, 18938): {'id1': 18036,
#   'id2': 18938,
#   'count': 216,
#   'i>j': 73,
#   'i=j': 131},
#  (18036, 6523): {'id1': 18036,
#   'id2': 6523,
#   'count': 237,
#   'i>j': 79,
#   'i=j': 148},
#  (18332, 129953): {'id1': 18332,
#   'id2': 129953,
#   'count': 180,
#   'i>j': 48,
#   'i=j': 123},
#  (18332, 129955): {'id1': 18332,
#   'id2': 129955,
#   'count': 432,
#   'i>j': 109,
#   'i=j': 293},
#  (18332, 8550): {'id1': 18332,
#   'id2': 8550,
#   'count': 712,
#   'i>j': 199,
#   'i=j': 460},
#  (18332, 159247): {'id1': 18332,
#   'id2': 159247,
#   'count': 629,
#   'i>j': 236,
#   'i=j': 356},
#  (18332, 18938): {'id1': 18332,
#   'id2': 18938,
#   'count': 509,
#   'i>j': 158,
#   'i=j': 314},
#  (18332, 6523): {'id1': 18332,
#   'id2': 6523,
#   'count': 674,
#   'i>j': 263,
#   'i=j': 374},
#  (15456, 33369): {'id1': 15456,
#   'id2': 33369,
#   'count': 201,
#   'i>j': 46,
#   'i=j': 134},
#  (15456, 30459): {'id1': 15456,
#   'id2': 30459,
#   'count': 201,
#   'i>j': 45,
#   'i=j': 139},
#  (15456, 8372): {'id1': 15456,
#   'id2': 8372,
#   'count': 153,
#   'i>j': 32,
#   'i=j': 109},
#  (15456, 30013): {'id1': 15456,
#   'id2': 30013,
#   'count': 153,
#   'i>j': 32,
#   'i=j': 109},
#  (6212, 33369): {'id1': 6212,
#   'id2': 33369,
#   'count': 201,
#   'i>j': 52,
#   'i=j': 132},
#  (6212, 30459): {'id1': 6212,
#   'id2': 30459,
#   'count': 309,
#   'i>j': 89,
#   'i=j': 201},
#  (6212, 8372): {'id1': 6212, 'id2': 8372, 'count': 261, 'i>j': 76, 'i=j': 171},
#  (6212, 30013): {'id1': 6212,
#   'id2': 30013,
#   'count': 261,
#   'i>j': 76,
#   'i=j': 171},
#  (26089, 33369): {'id1': 26089,
#   'id2': 33369,
#   'count': 72,
#   'i>j': 19,
#   'i=j': 47},
#  (26089, 30459): {'id1': 26089,
#   'id2': 30459,
#   'count': 108,
#   'i>j': 30,
#   'i=j': 72},
#  (26089, 8372): {'id1': 26089,
#   'id2': 8372,
#   'count': 108,
#   'i>j': 30,
#   'i=j': 72},
#  (26089, 30013): {'id1': 26089,
#   'id2': 30013,
#   'count': 108,
#   'i>j': 30,
#   'i=j': 72},
#  (22799, 33369): {'id1': 22799,
#   'id2': 33369,
#   'count': 192,
#   'i>j': 49,
#   'i=j': 124},
#  (22799, 30459): {'id1': 22799,
#   'id2': 30459,
#   'count': 228,
#   'i>j': 57,
#   'i=j': 154},
#  (22799, 8372): {'id1': 22799,
#   'id2': 8372,
#   'count': 180,
#   'i>j': 44,
#   'i=j': 124},
#  (22799, 30013): {'id1': 22799,
#   'id2': 30013,
#   'count': 180,
#   'i>j': 44,
#   'i=j': 124},
#  (18036, 33369): {'id1': 18036,
#   'id2': 33369,
#   'count': 156,
#   'i>j': 37,
#   'i=j': 105},
#  (18036, 30459): {'id1': 18036,
#   'id2': 30459,
#   'count': 192,
#   'i>j': 48,
#   'i=j': 130},
#  (18036, 8372): {'id1': 18036,
#   'id2': 8372,
#   'count': 144,
#   'i>j': 35,
#   'i=j': 100},
#  (18036, 30013): {'id1': 18036,
#   'id2': 30013,
#   'count': 144,
#   'i>j': 35,
#   'i=j': 100},
#  (18332, 33369): {'id1': 18332,
#   'id2': 33369,
#   'count': 228,
#   'i>j': 57,
#   'i=j': 150},
#  (18332, 30459): {'id1': 18332,
#   'id2': 30459,
#   'count': 336,
#   'i>j': 90,
#   'i=j': 225},
#  (18332, 8372): {'id1': 18332,
#   'id2': 8372,
#   'count': 288,
#   'i>j': 77,
#   'i=j': 195},
#  (18332, 30013): {'id1': 18332,
#   'id2': 30013,
#   'count': 288,
#   'i>j': 77,
#   'i=j': 195},
#  (15456, 13857): {'id1': 15456,
#   'id2': 13857,
#   'count': 426,
#   'i>j': 97,
#   'i=j': 282},
#  (15456, 4258): {'id1': 15456,
#   'id2': 4258,
#   'count': 453,
#   'i>j': 97,
#   'i=j': 308},
#  (15456, 46339): {'id1': 15456,
#   'id2': 46339,
#   'count': 390,
#   'i>j': 95,
#   'i=j': 258},
#  (15456, 37836): {'id1': 15456,
#   'id2': 37836,
#   'count': 426,
#   'i>j': 97,
#   'i=j': 282},
#  (15456, 33620): {'id1': 15456,
#   'id2': 33620,
#   'count': 678,
#   'i>j': 137,
#   'i=j': 470},
#  (15456, 12148): {'id1': 15456,
#   'id2': 12148,
#   'count': 120,
#   'i>j': 22,
#   'i=j': 88},
#  (6212, 13857): {'id1': 6212,
#   'id2': 13857,
#   'count': 330,
#   'i>j': 93,
#   'i=j': 210},
#  (6212, 4258): {'id1': 6212, 'id2': 4258, 'count': 348, 'i>j': 80, 'i=j': 234},
#  (6212, 46339): {'id1': 6212,
#   'id2': 46339,
#   'count': 294,
#   'i>j': 83,
#   'i=j': 187},
#  (6212, 37836): {'id1': 6212,
#   'id2': 37836,
#   'count': 330,
#   'i>j': 93,
#   'i=j': 210},
#  (6212, 33620): {'id1': 6212,
#   'id2': 33620,
#   'count': 888,
#   'i>j': 173,
#   'i=j': 628},
#  (6212, 12148): {'id1': 6212,
#   'id2': 12148,
#   'count': 156,
#   'i>j': 32,
#   'i=j': 111},
#  (26089, 13857): {'id1': 26089,
#   'id2': 13857,
#   'count': 36,
#   'i>j': 8,
#   'i=j': 24},
#  (26089, 4258): {'id1': 26089,
#   'id2': 4258,
#   'count': 144,
#   'i>j': 36,
#   'i=j': 96},
#  (26089, 46339): {'id1': 26089,
#   'id2': 46339,
#   'count': 36,
#   'i>j': 8,
#   'i=j': 24},
#  (26089, 37836): {'id1': 26089,
#   'id2': 37836,
#   'count': 36,
#   'i>j': 8,
#   'i=j': 24},
#  (26089, 33620): {'id1': 26089,
#   'id2': 33620,
#   'count': 270,
#   'i>j': 45,
#   'i=j': 197},
#  (26089, 12148): {'id1': 26089,
#   'id2': 12148,
#   'count': 36,
#   'i>j': 8,
#   'i=j': 24},
#  (22799, 13857): {'id1': 22799,
#   'id2': 13857,
#   'count': 366,
#   'i>j': 90,
#   'i=j': 240},
#  (22799, 4258): {'id1': 22799,
#   'id2': 4258,
#   'count': 423,
#   'i>j': 104,
#   'i=j': 277},
#  (22799, 46339): {'id1': 22799,
#   'id2': 46339,
#   'count': 330,
#   'i>j': 85,
#   'i=j': 218},
#  (22799, 37836): {'id1': 22799,
#   'id2': 37836,
#   'count': 366,
#   'i>j': 90,
#   'i=j': 240},
#  (22799, 33620): {'id1': 22799,
#   'id2': 33620,
#   'count': 744,
#   'i>j': 144,
#   'i=j': 523},
#  (22799, 12148): {'id1': 22799,
#   'id2': 12148,
#   'count': 120,
#   'i>j': 22,
#   'i=j': 88},
#  (18036, 13857): {'id1': 18036,
#   'id2': 13857,
#   'count': 330,
#   'i>j': 86,
#   'i=j': 210},
#  (18036, 4258): {'id1': 18036,
#   'id2': 4258,
#   'count': 315,
#   'i>j': 76,
#   'i=j': 212},
#  (18036, 46339): {'id1': 18036,
#   'id2': 46339,
#   'count': 294,
#   'i>j': 81,
#   'i=j': 188},
#  (18036, 37836): {'id1': 18036,
#   'id2': 37836,
#   'count': 330,
#   'i>j': 86,
#   'i=j': 210},
#  (18036, 33620): {'id1': 18036,
#   'id2': 33620,
#   'count': 600,
#   'i>j': 128,
#   'i=j': 411},
#  (18036, 12148): {'id1': 18036,
#   'id2': 12148,
#   'count': 156,
#   'i>j': 27,
#   'i=j': 110},
#  (18332, 13857): {'id1': 18332,
#   'id2': 13857,
#   'count': 366,
#   'i>j': 93,
#   'i=j': 237},
#  (18332, 4258): {'id1': 18332,
#   'id2': 4258,
#   'count': 603,
#   'i>j': 135,
#   'i=j': 412},
#  (18332, 46339): {'id1': 18332,
#   'id2': 46339,
#   'count': 330,
#   'i>j': 88,
#   'i=j': 215},
#  (18332, 37836): {'id1': 18332,
#   'id2': 37836,
#   'count': 366,
#   'i>j': 93,
#   'i=j': 237},
#  (18332, 33620): {'id1': 18332,
#   'id2': 33620,
#   'count': 963,
#   'i>j': 175,
#   'i=j': 693},
#  (18332, 12148): {'id1': 18332,
#   'id2': 12148,
#   'count': 120,
#   'i>j': 22,
#   'i=j': 88},
#  (15456, 8159): {'id1': 15456,
#   'id2': 8159,
#   'count': 201,
#   'i>j': 80,
#   'i=j': 111},
#  (15456, 67274): {'id1': 15456,
#   'id2': 67274,
#   'count': 210,
#   'i>j': 85,
#   'i=j': 114},
#  (15456, 32767): {'id1': 15456,
#   'id2': 32767,
#   'count': 201,
#   'i>j': 80,
#   'i=j': 111},
#  (15456, 91159): {'id1': 15456,
#   'id2': 91159,
#   'count': 306,
#   'i>j': 89,
#   'i=j': 191},
#  (6212, 8159): {'id1': 6212,
#   'id2': 8159,
#   'count': 353,
#   'i>j': 169,
#   'i=j': 174},
#  (6212, 67274): {'id1': 6212,
#   'id2': 67274,
#   'count': 326,
#   'i>j': 155,
#   'i=j': 160},
#  (6212, 32767): {'id1': 6212,
#   'id2': 32767,
#   'count': 353,
#   'i>j': 169,
#   'i=j': 174},
#  (6212, 91159): {'id1': 6212,
#   'id2': 91159,
#   'count': 594,
#   'i>j': 164,
#   'i=j': 361},
#  (26089, 8159): {'id1': 26089, 'id2': 8159, 'count': 72, 'i>j': 28, 'i=j': 39},
#  (26089, 67274): {'id1': 26089,
#   'id2': 67274,
#   'count': 81,
#   'i>j': 34,
#   'i=j': 41},
#  (26089, 32767): {'id1': 26089,
#   'id2': 32767,
#   'count': 72,
#   'i>j': 28,
#   'i=j': 39},
#  (26089, 91159): {'id1': 26089,
#   'id2': 91159,
#   'count': 258,
#   'i>j': 77,
#   'i=j': 158},
#  (22799, 8159): {'id1': 22799,
#   'id2': 8159,
#   'count': 308,
#   'i>j': 138,
#   'i=j': 160},
#  (22799, 67274): {'id1': 22799,
#   'id2': 67274,
#   'count': 281,
#   'i>j': 124,
#   'i=j': 146},
#  (22799, 32767): {'id1': 22799,
#   'id2': 32767,
#   'count': 308,
#   'i>j': 138,
#   'i=j': 160},
#  (22799, 91159): {'id1': 22799,
#   'id2': 91159,
#   'count': 453,
#   'i>j': 139,
#   'i=j': 280},
#  (18036, 8159): {'id1': 18036,
#   'id2': 8159,
#   'count': 303,
#   'i>j': 126,
#   'i=j': 167},
#  (18036, 67274): {'id1': 18036,
#   'id2': 67274,
#   'count': 276,
#   'i>j': 112,
#   'i=j': 153},
#  (18036, 32767): {'id1': 18036,
#   'id2': 32767,
#   'count': 267,
#   'i>j': 110,
#   'i=j': 147},
#  (18036, 91159): {'id1': 18036,
#   'id2': 91159,
#   'count': 417,
#   'i>j': 126,
#   'i=j': 259},
#  (18332, 8159): {'id1': 18332,
#   'id2': 8159,
#   'count': 380,
#   'i>j': 176,
#   'i=j': 192},
#  (18332, 67274): {'id1': 18332,
#   'id2': 67274,
#   'count': 353,
#   'i>j': 170,
#   'i=j': 171},
#  (18332, 32767): {'id1': 18332,
#   'id2': 32767,
#   'count': 344,
#   'i>j': 149,
#   'i=j': 184},
#  (18332, 91159): {'id1': 18332,
#   'id2': 91159,
#   'count': 669,
#   'i>j': 195,
#   'i=j': 402},
#  (15456, 18305): {'id1': 15456,
#   'id2': 18305,
#   'count': 345,
#   'i>j': 74,
#   'i=j': 244},
#  (15456, 54468): {'id1': 15456,
#   'id2': 54468,
#   'count': 381,
#   'i>j': 77,
#   'i=j': 272},
#  (15456, 54469): {'id1': 15456,
#   'id2': 54469,
#   'count': 381,
#   'i>j': 77,
#   'i=j': 272},
#  (15456, 32004): {'id1': 15456,
#   'id2': 32004,
#   'count': 336,
#   'i>j': 72,
#   'i=j': 235},
#  (15456, 16871): {'id1': 15456,
#   'id2': 16871,
#   'count': 156,
#   'i>j': 35,
#   'i=j': 110},
#  (15456, 38647): {'id1': 15456,
#   'id2': 38647,
#   'count': 381,
#   'i>j': 77,
#   'i=j': 272},
#  (6212, 18305): {'id1': 6212,
#   'id2': 18305,
#   'count': 638,
#   'i>j': 135,
#   'i=j': 451},
#  (6212, 54468): {'id1': 6212,
#   'id2': 54468,
#   'count': 638,
#   'i>j': 133,
#   'i=j': 451},
#  (6212, 54469): {'id1': 6212,
#   'id2': 54469,
#   'count': 638,
#   'i>j': 133,
#   'i=j': 451},
#  (6212, 32004): {'id1': 6212,
#   'id2': 32004,
#   'count': 662,
#   'i>j': 156,
#   'i=j': 448},
#  (6212, 16871): {'id1': 6212,
#   'id2': 16871,
#   'count': 413,
#   'i>j': 84,
#   'i=j': 295},
#  (6212, 38647): {'id1': 6212,
#   'id2': 38647,
#   'count': 674,
#   'i>j': 140,
#   'i=j': 476},
#  (26089, 18305): {'id1': 26089,
#   'id2': 18305,
#   'count': 189,
#   'i>j': 43,
#   'i=j': 129},
#  (26089, 54468): {'id1': 26089,
#   'id2': 54468,
#   'count': 189,
#   'i>j': 43,
#   'i=j': 129},
#  (26089, 54469): {'id1': 26089,
#   'id2': 54469,
#   'count': 189,
#   'i>j': 43,
#   'i=j': 129},
#  (26089, 32004): {'id1': 26089,
#   'id2': 32004,
#   'count': 108,
#   'i>j': 21,
#   'i=j': 78},
#  (26089, 16871): {'id1': 26089,
#   'id2': 16871,
#   'count': 72,
#   'i>j': 16,
#   'i=j': 49},
#  (26089, 38647): {'id1': 26089,
#   'id2': 38647,
#   'count': 189,
#   'i>j': 43,
#   'i=j': 129},
#  (22799, 18305): {'id1': 22799,
#   'id2': 18305,
#   'count': 458,
#   'i>j': 95,
#   'i=j': 326},
#  (22799, 54468): {'id1': 22799,
#   'id2': 54468,
#   'count': 422,
#   'i>j': 88,
#   'i=j': 301},
#  (22799, 54469): {'id1': 22799,
#   'id2': 54469,
#   'count': 422,
#   'i>j': 88,
#   'i=j': 301},
#  (22799, 32004): {'id1': 22799,
#   'id2': 32004,
#   'count': 413,
#   'i>j': 92,
#   'i=j': 289},
#  (22799, 16871): {'id1': 22799,
#   'id2': 16871,
#   'count': 269,
#   'i>j': 56,
#   'i=j': 192},
#  (22799, 38647): {'id1': 22799,
#   'id2': 38647,
#   'count': 458,
#   'i>j': 95,
#   'i=j': 326},
#  (18036, 18305): {'id1': 18036,
#   'id2': 18305,
#   'count': 309,
#   'i>j': 61,
#   'i=j': 221},
#  (18036, 54468): {'id1': 18036,
#   'id2': 54468,
#   'count': 309,
#   'i>j': 61,
#   'i=j': 221},
#  (18036, 54469): {'id1': 18036,
#   'id2': 54469,
#   'count': 309,
#   'i>j': 61,
#   'i=j': 221},
#  (18036, 32004): {'id1': 18036,
#   'id2': 32004,
#   'count': 192,
#   'i>j': 33,
#   'i=j': 143},
#  (18036, 16871): {'id1': 18036,
#   'id2': 16871,
#   'count': 192,
#   'i>j': 41,
#   'i=j': 134},
#  (18036, 38647): {'id1': 18036,
#   'id2': 38647,
#   'count': 309,
#   'i>j': 61,
#   'i=j': 221},
#  (18332, 18305): {'id1': 18332,
#   'id2': 18305,
#   'count': 602,
#   'i>j': 137,
#   'i=j': 415},
#  (18332, 54468): {'id1': 18332,
#   'id2': 54468,
#   'count': 566,
#   'i>j': 128,
#   'i=j': 392},
#  (18332, 54469): {'id1': 18332,
#   'id2': 54469,
#   'count': 566,
#   'i>j': 128,
#   'i=j': 392},
#  (18332, 32004): {'id1': 18332,
#   'id2': 32004,
#   'count': 593,
#   'i>j': 136,
#   'i=j': 402},
#  (18332, 16871): {'id1': 18332,
#   'id2': 16871,
#   'count': 305,
#   'i>j': 69,
#   'i=j': 213},
#  (18332, 38647): {'id1': 18332,
#   'id2': 38647,
#   'count': 602,
#   'i>j': 134,
#   'i=j': 417},
#  (15456, 38020): {'id1': 15456,
#   'id2': 38020,
#   'count': 598,
#   'i>j': 145,
#   'i=j': 393},
#  (15456, 67304): {'id1': 15456,
#   'id2': 67304,
#   'count': 288,
#   'i>j': 84,
#   'i=j': 184},
#  (15456, 180969): {'id1': 15456,
#   'id2': 180969,
#   'count': 144,
#   'i>j': 40,
#   'i=j': 97},
#  (15456, 188946): {'id1': 15456,
#   'id2': 188946,
#   'count': 72,
#   'i>j': 23,
#   'i=j': 47},
#  (15456, 188947): {'id1': 15456,
#   'id2': 188947,
#   'count': 72,
#   'i>j': 13,
#   'i=j': 53},
#  (15456, 62620): {'id1': 15456,
#   'id2': 62620,
#   'count': 108,
#   'i>j': 23,
#   'i=j': 78},
#  (6212, 38020): {'id1': 6212,
#   'id2': 38020,
#   'count': 890,
#   'i>j': 221,
#   'i=j': 589},
#  (6212, 67304): {'id1': 6212,
#   'id2': 67304,
#   'count': 576,
#   'i>j': 159,
#   'i=j': 368},
#  (6212, 180969): {'id1': 6212,
#   'id2': 180969,
#   'count': 396,
#   'i>j': 122,
#   'i=j': 240},
#  (6212, 188946): {'id1': 6212,
#   'id2': 188946,
#   'count': 180,
#   'i>j': 60,
#   'i=j': 109},
#  (6212, 188947): {'id1': 6212,
#   'id2': 188947,
#   'count': 216,
#   'i>j': 56,
#   'i=j': 141},
#  (6212, 62620): {'id1': 6212,
#   'id2': 62620,
#   'count': 216,
#   'i>j': 59,
#   'i=j': 139},
#  (26089, 38020): {'id1': 26089,
#   'id2': 38020,
#   'count': 187,
#   'i>j': 45,
#   'i=j': 126},
#  (26089, 67304): {'id1': 26089,
#   'id2': 67304,
#   'count': 72,
#   'i>j': 17,
#   'i=j': 53},
#  (26089, 180969): {'id1': 26089,
#   'id2': 180969,
#   'count': 72,
#   'i>j': 20,
#   'i=j': 49},
#  (26089, 188946): {'id1': 26089,
#   'id2': 188946,
#   'count': 72,
#   'i>j': 20,
#   'i=j': 49},
#  (26089, 188947): {'id1': 26089,
#   'id2': 188947,
#   'count': 36,
#   'i>j': 6,
#   'i=j': 28},
#  (26089, 62620): {'id1': 26089,
#   'id2': 62620,
#   'count': 36,
#   'i>j': 6,
#   'i=j': 28},
#  (22799, 38020): {'id1': 22799,
#   'id2': 38020,
#   'count': 517,
#   'i>j': 128,
#   'i=j': 346},
#  (22799, 67304): {'id1': 22799,
#   'id2': 67304,
#   'count': 216,
#   'i>j': 67,
#   'i=j': 140},
#  (22799, 180969): {'id1': 22799,
#   'id2': 180969,
#   'count': 144,
#   'i>j': 47,
#   'i=j': 93},
#  (22799, 188946): {'id1': 22799,
#   'id2': 188946,
#   'count': 108,
#   'i>j': 37,
#   'i=j': 68},
#  (22799, 188947): {'id1': 22799,
#   'id2': 188947,
#   'count': 36,
#   'i>j': 6,
#   'i=j': 28},
#  (22799, 62620): {'id1': 22799,
#   'id2': 62620,
#   'count': 72,
#   'i>j': 16,
#   'i=j': 53},
#  (18036, 38020): {'id1': 18036,
#   'id2': 38020,
#   'count': 441,
#   'i>j': 121,
#   'i=j': 288},
#  (18036, 67304): {'id1': 18036,
#   'id2': 67304,
#   'count': 180,
#   'i>j': 50,
#   'i=j': 121},
#  (18036, 180969): {'id1': 18036,
#   'id2': 180969,
#   'count': 108,
#   'i>j': 30,
#   'i=j': 74},
#  (18036, 188946): {'id1': 18036,
#   'id2': 188946,
#   'count': 72,
#   'i>j': 20,
#   'i=j': 49},
#  (18036, 188947): {'id1': 18036,
#   'id2': 188947,
#   'count': 36,
#   'i>j': 6,
#   'i=j': 28},
#  (18036, 62620): {'id1': 18036,
#   'id2': 62620,
#   'count': 72,
#   'i>j': 16,
#   'i=j': 53},
#  (18332, 38020): {'id1': 18332,
#   'id2': 38020,
#   'count': 841,
#   'i>j': 221,
#   'i=j': 546},
#  (18332, 67304): {'id1': 18332,
#   'id2': 67304,
#   'count': 684,
#   'i>j': 181,
#   'i=j': 455},
#  (18332, 180969): {'id1': 18332,
#   'id2': 180969,
#   'count': 504,
#   'i>j': 149,
#   'i=j': 322},
#  (18332, 188946): {'id1': 18332,
#   'id2': 188946,
#   'count': 144,
#   'i>j': 43,
#   'i=j': 96},
#  (18332, 188947): {'id1': 18332,
#   'id2': 188947,
#   'count': 180,
#   'i>j': 43,
#   'i=j': 122},
#  (18332, 62620): {'id1': 18332,
#   'id2': 62620,
#   'count': 216,
#   'i>j': 47,
#   'i=j': 147},
#  (15456, 33099): {'id1': 15456,
#   'id2': 33099,
#   'count': 522,
#   'i>j': 181,
#   'i=j': 310},
#  (15456, 27691): {'id1': 15456,
#   'id2': 27691,
#   'count': 342,
#   'i>j': 136,
#   'i=j': 193},
#  (15456, 8044): {'id1': 15456,
#   'id2': 8044,
#   'count': 411,
#   'i>j': 136,
#   'i=j': 248},
#  (15456, 3645): {'id1': 15456,
#   'id2': 3645,
#   'count': 522,
#   'i>j': 181,
#   'i=j': 310},
#  (6212, 33099): {'id1': 6212,
#   'id2': 33099,
#   'count': 803,
#   'i>j': 267,
#   'i=j': 497},
#  (6212, 27691): {'id1': 6212,
#   'id2': 27691,
#   'count': 659,
#   'i>j': 216,
#   'i=j': 413},
#  (6212, 8044): {'id1': 6212,
#   'id2': 8044,
#   'count': 560,
#   'i>j': 178,
#   'i=j': 352},
#  (6212, 3645): {'id1': 6212,
#   'id2': 3645,
#   'count': 938,
#   'i>j': 296,
#   'i=j': 594},
#  (26089, 33099): {'id1': 26089,
#   'id2': 33099,
#   'count': 258,
#   'i>j': 98,
#   'i=j': 149},
#  (26089, 27691): {'id1': 26089,
#   'id2': 27691,
#   'count': 222,
#   'i>j': 84,
#   'i=j': 129},
#  (26089, 8044): {'id1': 26089,
#   'id2': 8044,
#   'count': 147,
#   'i>j': 58,
#   'i=j': 84},
#  (26089, 3645): {'id1': 26089,
#   'id2': 3645,
#   'count': 288,
#   'i>j': 110,
#   'i=j': 167},
#  (22799, 33099): {'id1': 22799,
#   'id2': 33099,
#   'count': 563,
#   'i>j': 196,
#   'i=j': 340},
#  (22799, 27691): {'id1': 22799,
#   'id2': 27691,
#   'count': 419,
#   'i>j': 150,
#   'i=j': 251},
#  (22799, 8044): {'id1': 22799,
#   'id2': 8044,
#   'count': 416,
#   'i>j': 145,
#   'i=j': 254},
#  (22799, 3645): {'id1': 22799,
#   'id2': 3645,
#   'count': 668,
#   'i>j': 235,
#   'i=j': 404},
#  (18036, 33099): {'id1': 18036,
#   'id2': 33099,
#   'count': 486,
#   'i>j': 181,
#   'i=j': 285},
#  (18036, 27691): {'id1': 18036,
#   'id2': 27691,
#   'count': 414,
#   'i>j': 156,
#   'i=j': 242},
#  (18036, 8044): {'id1': 18036,
#   'id2': 8044,
#   'count': 339,
#   'i>j': 122,
#   'i=j': 203},
#  (18036, 3645): {'id1': 18036,
#   'id2': 3645,
#   'count': 591,
#   'i>j': 220,
#   'i=j': 349},
#  (18332, 33099): {'id1': 18332,
#   'id2': 33099,
#   'count': 914,
#   'i>j': 295,
#   'i=j': 576},
#  (18332, 27691): {'id1': 18332,
#   'id2': 27691,
#   'count': 698,
#   'i>j': 227,
#   'i=j': 438},
#  (18332, 8044): {'id1': 18332,
#   'id2': 8044,
#   'count': 635,
#   'i>j': 203,
#   'i=j': 399},
#  (18332, 3645): {'id1': 18332,
#   'id2': 3645,
#   'count': 1055,
#   'i>j': 339,
#   'i=j': 668},
#  (15456, 98626): {'id1': 15456,
#   'id2': 98626,
#   'count': 144,
#   'i>j': 31,
#   'i=j': 106},
#  (15456, 4114): {'id1': 15456, 'id2': 4114, 'count': 96, 'i>j': 17, 'i=j': 73},
#  (15456, 17510): {'id1': 15456,
#   'id2': 17510,
#   'count': 96,
#   'i>j': 17,
#   'i=j': 73},
#  (6212, 98626): {'id1': 6212,
#   'id2': 98626,
#   'count': 305,
#   'i>j': 72,
#   'i=j': 204},
#  (6212, 4114): {'id1': 6212, 'id2': 4114, 'count': 221, 'i>j': 55, 'i=j': 136},
#  (6212, 17510): {'id1': 6212,
#   'id2': 17510,
#   'count': 221,
#   'i>j': 55,
#   'i=j': 136},
#  (26089, 98626): {'id1': 26089,
#   'id2': 98626,
#   'count': 72,
#   'i>j': 14,
#   'i=j': 54},
#  (26089, 4114): {'id1': 26089, 'id2': 4114, 'count': 36, 'i>j': 8, 'i=j': 25},
#  (26089, 17510): {'id1': 26089,
#   'id2': 17510,
#   'count': 36,
#   'i>j': 8,
#   'i=j': 25},
#  (22799, 98626): {'id1': 22799,
#   'id2': 98626,
#   'count': 197,
#   'i>j': 54,
#   'i=j': 133},
#  (22799, 4114): {'id1': 22799, 'id2': 4114, 'count': 77, 'i>j': 25, 'i=j': 46},
#  (22799, 17510): {'id1': 22799,
#   'id2': 17510,
#   'count': 77,
#   'i>j': 25,
#   'i=j': 46},
#  (18036, 98626): {'id1': 18036,
#   'id2': 98626,
#   'count': 120,
#   'i>j': 28,
#   'i=j': 87},
#  (18036, 4114): {'id1': 18036, 'id2': 4114, 'count': 36, 'i>j': 8, 'i=j': 25},
#  (18036, 17510): {'id1': 18036,
#   'id2': 17510,
#   'count': 36,
#   'i>j': 8,
#   'i=j': 25},
#  (18332, 98626): {'id1': 18332,
#   'id2': 98626,
#   'count': 233,
#   'i>j': 59,
#   'i=j': 158},
#  (18332, 4114): {'id1': 18332,
#   'id2': 4114,
#   'count': 113,
#   'i>j': 30,
#   'i=j': 73},
#  (18332, 17510): {'id1': 18332,
#   'id2': 17510,
#   'count': 113,
#   'i>j': 30,
#   'i=j': 73},
#  (15456, 117993): {'id1': 15456,
#   'id2': 117993,
#   'count': 444,
#   'i>j': 169,
#   'i=j': 255},
#  (15456, 131082): {'id1': 15456,
#   'id2': 131082,
#   'count': 651,
#   'i>j': 194,
#   'i=j': 407},
#  (15456, 44019): {'id1': 15456,
#   'id2': 44019,
#   'count': 462,
#   'i>j': 148,
#   'i=j': 282},
#  (15456, 109848): {'id1': 15456,
#   'id2': 109848,
#   'count': 228,
#   'i>j': 69,
#   'i=j': 145},
#  (15456, 112122): {'id1': 15456,
#   'id2': 112122,
#   'count': 300,
#   'i>j': 105,
#   'i=j': 175},
#  (15456, 112125): {'id1': 15456,
#   'id2': 112125,
#   'count': 651,
#   'i>j': 206,
#   'i=j': 400},
#  (6212, 117993): {'id1': 6212,
#   'id2': 117993,
#   'count': 884,
#   'i>j': 374,
#   'i=j': 475},
#  (6212, 131082): {'id1': 6212,
#   'id2': 131082,
#   'count': 1010,
#   'i>j': 315,
#   'i=j': 635},
#  (6212, 44019): {'id1': 6212,
#   'id2': 44019,
#   'count': 866,
#   'i>j': 274,
#   'i=j': 545},
#  (6212, 109848): {'id1': 6212,
#   'id2': 109848,
#   'count': 483,
#   'i>j': 163,
#   'i=j': 300},
#  (6212, 112122): {'id1': 6212,
#   'id2': 112122,
#   'count': 701,
#   'i>j': 270,
#   'i=j': 394},
#  (6212, 112125): {'id1': 6212,
#   'id2': 112125,
#   'count': 1046,
#   'i>j': 336,
#   'i=j': 651},
#  (26089, 117993): {'id1': 26089,
#   'id2': 117993,
#   'count': 180,
#   'i>j': 76,
#   'i=j': 98},
#  (26089, 131082): {'id1': 26089,
#   'id2': 131082,
#   'count': 108,
#   'i>j': 28,
#   'i=j': 73},
#  (26089, 44019): {'id1': 26089,
#   'id2': 44019,
#   'count': 144,
#   'i>j': 41,
#   'i=j': 97},
#  (26089, 109848): {'id1': 26089,
#   'id2': 109848,
#   'count': 36,
#   'i>j': 8,
#   'i=j': 25},
#  (26089, 112122): {'id1': 26089,
#   'id2': 112122,
#   'count': 108,
#   'i>j': 37,
#   'i=j': 65},
#  (26089, 112125): {'id1': 26089,
#   'id2': 112125,
#   'count': 144,
#   'i>j': 48,
#   'i=j': 88},
#  (22799, 117993): {'id1': 22799,
#   'id2': 117993,
#   'count': 521,
#   'i>j': 229,
#   'i=j': 272},
#  (22799, 131082): {'id1': 22799,
#   'id2': 131082,
#   'count': 611,
#   'i>j': 197,
#   'i=j': 370},
#  (22799, 44019): {'id1': 22799,
#   'id2': 44019,
#   'count': 539,
#   'i>j': 177,
#   'i=j': 331},
#  (22799, 109848): {'id1': 22799,
#   'id2': 109848,
#   'count': 264,
#   'i>j': 75,
#   'i=j': 168},
#  (22799, 112122): {'id1': 22799,
#   'id2': 112122,
#   'count': 413,
#   'i>j': 148,
#   'i=j': 241},
#  (22799, 112125): {'id1': 22799,
#   'id2': 112125,
#   'count': 647,
#   'i>j': 225,
#   'i=j': 382},
#  (18036, 117993): {'id1': 18036,
#   'id2': 117993,
#   'count': 300,
#   'i>j': 146,
#   'i=j': 147},
#  (18036, 131082): {'id1': 18036,
#   'id2': 131082,
#   'count': 318,
#   'i>j': 106,
#   'i=j': 192},
#  (18036, 44019): {'id1': 18036,
#   'id2': 44019,
#   'count': 282,
#   'i>j': 95,
#   'i=j': 173},
#  (18036, 109848): {'id1': 18036,
#   'id2': 109848,
#   'count': 192,
#   'i>j': 56,
#   'i=j': 123},
#  (18036, 112122): {'id1': 18036,
#   'id2': 112122,
#   'count': 264,
#   'i>j': 86,
#   'i=j': 164},
#  (18036, 112125): {'id1': 18036,
#   'id2': 112125,
#   'count': 354,
#   'i>j': 134,
#   'i=j': 204},
#  (18332, 117993): {'id1': 18332,
#   'id2': 117993,
#   'count': 1064,
#   'i>j': 409,
#   'i=j': 599},
#  (18332, 131082): {'id1': 18332,
#   'id2': 131082,
#   'count': 1007,
#   'i>j': 304,
#   'i=j': 636},
#  (18332, 44019): {'id1': 18332,
#   'id2': 44019,
#   'count': 794,
#   'i>j': 260,
#   'i=j': 485},
#  (18332, 109848): {'id1': 18332,
#   'id2': 109848,
#   'count': 480,
#   'i>j': 146,
#   'i=j': 301},
#  (18332, 112122): {'id1': 18332,
#   'id2': 112122,
#   'count': 704,
#   'i>j': 269,
#   'i=j': 395},
#  (18332, 112125): {'id1': 18332,
#   'id2': 112125,
#   'count': 1118,
#   'i>j': 368,
#   'i=j': 686},
#  (15456, 81696): {'id1': 15456,
#   'id2': 81696,
#   'count': 300,
#   'i>j': 64,
#   'i=j': 208},
#  (15456, 63339): {'id1': 15456,
#   'id2': 63339,
#   'count': 453,
#   'i>j': 90,
#   'i=j': 321},
#  (15456, 16081): {'id1': 15456,
#   'id2': 16081,
#   'count': 597,
#   'i>j': 133,
#   'i=j': 406},
#  (15456, 19027): {'id1': 15456,
#   'id2': 19027,
#   'count': 405,
#   'i>j': 74,
#   'i=j': 291},
#  (15456, 19646): {'id1': 15456,
#   'id2': 19646,
#   'count': 372,
#   'i>j': 89,
#   'i=j': 248},
#  (6212, 81696): {'id1': 6212,
#   'id2': 81696,
#   'count': 521,
#   'i>j': 116,
#   'i=j': 357},
#  (6212, 63339): {'id1': 6212,
#   'id2': 63339,
#   'count': 633,
#   'i>j': 137,
#   'i=j': 434},
#  (6212, 16081): {'id1': 6212,
#   'id2': 16081,
#   'count': 1031,
#   'i>j': 235,
#   'i=j': 699},
#  (6212, 19027): {'id1': 6212,
#   'id2': 19027,
#   'count': 698,
#   'i>j': 147,
#   'i=j': 480},
#  (6212, 19646): {'id1': 6212,
#   'id2': 19646,
#   'count': 660,
#   'i>j': 159,
#   'i=j': 435},
#  (26089, 81696): {'id1': 26089,
#   'id2': 81696,
#   'count': 108,
#   'i>j': 22,
#   'i=j': 77},
#  (26089, 63339): {'id1': 26089,
#   'id2': 63339,
#   'count': 117,
#   'i>j': 19,
#   'i=j': 88},
#  (26089, 16081): {'id1': 26089,
#   'id2': 16081,
#   'count': 189,
#   'i>j': 44,
#   'i=j': 129},
#  (26089, 19027): {'id1': 26089,
#   'id2': 19027,
#   'count': 117,
#   'i>j': 19,
#   'i=j': 88},
#  (26089, 19646): {'id1': 26089,
#   'id2': 19646,
#   'count': 72,
#   'i>j': 14,
#   'i=j': 51},
#  (22799, 81696): {'id1': 22799,
#   'id2': 81696,
#   'count': 341,
#   'i>j': 75,
#   'i=j': 237},
#  (22799, 63339): {'id1': 22799,
#   'id2': 63339,
#   'count': 513,
#   'i>j': 113,
#   'i=j': 353},
#  (22799, 16081): {'id1': 22799,
#   'id2': 16081,
#   'count': 638,
#   'i>j': 157,
#   'i=j': 423},
#  (22799, 19027): {'id1': 22799,
#   'id2': 19027,
#   'count': 542,
#   'i>j': 116,
#   'i=j': 376},
#  (22799, 19646): {'id1': 22799,
#   'id2': 19646,
#   'count': 504,
#   'i>j': 126,
#   'i=j': 330},
#  (18036, 81696): {'id1': 18036,
#   'id2': 81696,
#   'count': 192,
#   'i>j': 34,
#   'i=j': 142},
#  (18036, 63339): {'id1': 18036,
#   'id2': 63339,
#   'count': 297,
#   'i>j': 60,
#   'i=j': 210},
#  (18036, 16081): {'id1': 18036,
#   'id2': 16081,
#   'count': 345,
#   'i>j': 71,
#   'i=j': 240},
#  (18036, 19027): {'id1': 18036,
#   'id2': 19027,
#   'count': 321,
#   'i>j': 66,
#   'i=j': 225},
#  (18036, 19646): {'id1': 18036,
#   'id2': 19646,
#   'count': 288,
#   'i>j': 71,
#   'i=j': 189},
#  (18332, 81696): {'id1': 18332,
#   'id2': 81696,
#   'count': 557,
#   'i>j': 131,
#   'i=j': 371},
#  (18332, 63339): {'id1': 18332,
#   'id2': 63339,
# ...
#   'i>j': 90,
#   'i=j': 205},
#  (18332, 35009): {'id1': 18332,
#   'id2': 35009,
#   'count': 1026,
#   'i>j': 253,
#   'i=j': 697},
#  (18332, 115748): {'id1': 18332,
#   'id2': 115748,
#   'count': 854,
#   'i>j': 276,
#   'i=j': 528},
#  (18332, 132716): {'id1': 18332,
#   'id2': 132716,
#   'count': 590,
#   'i>j': 197,
#   'i=j': 359},
#  (18332, 111065): {'id1': 18332,
#   'id2': 111065,
#   'count': 889,
#   'i>j': 309,
#   'i=j': 526},
#  (18332, 132891): {'id1': 18332,
#   'id2': 132891,
#   'count': 509,
#   'i>j': 156,
#   'i=j': 324},
#  (18332, 37277): {'id1': 18332,
#   'id2': 37277,
#   'count': 597,
#   'i>j': 203,
#   'i=j': 355},
#  (15456, 68676): {'id1': 15456,
#   'id2': 68676,
#   'count': 450,
#   'i>j': 152,
#   'i=j': 278},
#  (15456, 4878): {'id1': 15456,
#   'id2': 4878,
#   'count': 405,
#   'i>j': 95,
#   'i=j': 272},
#  (15456, 140179): {'id1': 15456,
#   'id2': 140179,
#   'count': 384,
#   'i>j': 108,
#   'i=j': 249},
#  (15456, 161269): {'id1': 15456,
#   'id2': 161269,
#   'count': 283,
#   'i>j': 82,
#   'i=j': 171},
#  (15456, 14518): {'id1': 15456,
#   'id2': 14518,
#   'count': 672,
#   'i>j': 179,
#   'i=j': 434},
#  (15456, 11993): {'id1': 15456,
#   'id2': 11993,
#   'count': 228,
#   'i>j': 92,
#   'i=j': 128},
#  (6212, 68676): {'id1': 6212,
#   'id2': 68676,
#   'count': 959,
#   'i>j': 300,
#   'i=j': 585},
#  (6212, 4878): {'id1': 6212,
#   'id2': 4878,
#   'count': 729,
#   'i>j': 148,
#   'i=j': 498},
#  (6212, 140179): {'id1': 6212,
#   'id2': 140179,
#   'count': 533,
#   'i>j': 162,
#   'i=j': 333},
#  (6212, 161269): {'id1': 6212,
#   'id2': 161269,
#   'count': 356,
#   'i>j': 123,
#   'i=j': 209},
#  (6212, 14518): {'id1': 6212,
#   'id2': 14518,
#   'count': 1159,
#   'i>j': 313,
#   'i=j': 748},
#  (6212, 11993): {'id1': 6212,
#   'id2': 11993,
#   'count': 405,
#   'i>j': 168,
#   'i=j': 224},
#  (26089, 68676): {'id1': 26089,
#   'id2': 68676,
#   'count': 189,
#   'i>j': 48,
#   'i=j': 128},
#  (26089, 4878): {'id1': 26089,
#   'id2': 4878,
#   'count': 267,
#   'i>j': 34,
#   'i=j': 199},
#  (26089, 140179): {'id1': 26089,
#   'id2': 140179,
#   'count': 192,
#   'i>j': 54,
#   'i=j': 123},
#  (26089, 161269): {'id1': 26089,
#   'id2': 161269,
#   'count': 111,
#   'i>j': 39,
#   'i=j': 65},
#  (26089, 14518): {'id1': 26089,
#   'id2': 14518,
#   'count': 259,
#   'i>j': 79,
#   'i=j': 158},
#  (26089, 11993): {'id1': 26089,
#   'id2': 11993,
#   'count': 108,
#   'i>j': 48,
#   'i=j': 56},
#  (22799, 68676): {'id1': 22799,
#   'id2': 68676,
#   'count': 518,
#   'i>j': 165,
#   'i=j': 319},
#  (22799, 4878): {'id1': 22799,
#   'id2': 4878,
#   'count': 525,
#   'i>j': 105,
#   'i=j': 362},
#  (22799, 140179): {'id1': 22799,
#   'id2': 140179,
#   'count': 389,
#   'i>j': 115,
#   'i=j': 246},
#  (22799, 161269): {'id1': 22799,
#   'id2': 161269,
#   'count': 284,
#   'i>j': 90,
#   'i=j': 173},
#  (22799, 14518): {'id1': 22799,
#   'id2': 14518,
#   'count': 595,
#   'i>j': 168,
#   'i=j': 382},
#  (22799, 11993): {'id1': 22799,
#   'id2': 11993,
#   'count': 228,
#   'i>j': 105,
#   'i=j': 117},
#  (18036, 68676): {'id1': 18036,
#   'id2': 68676,
#   'count': 261,
#   'i>j': 71,
#   'i=j': 169},
#  (18036, 4878): {'id1': 18036,
#   'id2': 4878,
#   'count': 453,
#   'i>j': 84,
#   'i=j': 316},
#  (18036, 140179): {'id1': 18036,
#   'id2': 140179,
#   'count': 204,
#   'i>j': 62,
#   'i=j': 124},
#  (18036, 161269): {'id1': 18036,
#   'id2': 161269,
#   'count': 207,
#   'i>j': 73,
#   'i=j': 116},
#  (18036, 14518): {'id1': 18036,
#   'id2': 14518,
#   'count': 375,
#   'i>j': 112,
#   'i=j': 238},
#  (18036, 11993): {'id1': 18036,
#   'id2': 11993,
#   'count': 228,
#   'i>j': 103,
#   'i=j': 118},
#  (18332, 68676): {'id1': 18332,
#   'id2': 68676,
#   'count': 953,
#   'i>j': 318,
#   'i=j': 578},
#  (18332, 4878): {'id1': 18332,
#   'id2': 4878,
#   'count': 693,
#   'i>j': 147,
#   'i=j': 467},
#  (18332, 140179): {'id1': 18332,
#   'id2': 140179,
#   'count': 749,
#   'i>j': 199,
#   'i=j': 480},
#  (18332, 161269): {'id1': 18332,
#   'id2': 161269,
#   'count': 356,
#   'i>j': 118,
#   'i=j': 212},
#  (18332, 14518): {'id1': 18332,
#   'id2': 14518,
#   'count': 1306,
#   'i>j': 360,
#   'i=j': 834},
#  (18332, 11993): {'id1': 18332,
#   'id2': 11993,
#   'count': 396,
#   'i>j': 161,
#   'i=j': 216},
#  (15456, 17024): {'id1': 15456,
#   'id2': 17024,
#   'count': 714,
#   'i>j': 169,
#   'i=j': 465},
#  (15456, 30180): {'id1': 15456,
#   'id2': 30180,
#   'count': 534,
#   'i>j': 125,
#   'i=j': 341},
#  (15456, 20397): {'id1': 15456,
#   'id2': 20397,
#   'count': 561,
#   'i>j': 140,
#   'i=j': 366},
#  (15456, 17230): {'id1': 15456,
#   'id2': 17230,
#   'count': 477,
#   'i>j': 110,
#   'i=j': 313},
#  (15456, 104732): {'id1': 15456,
#   'id2': 104732,
#   'count': 525,
#   'i>j': 125,
#   'i=j': 342},
#  (15456, 115772): {'id1': 15456,
#   'id2': 115772,
#   'count': 558,
#   'i>j': 124,
#   'i=j': 371},
#  (6212, 17024): {'id1': 6212,
#   'id2': 17024,
#   'count': 1103,
#   'i>j': 286,
#   'i=j': 725},
#  (6212, 30180): {'id1': 6212,
#   'id2': 30180,
#   'count': 887,
#   'i>j': 224,
#   'i=j': 588},
#  (6212, 20397): {'id1': 6212,
#   'id2': 20397,
#   'count': 806,
#   'i>j': 218,
#   'i=j': 525},
#  (6212, 17230): {'id1': 6212,
#   'id2': 17230,
#   'count': 612,
#   'i>j': 150,
#   'i=j': 403},
#  (6212, 104732): {'id1': 6212,
#   'id2': 104732,
#   'count': 809,
#   'i>j': 206,
#   'i=j': 535},
#  (6212, 115772): {'id1': 6212,
#   'id2': 115772,
#   'count': 911,
#   'i>j': 231,
#   'i=j': 605},
#  (26089, 17024): {'id1': 26089,
#   'id2': 17024,
#   'count': 144,
#   'i>j': 45,
#   'i=j': 89},
#  (26089, 30180): {'id1': 26089,
#   'id2': 30180,
#   'count': 108,
#   'i>j': 30,
#   'i=j': 70},
#  (26089, 20397): {'id1': 26089,
#   'id2': 20397,
#   'count': 72,
#   'i>j': 23,
#   'i=j': 45},
#  (26089, 17230): {'id1': 26089,
#   'id2': 17230,
#   'count': 72,
#   'i>j': 18,
#   'i=j': 49},
#  (26089, 104732): {'id1': 26089,
#   'id2': 104732,
#   'count': 108,
#   'i>j': 30,
#   'i=j': 70},
#  (26089, 115772): {'id1': 26089,
#   'id2': 115772,
#   'count': 108,
#   'i>j': 35,
#   'i=j': 66},
#  (22799, 17024): {'id1': 22799,
#   'id2': 17024,
#   'count': 593,
#   'i>j': 161,
#   'i=j': 373},
#  (22799, 30180): {'id1': 22799,
#   'id2': 30180,
#   'count': 545,
#   'i>j': 143,
#   'i=j': 342},
#  (22799, 20397): {'id1': 22799,
#   'id2': 20397,
#   'count': 485,
#   'i>j': 141,
#   'i=j': 303},
#  (22799, 17230): {'id1': 22799,
#   'id2': 17230,
#   'count': 396,
#   'i>j': 97,
#   'i=j': 257},
#  (22799, 104732): {'id1': 22799,
#   'id2': 104732,
#   'count': 557,
#   'i>j': 145,
#   'i=j': 355},
#  (22799, 115772): {'id1': 22799,
#   'id2': 115772,
#   'count': 545,
#   'i>j': 147,
#   'i=j': 347},
#  (18036, 17024): {'id1': 18036,
#   'id2': 17024,
#   'count': 336,
#   'i>j': 96,
#   'i=j': 211},
#  (18036, 30180): {'id1': 18036,
#   'id2': 30180,
#   'count': 360,
#   'i>j': 95,
#   'i=j': 231},
#  (18036, 20397): {'id1': 18036,
#   'id2': 20397,
#   'count': 228,
#   'i>j': 79,
#   'i=j': 137},
#  (18036, 17230): {'id1': 18036,
#   'id2': 17230,
#   'count': 144,
#   'i>j': 45,
#   'i=j': 87},
#  (18036, 104732): {'id1': 18036,
#   'id2': 104732,
#   'count': 300,
#   'i>j': 81,
#   'i=j': 192},
#  (18036, 115772): {'id1': 18036,
#   'id2': 115772,
#   'count': 216,
#   'i>j': 56,
#   'i=j': 140},
#  (18332, 17024): {'id1': 18332,
#   'id2': 17024,
#   'count': 881,
#   'i>j': 254,
#   'i=j': 558},
#  (18332, 30180): {'id1': 18332,
#   'id2': 30180,
#   'count': 764,
#   'i>j': 217,
#   'i=j': 487},
#  (18332, 20397): {'id1': 18332,
#   'id2': 20397,
#   'count': 740,
#   'i>j': 220,
#   'i=j': 464},
#  (18332, 17230): {'id1': 18332,
#   'id2': 17230,
#   'count': 720,
#   'i>j': 192,
#   'i=j': 473},
#  (18332, 104732): {'id1': 18332,
#   'id2': 104732,
#   'count': 884,
#   'i>j': 248,
#   'i=j': 568},
#  (18332, 115772): {'id1': 18332,
#   'id2': 115772,
#   'count': 872,
#   'i>j': 247,
#   'i=j': 554},
#  (15456, 125618): {'id1': 15456,
#   'id2': 125618,
#   'count': 84,
#   'i>j': 27,
#   'i=j': 52},
#  (15456, 151243): {'id1': 15456,
#   'id2': 151243,
#   'count': 36,
#   'i>j': 9,
#   'i=j': 24},
#  (15456, 124981): {'id1': 15456,
#   'id2': 124981,
#   'count': 84,
#   'i>j': 27,
#   'i=j': 52},
#  (15456, 125147): {'id1': 15456,
#   'id2': 125147,
#   'count': 84,
#   'i>j': 27,
#   'i=j': 52},
#  (6212, 125618): {'id1': 6212,
#   'id2': 125618,
#   'count': 192,
#   'i>j': 64,
#   'i=j': 118},
#  (6212, 151243): {'id1': 6212,
#   'id2': 151243,
#   'count': 144,
#   'i>j': 46,
#   'i=j': 90},
#  (6212, 124981): {'id1': 6212,
#   'id2': 124981,
#   'count': 192,
#   'i>j': 64,
#   'i=j': 118},
#  (6212, 125147): {'id1': 6212,
#   'id2': 125147,
#   'count': 192,
#   'i>j': 64,
#   'i=j': 118},
#  (26089, 125618): {'id1': 26089,
#   'id2': 125618,
#   'count': 72,
#   'i>j': 20,
#   'i=j': 48},
#  (26089, 151243): {'id1': 26089,
#   'id2': 151243,
#   'count': 72,
#   'i>j': 20,
#   'i=j': 48},
#  (26089, 124981): {'id1': 26089,
#   'id2': 124981,
#   'count': 72,
#   'i>j': 20,
#   'i=j': 48},
#  (26089, 125147): {'id1': 26089,
#   'id2': 125147,
#   'count': 72,
#   'i>j': 20,
#   'i=j': 48},
#  (22799, 125618): {'id1': 22799,
#   'id2': 125618,
#   'count': 120,
#   'i>j': 38,
#   'i=j': 76},
#  (22799, 151243): {'id1': 22799,
#   'id2': 151243,
#   'count': 72,
#   'i>j': 20,
#   'i=j': 48},
#  (22799, 124981): {'id1': 22799,
#   'id2': 124981,
#   'count': 120,
#   'i>j': 38,
#   'i=j': 76},
#  (22799, 125147): {'id1': 22799,
#   'id2': 125147,
#   'count': 120,
#   'i>j': 38,
#   'i=j': 76},
#  (18036, 125618): {'id1': 18036,
#   'id2': 125618,
#   'count': 156,
#   'i>j': 49,
#   'i=j': 98},
#  (18036, 151243): {'id1': 18036,
#   'id2': 151243,
#   'count': 108,
#   'i>j': 31,
#   'i=j': 70},
#  (18036, 124981): {'id1': 18036,
#   'id2': 124981,
#   'count': 156,
#   'i>j': 49,
#   'i=j': 98},
#  (18036, 125147): {'id1': 18036,
#   'id2': 125147,
#   'count': 156,
#   'i>j': 49,
#   'i=j': 98},
#  (18332, 125618): {'id1': 18332,
#   'id2': 125618,
#   'count': 228,
#   'i>j': 79,
#   'i=j': 137},
#  (18332, 151243): {'id1': 18332,
#   'id2': 151243,
#   'count': 180,
#   'i>j': 61,
#   'i=j': 109},
#  (18332, 124981): {'id1': 18332,
#   'id2': 124981,
#   'count': 264,
#   'i>j': 90,
#   'i=j': 160},
#  (18332, 125147): {'id1': 18332,
#   'id2': 125147,
#   'count': 264,
#   'i>j': 90,
#   'i=j': 160},
#  (15456, 47521): {'id1': 15456,
#   'id2': 47521,
#   'count': 621,
#   'i>j': 124,
#   'i=j': 439},
#  (15456, 33032): {'id1': 15456,
#   'id2': 33032,
#   'count': 909,
#   'i>j': 117,
#   'i=j': 707},
#  (15456, 110920): {'id1': 15456,
#   'id2': 110920,
#   'count': 1291,
#   'i>j': 200,
#   'i=j': 976},
#  (15456, 27499): {'id1': 15456,
#   'id2': 27499,
#   'count': 1183,
#   'i>j': 183,
#   'i=j': 896},
#  (15456, 54475): {'id1': 15456,
#   'id2': 54475,
#   'count': 456,
#   'i>j': 109,
#   'i=j': 291},
#  (15456, 12313): {'id1': 15456,
#   'id2': 12313,
#   'count': 1102,
#   'i>j': 164,
#   'i=j': 848},
#  (6212, 47521): {'id1': 6212,
#   'id2': 47521,
#   'count': 1175,
#   'i>j': 228,
#   'i=j': 830},
#  (6212, 33032): {'id1': 6212,
#   'id2': 33032,
#   'count': 1049,
#   'i>j': 173,
#   'i=j': 756},
#  (6212, 110920): {'id1': 6212,
#   'id2': 110920,
#   'count': 1858,
#   'i>j': 366,
#   'i=j': 1300},
#  (6212, 27499): {'id1': 6212,
#   'id2': 27499,
#   'count': 1635,
#   'i>j': 323,
#   'i=j': 1136},
#  (6212, 54475): {'id1': 6212,
#   'id2': 54475,
#   'count': 820,
#   'i>j': 173,
#   'i=j': 554},
#  (6212, 12313): {'id1': 6212,
#   'id2': 12313,
#   'count': 1603,
#   'i>j': 309,
#   'i=j': 1123},
#  (26089, 47521): {'id1': 26089,
#   'id2': 47521,
#   'count': 342,
#   'i>j': 70,
#   'i=j': 238},
#  (26089, 33032): {'id1': 26089,
#   'id2': 33032,
#   'count': 414,
#   'i>j': 74,
#   'i=j': 295},
#  (26089, 110920): {'id1': 26089,
#   'id2': 110920,
#   'count': 415,
#   'i>j': 85,
#   'i=j': 295},
#  (26089, 27499): {'id1': 26089,
#   'id2': 27499,
#   'count': 375,
#   'i>j': 81,
#   'i=j': 264},
#  (26089, 54475): {'id1': 26089,
#   'id2': 54475,
#   'count': 187,
#   'i>j': 42,
#   'i=j': 129},
#  (26089, 12313): {'id1': 26089,
#   'id2': 12313,
#   'count': 379,
#   'i>j': 77,
#   'i=j': 272},
#  (22799, 47521): {'id1': 22799,
#   'id2': 47521,
#   'count': 884,
#   'i>j': 188,
#   'i=j': 604},
#  (22799, 33032): {'id1': 22799,
#   'id2': 33032,
#   'count': 1136,
#   'i>j': 167,
#   'i=j': 860},
#  (22799, 110920): {'id1': 22799,
#   'id2': 110920,
#   'count': 1281,
#   'i>j': 232,
#   'i=j': 944},
#  (22799, 27499): {'id1': 22799,
#   'id2': 27499,
#   'count': 1169,
#   'i>j': 211,
#   'i=j': 862},
#  (22799, 54475): {'id1': 22799,
#   'id2': 54475,
#   'count': 454,
#   'i>j': 101,
#   'i=j': 312},
#  (22799, 12313): {'id1': 22799,
#   'id2': 12313,
#   'count': 1173,
#   'i>j': 207,
#   'i=j': 870},
#  (18036, 47521): {'id1': 18036,
#   'id2': 47521,
#   'count': 627,
#   'i>j': 135,
#   'i=j': 421},
#  (18036, 33032): {'id1': 18036,
#   'id2': 33032,
#   'count': 663,
#   'i>j': 120,
#   'i=j': 472},
#  (18036, 110920): {'id1': 18036,
#   'id2': 110920,
#   'count': 768,
#   'i>j': 161,
#   'i=j': 528},
#  (18036, 27499): {'id1': 18036,
#   'id2': 27499,
#   'count': 696,
#   'i>j': 145,
#   'i=j': 481},
#  (18036, 54475): {'id1': 18036,
#   'id2': 54475,
#   'count': 306,
#   'i>j': 73,
#   'i=j': 208},
#  (18036, 12313): {'id1': 18036,
#   'id2': 12313,
#   'count': 696,
#   'i>j': 145,
#   'i=j': 481},
#  (18332, 47521): {'id1': 18332,
#   'id2': 47521,
#   'count': 1208,
#   'i>j': 227,
#   'i=j': 874},
#  (18332, 33032): {'id1': 18332,
#   'id2': 33032,
#   'count': 1340,
#   'i>j': 221,
#   'i=j': 974},
#  (18332, 110920): {'id1': 18332,
#   'id2': 110920,
#   'count': 1917,
#   'i>j': 363,
#   'i=j': 1373},
#  (18332, 27499): {'id1': 18332,
#   'id2': 27499,
#   'count': 1844,
#   'i>j': 348,
#   'i=j': 1312},
#  (18332, 54475): {'id1': 18332,
#   'id2': 54475,
#   'count': 634,
#   'i>j': 148,
#   'i=j': 431},
#  (18332, 12313): {'id1': 18332,
#   'id2': 12313,
#   'count': 1737,
#   'i>j': 321,
#   'i=j': 1246},
#  (15456, 3440): {'id1': 15456,
#   'id2': 3440,
#   'count': 144,
#   'i>j': 41,
#   'i=j': 97},
#  (15456, 96642): {'id1': 15456,
#   'id2': 96642,
#   'count': 225,
#   'i>j': 85,
#   'i=j': 128},
#  (15456, 130842): {'id1': 15456,
#   'id2': 130842,
#   'count': 237,
#   'i>j': 81,
#   'i=j': 150},
#  (15456, 102548): {'id1': 15456,
#   'id2': 102548,
#   'count': 369,
#   'i>j': 127,
#   'i=j': 229},
#  (6212, 3440): {'id1': 6212,
#   'id2': 3440,
#   'count': 437,
#   'i>j': 139,
#   'i=j': 275},
#  (6212, 96642): {'id1': 6212,
#   'id2': 96642,
#   'count': 518,
#   'i>j': 202,
#   'i=j': 286},
#  (6212, 130842): {'id1': 6212,
#   'id2': 130842,
#   'count': 494,
#   'i>j': 175,
#   'i=j': 299},
#  (6212, 102548): {'id1': 6212,
#   'id2': 102548,
#   'count': 803,
#   'i>j': 269,
#   'i=j': 493},
#  (26089, 3440): {'id1': 26089,
#   'id2': 3440,
#   'count': 108,
#   'i>j': 31,
#   'i=j': 71},
#  (26089, 96642): {'id1': 26089,
#   'id2': 96642,
#   'count': 108,
#   'i>j': 44,
#   'i=j': 59},
#  (26089, 130842): {'id1': 26089,
#   'id2': 130842,
#   'count': 153,
#   'i>j': 43,
#   'i=j': 102},
#  (26089, 102548): {'id1': 26089,
#   'id2': 102548,
#   'count': 117,
#   'i>j': 33,
#   'i=j': 78},
#  (22799, 3440): {'id1': 22799,
#   'id2': 3440,
#   'count': 293,
#   'i>j': 90,
#   'i=j': 189},
#  (22799, 96642): {'id1': 22799,
#   'id2': 96642,
#   'count': 365,
#   'i>j': 144,
#   'i=j': 201},
#  (22799, 130842): {'id1': 22799,
#   'id2': 130842,
#   'count': 350,
#   'i>j': 119,
#   'i=j': 219},
#  (22799, 102548): {'id1': 22799,
#   'id2': 102548,
#   'count': 374,
#   'i>j': 126,
#   'i=j': 232},
#  (18036, 3440): {'id1': 18036,
#   'id2': 3440,
#   'count': 180,
#   'i>j': 51,
#   'i=j': 121},
#  (18036, 96642): {'id1': 18036,
#   'id2': 96642,
#   'count': 180,
#   'i>j': 70,
#   'i=j': 103},
#  (18036, 130842): {'id1': 18036,
#   'id2': 130842,
#   'count': 309,
#   'i>j': 95,
#   'i=j': 201},
#  (18036, 102548): {'id1': 18036,
#   'id2': 102548,
#   'count': 225,
#   'i>j': 64,
#   'i=j': 150},
#  (18332, 3440): {'id1': 18332,
#   'id2': 3440,
#   'count': 401,
#   'i>j': 141,
#   'i=j': 239},
#  (18332, 96642): {'id1': 18332,
#   'id2': 96642,
#   'count': 401,
#   'i>j': 152,
#   'i=j': 227},
#  (18332, 130842): {'id1': 18332,
#   'id2': 130842,
#   'count': 569,
#   'i>j': 204,
#   'i=j': 341},
#  (18332, 102548): {'id1': 18332,
#   'id2': 102548,
#   'count': 737,
#   'i>j': 255,
#   'i=j': 441},
#  (15456, 27009): {'id1': 15456,
#   'id2': 27009,
#   'count': 318,
#   'i>j': 74,
#   'i=j': 213},
#  (15456, 54574): {'id1': 15456,
#   'id2': 54574,
#   'count': 318,
#   'i>j': 84,
#   'i=j': 208},
#  (15456, 116628): {'id1': 15456,
#   'id2': 116628,
#   'count': 318,
#   'i>j': 84,
#   'i=j': 208},
#  (15456, 88505): {'id1': 15456,
#   'id2': 88505,
#   'count': 318,
#   'i>j': 84,
#   'i=j': 208},
#  (15456, 30236): {'id1': 15456,
#   'id2': 30236,
#   'count': 534,
#   'i>j': 144,
#   'i=j': 349},
#  (6212, 27009): {'id1': 6212,
#   'id2': 27009,
#   'count': 599,
#   'i>j': 123,
#   'i=j': 421},
#  (6212, 54574): {'id1': 6212,
#   'id2': 54574,
#   'count': 575,
#   'i>j': 143,
#   'i=j': 387},
#  (6212, 116628): {'id1': 6212,
#   'id2': 116628,
#   'count': 503,
#   'i>j': 106,
#   'i=j': 353},
#  (6212, 88505): {'id1': 6212,
#   'id2': 88505,
#   'count': 611,
#   'i>j': 148,
#   'i=j': 416},
#  (6212, 30236): {'id1': 6212,
#   'id2': 30236,
#   'count': 767,
#   'i>j': 202,
#   'i=j': 504},
#  ...}

# %% [markdown]
# Зафиксируем $\theta$ и будем итеративно подбирать $\gamma_k$ Команды в данном случае не рассматриваются, все игроки рассматриваются независимо

# %%
teta = 1.1
gamma = {id: 1./len(train_players_ids) for id in train_players_ids}
for _ in range(1):
    gamma_new = {id: {'wins': 0, 'sum1': 0, 'sum2': 0, 'count': 0} for id in train_players_ids}
    for r in res:
        row = res[r]
        id1 = row['id1']
        id2 = row['id2']
        gamma_new[id1]['count'] += row['count']
        gamma_new[id2]['count'] += row['count']
        gamma_new[id1]['wins'] += row['i>j']
        gamma_new[id2]['wins'] += row['count'] - row['i>j'] - row['i=j']
        gamma_new[id1]['sum1'] += row['i>j'] / (gamma[id1] + teta * gamma[id2])
        gamma_new[id2]['sum1'] += (row['count'] - row['i>j'] - row['i=j']) / (gamma[id2] + teta * gamma[id1])
        gamma_new[id1]['sum2'] += (row['count'] - row['i>j'] - row['i=j']) * teta / (gamma[id2] + teta * gamma[id1])
        gamma_new[id2]['sum2'] += row['i>j'] * teta / (gamma[id1] + teta * gamma[id2])
    s = 0.0
    for k in gamma:
        gamma[k] = gamma_new[k]['wins'] / (gamma_new[id1]['sum1'] + gamma_new[id1]['sum2'])
        s += gamma[k]
    for k in gamma:
        gamma[k] /= s

# %%
from scipy import stats

# %%
n_tournaments = 0
correlation_spearmanr = 0.0
correlation_kendall = 0.0
for tournament_id in list(test.keys()):
    tournament = test[tournament_id]
    if len(tournament) == 0:
        continue
    real_order = []
    predicted_order = []
    unknown = True
    for team_data in tournament:
        real_order.append(team_data['position'])
        score = 0.0
        count = 0
        for member in team_data['teamMembers']:
            id = member['player']['id']
            if id in gamma:
                score += gamma[id]
                count += 1
        if count == 0:
            predicted_order.append(0)
        else:
            unknown = False
            predicted_order.append(score / count)
    if unknown or len(predicted_order) <= 1:
        continue
    predicted_order.reverse()
    correlation_spearmanr += stats.spearmanr(predicted_order, real_order).correlation
    tau, _ = stats.kendalltau(predicted_order, real_order)
    correlation_kendall += tau
    n_tournaments += 1
print(f'Spearmanr correlation: {correlation_spearmanr / n_tournaments}')
print(f'Kendall correlation: {correlation_kendall / n_tournaments}')
# Out:
# Spearmanr correlation: 0.6222815643575041
# Kendall correlation: 0.4772904777018144

# %% [markdown]
# Попробуем учесть команды и сложности вопросов

# %%
from scipy.optimize import minimize

# %% [markdown]
# Для удобства соберем dict с информацией по игрокам в каких играх и командах он играл

# %%
players_games = {}
for idx in filtered_train:
    teams = filtered_train[idx]
    for team_idx in range(len(teams)):
        team = teams[team_idx]
        for player_id in team['ids']:
            if player_id in players_games:
                players_games[player_id].append({'game_id': idx, 'team_idx': team_idx})
            else:
                players_games[player_id] = [{'game_id': idx, 'team_idx': team_idx}]

# %% [markdown]
# В данных есть случаи, когда какие-то игроки всегда играли только в одних и тех же командах, в таком случае у нас нет данных, для того, чтобы отличить таких игроков по рейтингу, поэтому будем считать их "одним" игроком

# %%
similar_players = {}
for player_id in players_games:
    games = players_games[player_id]
    game_ids = tuple(sorted([e['game_id'] for e in games]))
    if game_ids in similar_players:
        similar_players[game_ids].append(player_id)
    else:
        similar_players[game_ids] = [player_id]
        
for k in similar_players:
    similar_players[k] = sorted(similar_players[k])

# %%
train_players_ids = [sorted(similar_players[k])[0] for k in similar_players]

# %% [markdown]
# Инициализируем сложности вопросов и рейтинги игроков какими-то начальными значениями, например можно инициализировать сложности вопросов по тому какой процент команд в данном турнире на него ответил. Далее будем поэтапно подбирать параметры сложности вопросов и значения рейтингов. Считаем рейтинг заданной команды как средний по рейтингу игроков, ошибку считаем на основе разности между рейтингом и сложностью вопроса и тем правильный был ответ или нет. На каждом шаге пытаемся минимизировать ошибку

# %%
players_scores = {k: random.random() for k in train_players_ids}

# %%
def get_player_score(player_id, players_data):
    if player_id not in train_players_ids:
        return None
    return players_data[player_id]

def get_team_score(team, players_data):
    s = 0.0
    ii = 0
    for curr_id in team['ids']:
        score = get_player_score(curr_id, players_data)
        if score is not None:
            s += score
            ii += 1
    if ii == 0:
        return (None, None)
    return (s, ii)

for idx in filtered_train:
    teams = filtered_train[idx]
    for team in teams:
        team['score'] = get_team_score(team, players_scores)

# %%
question_scores = {}
for idx in filtered_train:
    games = filtered_train[idx]
    if len(games) == 0:
        continue
    l = len(games[0]['mask'])
    #question_scores[idx] = [random.random() for k in range(l)]
    question_scores[idx] = []
    for k in range(l):
        s = ''
        for i in range(len(games)):
            s += games[i]['mask'][k]
        question_scores[idx].append(float(s.count('1')) / l)

# %%
def get_optim_game_score(game_id, question_idx):
    teams = filtered_train[game_id]
    teams_scores = []
    for team in teams:
        s, ii = team['score']
        if s is None:
            teams_scores.append(None)
            continue
        teams_scores.append(s / ii)
    def count_error(score):
        error = 0.0
        for idx in range(len(teams)):
            team = teams[idx]
            team_score = teams_scores[idx]
            if team_score is None:
                continue
            if team['mask'][question_idx] == '0':
                if team_score > score:
                    error += team_score - score
            else:
                if team_score < score:
                    error += score - team_score
        return error
    res = minimize(count_error, question_scores[game_id][question_idx], method='BFGS', options={'maxiter': 1})
    return res.x[0]

def get_optim_player_score(player_id):
    games = players_games[player_id]
    def count_error(score):
        error = 0.0
        for game in games:
            game_id = game['game_id']
            team_idx = game['team_idx']
            teams = filtered_train[game_id]
            team = teams[team_idx]
            team_score = team['score']
            if team_score is None:
                continue
            s, ii = team_score
            s -= players_scores[player_id]
            team_score = (s + score) / ii
            for idx in range(len(team['mask'])):
                question_res = team['mask'][idx]
                question_score = question_scores[game_id][idx]
                if question_res == '0':
                    if team_score > question_score:
                        error += team_score - question_score
                else:
                    if team_score < question_score:
                        error += question_score - team_score
        return error
    res = minimize(count_error, players_scores[player_id], method='BFGS', options={'maxiter': 1})
    return res.x[0]

# %%
for _ in range(1):
    for game_id in question_scores:
        questions = question_scores[game_id]
        for idx in range(len(questions)):
            question = questions[idx]
            score = get_optim_game_score(game_id, idx)
            questions[idx] = score
    for idx in range(len(train_players_ids)):
        games = players_games[player_id]
        game_ids = tuple(sorted([e['game_id'] for e in games]))
        player_id = train_players_ids[idx]
        old_score = players_scores[player_id]
        players_scores[player_id] = get_optim_player_score(player_id)
        for game in players_games[train_players_ids[idx]]:
            team = filtered_train[game['game_id']][game['team_idx']]
            s, ii = team['score']
            if s is None:
                continue
            team['score'] = (s - old_score + players_scores[player_id], ii)

# %% [markdown]
# Расчет корреляций для тестовой выборки

# %%
n_tournaments = 0
correlation_spearmanr = 0.0
correlation_kendall = 0.0
for tournament_id in list(test.keys()):
    tournament = test[tournament_id]
    if len(tournament) == 0:
        continue
    real_order = []
    predicted_order = []
    unknown = True
    for team_data in tournament:
        real_order.append(team_data['position'])
        score = 0.0
        count = 0
        for member in team_data['teamMembers']:
            id = member['player']['id']
            if id in train_players_ids:
                score += players_scores[id]
                count += 1
        if count == 0:
            predicted_order.append(0)
        else:
            unknown = False
            predicted_order.append(score / count)
    if unknown or len(predicted_order) <= 1:
        continue
    predicted_order.reverse()
    correlation_spearmanr += stats.spearmanr(predicted_order, real_order).correlation
    tau, _ = stats.kendalltau(predicted_order, real_order)
    correlation_kendall += tau
    n_tournaments += 1
print(f'Spearmanr correlation: {correlation_spearmanr / n_tournaments}')
print(f'Kendall correlation: {correlation_kendall / n_tournaments}')
# Out:
# Spearmanr correlation: 0.6325773318514789
# Kendall correlation: 0.4902036866538402
